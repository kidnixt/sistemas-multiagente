# %% [markdown]
# # Khun Poker - 3 Jugadores

# %% [markdown]
# ## Imports

# %%
from games.kuhn.kuhn3 import KuhnPoker3
from agents.counterfactual_regret import CounterFactualRegret
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt

from plot_utils import plot_strategy_evolution, plot_convergence_analysis

# %% [markdown]
# ## Chequear la política aprendida

# %% [markdown]
# ### Entrenar 10 veces

# %%
num_runs = 10
training_iterations = 2000
all_policies = []

print(f"Ejecutando {num_runs} sesiones de entrenamiento de {training_iterations} iteraciones cada una...")

for i in range(num_runs):
    print(f"\n--- Iniciando Ejecución {i+1}/{num_runs} ---")
    # Reinicializar el juego y los agentes para una ejecución limpia
    g = KuhnPoker3(initial_player=0)  # Semilla fija para el juego para reproducibilidad
    agent_classes = [CounterFactualRegret, CounterFactualRegret, CounterFactualRegret]
    my_agents = {}
    g.reset()
    for agent_id, agent_name in enumerate(g.agents):
        my_agents[agent_name] = agent_classes[agent_id](
            game=g, 
            agent=agent_name, 
            seed=24  # Usar una semilla diferente para el agente en cada ejecución
        )

    # Entrenar agentes
    for agent_name in g.agents:
        my_agents[agent_name].train(training_iterations)

    # Almacenar las políticas de esta ejecución
    run_policies = {}
    for agent_name in g.agents:
        # Extraer la política final del diccionario de nodos del agente
        policy = OrderedDict(
            (n, my_agents[agent_name].node_dict[n].policy()) 
            for n in sorted(my_agents[agent_name].node_dict.keys())
        )
        print(policy)
        run_policies[agent_name] = policy
    all_policies.append(run_policies)
    print(f"Ejecución {i+1} completada. Políticas almacenadas.")
# Out:
# Ejecutando 10 sesiones de entrenamiento de 2000 iteraciones cada una...
#
# --- Iniciando Ejecución 1/10 ---
# OrderedDict([('0', array([0.89945204, 0.10054796])), ('0b', array([0.99895833, 0.00104167])), ('0bb', array([9.99072356e-01, 9.27643785e-04])), ('0bp', array([9.99072356e-01, 9.27643785e-04])), ('0p', array([0.64222867, 0.35777133])), ('0pb', array([0.99814471, 0.00185529])), ('0pbb', array([9.99432761e-01, 5.67238781e-04])), ('0pbp', array([9.99432761e-01, 5.67238781e-04])), ('0pp', array([0.74353497, 0.25646503])), ('0ppb', array([9.99432761e-01, 5.67238781e-04])), ('0ppbb', array([9.99189022e-01, 8.10978015e-04])), ('0ppbp', array([9.99189022e-01, 8.10978015e-04])), ('1', array([0.91744549, 0.08255451])), ('1b', array([0.97002168, 0.02997832])), ('1bb', array([0.99795501, 0.00204499])), ('1bp', array([0.99897751, 0.00102249])), ('1p', array([0.96597456, 0.03402544])), ('1pb', array([0.9043056, 0.0956944])), ('1pbb', array([9.99435827e-01, 5.64173403e-04])), ('1pbp', array([0.9979885, 0.0020115])), ('1pp', array([0.88032662, 0.11967338])), ('1ppb', array([0.99605079, 0.00394921])), ('1ppbb', array([0.97775886, 0.02224114])), ('1ppbp', array([0.99898904, 0.00101096])), ('2', array([0.96082029, 0.03917971])), ('2b', array([0.70915079, 0.29084921])), ('2bb', array([0.49206472, 0.50793528])), ('2bp', array([0.8104694, 0.1895306])), ('2p', array([0.98556927, 0.01443073])), ('2pb', array([0.65764513, 0.34235487])), ('2pbb', array([0.95810762, 0.04189238])), ('2pbp', array([0.83843959, 0.16156041])), ('2pp', array([0.99570815, 0.00429185])), ('2ppb', array([0.18609973, 0.81390027])), ('2ppbb', array([0.75123386, 0.24876614])), ('2ppbp', array([0.86025602, 0.13974398])), ('3', array([0.77832929, 0.22167071])), ('3b', array([9.54198473e-04, 9.99045802e-01])), ('3bb', array([9.88142292e-04, 9.99011858e-01])), ('3bp', array([0.00494071, 0.99505929])), ('3p', array([0.28090815, 0.71909185])), ('3pb', array([9.88142292e-04, 9.99011858e-01])), ('3pbb', array([6.20078787e-04, 9.99379921e-01])), ('3pbp', array([6.20078787e-04, 9.99379921e-01])), ('3pp', array([0.00296443, 0.99703557])), ('3ppb', array([6.20078787e-04, 9.99379921e-01])), ('3ppbb', array([0.00169842, 0.99830158])), ('3ppbp', array([0.00169842, 0.99830158]))])
# OrderedDict([('0', array([9.99053030e-01, 9.46969697e-04])), ('0b', array([0.99893162, 0.00106838])), ('0bb', array([0.99897541, 0.00102459])), ('0bp', array([0.99897541, 0.00102459])), ('0p', array([0.72732814, 0.27267186])), ('0pb', array([0.99795082, 0.00204918])), ('0pbb', array([0.99383886, 0.00616114])), ('0pbp', array([9.99526066e-01, 4.73933649e-04])), ('0pp', array([0.89673961, 0.10326039])), ('0ppb', array([0.9985782, 0.0014218])), ('0ppbb', array([0.99632774, 0.00367226])), ('0ppbp', array([9.99265547e-01, 7.34452591e-04])), ('1', array([0.81703675, 0.18296325])), ('1b', array([0.99585838, 0.00414162])), ('1bb', array([9.99067164e-01, 9.32835821e-04])), ('1bp', array([0.99440299, 0.00559701])), ('1p', array([0.90452605, 0.09547395])), ('1pb', array([9.99067164e-01, 9.32835821e-04])), ('1pbb', array([9.99409298e-01, 5.90702294e-04])), ('1pbp', array([0.99653824, 0.00346176])), ('1pp', array([0.57616631, 0.42383369])), ('1ppb', array([9.99409298e-01, 5.90702294e-04])), ('1ppbb', array([9.99446117e-01, 5.53883445e-04])), ('1ppbp', array([9.99446117e-01, 5.53883445e-04])), ('2', array([0.96518664, 0.03481336])), ('2b', array([0.48068844, 0.51931156])), ('2bb', array([0.97945158, 0.02054842])), ('2bp', array([0.77914004, 0.22085996])), ('2p', array([0.98518537, 0.01481463])), ('2pb', array([0.60722111, 0.39277889])), ('2pbb', array([9.99431980e-01, 5.68020309e-04])), ('2pbp', array([0.78410503, 0.21589497])), ('2pp', array([0.97820659, 0.02179341])), ('2ppb', array([0.49332072, 0.50667928])), ('2ppbb', array([9.99010685e-01, 9.89315211e-04])), ('2ppbp', array([0.33831865, 0.66168135])), ('3', array([0.66240182, 0.33759818])), ('3b', array([9.61538462e-04, 9.99038462e-01])), ('3bb', array([0.00105932, 0.99894068])), ('3bp', array([0.00105932, 0.99894068])), ('3p', array([0.02761469, 0.97238531])), ('3pb', array([0.00105932, 0.99894068])), ('3pbb', array([7.57860289e-04, 9.99242140e-01])), ('3pbp', array([7.57860289e-04, 9.99242140e-01])), ('3pp', array([0.00105932, 0.99894068])), ('3ppb', array([7.57860289e-04, 9.99242140e-01])), ('3ppbb', array([0.01740991, 0.98259009])), ('3ppbp', array([0.01740991, 0.98259009]))])
# OrderedDict([('0', array([0.99513789, 0.00486211])), ('0b', array([0.99896907, 0.00103093])), ('0bb', array([9.99053030e-01, 9.46969697e-04])), ('0bp', array([9.99053030e-01, 9.46969697e-04])), ('0p', array([0.99265464, 0.00734536])), ('0pb', array([9.99053030e-01, 9.46969697e-04])), ('0pbb', array([9.99503515e-01, 4.96485111e-04])), ('0pbp', array([9.99503515e-01, 4.96485111e-04])), ('0pp', array([0.74171382, 0.25828618])), ('0ppb', array([9.99503515e-01, 4.96485111e-04])), ('0ppbb', array([9.99480722e-01, 5.19278203e-04])), ('0ppbp', array([9.99480722e-01, 5.19278203e-04])), ('1', array([0.98609816, 0.01390184])), ('1b', array([0.99625749, 0.00374251])), ('1bb', array([0.99791667, 0.00208333])), ('1bp', array([0.99895833, 0.00104167])), ('1p', array([0.6030297, 0.3969703])), ('1pb', array([0.996875, 0.003125])), ('1pbb', array([9.99461732e-01, 5.38268484e-04])), ('1pbp', array([0.9328117, 0.0671883])), ('1pp', array([0.732747, 0.267253])), ('1ppb', array([0.78622325, 0.21377675])), ('1ppbb', array([9.99172508e-01, 8.27491573e-04])), ('1ppbp', array([0.43565869, 0.56434131])), ('2', array([0.99096575, 0.00903425])), ('2b', array([0.99808795, 0.00191205])), ('2bb', array([0.99895397, 0.00104603])), ('2bp', array([0.15336968, 0.84663032])), ('2p', array([0.92131543, 0.07868457])), ('2pb', array([0.44926708, 0.55073292])), ('2pbb', array([9.99501425e-01, 4.98575400e-04])), ('2pbp', array([0.81342336, 0.18657664])), ('2pp', array([0.96445043, 0.03554957])), ('2ppb', array([0.44044789, 0.55955211])), ('2ppbb', array([0.94088306, 0.05911694])), ('2ppbp', array([0.53786732, 0.46213268])), ('3', array([0.94441265, 0.05558735])), ('3b', array([0.00101833, 0.99898167])), ('3bb', array([9.72762646e-04, 9.99027237e-01])), ('3bp', array([9.72762646e-04, 9.99027237e-01])), ('3p', array([0.17384596, 0.82615404])), ('3pb', array([0.00194553, 0.99805447])), ('3pbb', array([5.12020879e-04, 9.99487979e-01])), ('3pbp', array([5.12020879e-04, 9.99487979e-01])), ('3pp', array([0.00194553, 0.99805447])), ('3ppb', array([5.12020879e-04, 9.99487979e-01])), ('3ppbb', array([0.00292883, 0.99707117])), ('3ppbp', array([0.00292883, 0.99707117]))])
# Ejecución 1 completada. Políticas almacenadas.
#
# --- Iniciando Ejecución 2/10 ---
# OrderedDict([('0', array([0.89945204, 0.10054796])), ('0b', array([0.99895833, 0.00104167])), ('0bb', array([9.99072356e-01, 9.27643785e-04])), ('0bp', array([9.99072356e-01, 9.27643785e-04])), ('0p', array([0.64222867, 0.35777133])), ('0pb', array([0.99814471, 0.00185529])), ('0pbb', array([9.99432761e-01, 5.67238781e-04])), ('0pbp', array([9.99432761e-01, 5.67238781e-04])), ('0pp', array([0.74353497, 0.25646503])), ('0ppb', array([9.99432761e-01, 5.67238781e-04])), ('0ppbb', array([9.99189022e-01, 8.10978015e-04])), ('0ppbp', array([9.99189022e-01, 8.10978015e-04])), ('1', array([0.91744549, 0.08255451])), ('1b', array([0.97002168, 0.02997832])), ('1bb', array([0.99795501, 0.00204499])), ('1bp', array([0.99897751, 0.00102249])), ('1p', array([0.96597456, 0.03402544])), ('1pb', array([0.9043056, 0.0956944])), ('1pbb', array([9.99435827e-01, 5.64173403e-04])), ('1pbp', array([0.9979885, 0.0020115])), ('1pp', array([0.88032662, 0.11967338])), ('1ppb', array([0.99605079, 0.00394921])), ('1ppbb', array([0.97775886, 0.02224114])), ('1ppbp', array([0.99898904, 0.00101096])), ('2', array([0.96082029, 0.03917971])), ('2b', array([0.70915079, 0.29084921])), ('2bb', array([0.49206472, 0.50793528])), ('2bp', array([0.8104694, 0.1895306])), ('2p', array([0.98556927, 0.01443073])), ('2pb', array([0.65764513, 0.34235487])), ('2pbb', array([0.95810762, 0.04189238])), ('2pbp', array([0.83843959, 0.16156041])), ('2pp', array([0.99570815, 0.00429185])), ('2ppb', array([0.18609973, 0.81390027])), ('2ppbb', array([0.75123386, 0.24876614])), ('2ppbp', array([0.86025602, 0.13974398])), ('3', array([0.77832929, 0.22167071])), ('3b', array([9.54198473e-04, 9.99045802e-01])), ('3bb', array([9.88142292e-04, 9.99011858e-01])), ('3bp', array([0.00494071, 0.99505929])), ('3p', array([0.28090815, 0.71909185])), ('3pb', array([9.88142292e-04, 9.99011858e-01])), ('3pbb', array([6.20078787e-04, 9.99379921e-01])), ('3pbp', array([6.20078787e-04, 9.99379921e-01])), ('3pp', array([0.00296443, 0.99703557])), ('3ppb', array([6.20078787e-04, 9.99379921e-01])), ('3ppbb', array([0.00169842, 0.99830158])), ('3ppbp', array([0.00169842, 0.99830158]))])
# OrderedDict([('0', array([9.99053030e-01, 9.46969697e-04])), ('0b', array([0.99893162, 0.00106838])), ('0bb', array([0.99897541, 0.00102459])), ('0bp', array([0.99897541, 0.00102459])), ('0p', array([0.72732814, 0.27267186])), ('0pb', array([0.99795082, 0.00204918])), ('0pbb', array([0.99383886, 0.00616114])), ('0pbp', array([9.99526066e-01, 4.73933649e-04])), ('0pp', array([0.89673961, 0.10326039])), ('0ppb', array([0.9985782, 0.0014218])), ('0ppbb', array([0.99632774, 0.00367226])), ('0ppbp', array([9.99265547e-01, 7.34452591e-04])), ('1', array([0.81703675, 0.18296325])), ('1b', array([0.99585838, 0.00414162])), ('1bb', array([9.99067164e-01, 9.32835821e-04])), ('1bp', array([0.99440299, 0.00559701])), ('1p', array([0.90452605, 0.09547395])), ('1pb', array([9.99067164e-01, 9.32835821e-04])), ('1pbb', array([9.99409298e-01, 5.90702294e-04])), ('1pbp', array([0.99653824, 0.00346176])), ('1pp', array([0.57616631, 0.42383369])), ('1ppb', array([9.99409298e-01, 5.90702294e-04])), ('1ppbb', array([9.99446117e-01, 5.53883445e-04])), ('1ppbp', array([9.99446117e-01, 5.53883445e-04])), ('2', array([0.96518664, 0.03481336])), ('2b', array([0.48068844, 0.51931156])), ('2bb', array([0.97945158, 0.02054842])), ('2bp', array([0.77914004, 0.22085996])), ('2p', array([0.98518537, 0.01481463])), ('2pb', array([0.60722111, 0.39277889])), ('2pbb', array([9.99431980e-01, 5.68020309e-04])), ('2pbp', array([0.78410503, 0.21589497])), ('2pp', array([0.97820659, 0.02179341])), ('2ppb', array([0.49332072, 0.50667928])), ('2ppbb', array([9.99010685e-01, 9.89315211e-04])), ('2ppbp', array([0.33831865, 0.66168135])), ('3', array([0.66240182, 0.33759818])), ('3b', array([9.61538462e-04, 9.99038462e-01])), ('3bb', array([0.00105932, 0.99894068])), ('3bp', array([0.00105932, 0.99894068])), ('3p', array([0.02761469, 0.97238531])), ('3pb', array([0.00105932, 0.99894068])), ('3pbb', array([7.57860289e-04, 9.99242140e-01])), ('3pbp', array([7.57860289e-04, 9.99242140e-01])), ('3pp', array([0.00105932, 0.99894068])), ('3ppb', array([7.57860289e-04, 9.99242140e-01])), ('3ppbb', array([0.01740991, 0.98259009])), ('3ppbp', array([0.01740991, 0.98259009]))])
# OrderedDict([('0', array([0.99513789, 0.00486211])), ('0b', array([0.99896907, 0.00103093])), ('0bb', array([9.99053030e-01, 9.46969697e-04])), ('0bp', array([9.99053030e-01, 9.46969697e-04])), ('0p', array([0.99265464, 0.00734536])), ('0pb', array([9.99053030e-01, 9.46969697e-04])), ('0pbb', array([9.99503515e-01, 4.96485111e-04])), ('0pbp', array([9.99503515e-01, 4.96485111e-04])), ('0pp', array([0.74171382, 0.25828618])), ('0ppb', array([9.99503515e-01, 4.96485111e-04])), ('0ppbb', array([9.99480722e-01, 5.19278203e-04])), ('0ppbp', array([9.99480722e-01, 5.19278203e-04])), ('1', array([0.98609816, 0.01390184])), ('1b', array([0.99625749, 0.00374251])), ('1bb', array([0.99791667, 0.00208333])), ('1bp', array([0.99895833, 0.00104167])), ('1p', array([0.6030297, 0.3969703])), ('1pb', array([0.996875, 0.003125])), ('1pbb', array([9.99461732e-01, 5.38268484e-04])), ('1pbp', array([0.9328117, 0.0671883])), ('1pp', array([0.732747, 0.267253])), ('1ppb', array([0.78622325, 0.21377675])), ('1ppbb', array([9.99172508e-01, 8.27491573e-04])), ('1ppbp', array([0.43565869, 0.56434131])), ('2', array([0.99096575, 0.00903425])), ('2b', array([0.99808795, 0.00191205])), ('2bb', array([0.99895397, 0.00104603])), ('2bp', array([0.15336968, 0.84663032])), ('2p', array([0.92131543, 0.07868457])), ('2pb', array([0.44926708, 0.55073292])), ('2pbb', array([9.99501425e-01, 4.98575400e-04])), ('2pbp', array([0.81342336, 0.18657664])), ('2pp', array([0.96445043, 0.03554957])), ('2ppb', array([0.44044789, 0.55955211])), ('2ppbb', array([0.94088306, 0.05911694])), ('2ppbp', array([0.53786732, 0.46213268])), ('3', array([0.94441265, 0.05558735])), ('3b', array([0.00101833, 0.99898167])), ('3bb', array([9.72762646e-04, 9.99027237e-01])), ('3bp', array([9.72762646e-04, 9.99027237e-01])), ('3p', array([0.17384596, 0.82615404])), ('3pb', array([0.00194553, 0.99805447])), ('3pbb', array([5.12020879e-04, 9.99487979e-01])), ('3pbp', array([5.12020879e-04, 9.99487979e-01])), ('3pp', array([0.00194553, 0.99805447])), ('3ppb', array([5.12020879e-04, 9.99487979e-01])), ('3ppbb', array([0.00292883, 0.99707117])), ('3ppbp', array([0.00292883, 0.99707117]))])
# Ejecución 1 completada. Políticas almacenadas.
#
# --- Iniciando Ejecución 2/10 ---
# OrderedDict([('0', array([0.98056788, 0.01943212])), ('0b', array([0.99897959, 0.00102041])), ('0bb', array([0.99350649, 0.00649351])), ('0bp', array([0.99350649, 0.00649351])), ('0p', array([0.62462295, 0.37537705])), ('0pb', array([0.99891775, 0.00108225])), ('0pbb', array([9.99504943e-01, 4.95056900e-04])), ('0pbp', array([9.99504943e-01, 4.95056900e-04])), ('0pp', array([0.78398753, 0.21601247])), ('0ppb', array([9.99504943e-01, 4.95056900e-04])), ('0ppbb', array([9.99183181e-01, 8.16819297e-04])), ('0ppbp', array([9.99183181e-01, 8.16819297e-04])), ('1', array([0.93570858, 0.06429142])), ('1b', array([0.98122673, 0.01877327])), ('1bb', array([0.99800797, 0.00199203])), ('1bp', array([0.93186798, 0.06813202])), ('1p', array([0.9189666, 0.0810334])), ('1pb', array([0.93608109, 0.06391891])), ('1pbb', array([9.99476123e-01, 5.23876863e-04])), ('1pbp', array([9.99476123e-01, 5.23876863e-04])), ('1pp', array([0.81165021, 0.18834979])), ('1ppb', array([0.89390574, 0.10609426])), ('1ppbb', array([0.99780609, 0.00219391])), ('1ppbp', array([0.99451523, 0.00548477])), ('2', array([0.998998, 0.001002])), ('2b', array([0.91912126, 0.08087874])), ('2bb', array([0.98917323, 0.01082677])), ('2bp', array([0.09557883, 0.90442117])), ('2p', array([0.9788128, 0.0211872])), ('2pb', array([0.67175415, 0.32824585])), ('2pbb', array([0.31224937, 0.68775063])), ('2pbp', array([0.63910287, 0.36089713])), ('2pp', array([0.99409449, 0.00590551])), ('2ppb', array([0.56636672, 0.43363328])), ('2ppbb', array([0.61400531, 0.38599469])), ('2ppbp', array([0.474052, 0.525948])), ('3', array([0.81416833, 0.18583167])), ('3b', array([0.0010352, 0.9989648])), ('3bb', array([9.46969697e-04, 9.99053030e-01])), ('3bp', array([9.46969697e-04, 9.99053030e-01])), ('3p', array([0.26592949, 0.73407051])), ('3pb', array([0.00189394, 0.99810606])), ('3pbb', array([6.45087832e-04, 9.99354912e-01])), ('3pbp', array([0.00305625, 0.99694375])), ('3pp', array([0.00189394, 0.99810606])), ('3ppb', array([6.45087832e-04, 9.99354912e-01])), ('3ppbb', array([0.00194637, 0.99805363])), ('3ppbp', array([0.00194637, 0.99805363]))])
# OrderedDict([('0', array([0.99888889, 0.00111111])), ('0b', array([0.99893617, 0.00106383])), ('0bb', array([0.99896266, 0.00103734])), ('0bp', array([0.99792531, 0.00207469])), ('0p', array([0.68825617, 0.31174383])), ('0pb', array([0.99792531, 0.00207469])), ('0pbb', array([9.99443826e-01, 5.56173526e-04])), ('0pbp', array([9.99443826e-01, 5.56173526e-04])), ('0pp', array([0.741066, 0.258934])), ('0ppb', array([0.99610679, 0.00389321])), ('0ppbb', array([9.99227156e-01, 7.72844354e-04])), ('0ppbp', array([9.99227156e-01, 7.72844354e-04])), ('1', array([0.87911106, 0.12088894])), ('1b', array([0.9955104, 0.0044896])), ('1bb', array([0.99701789, 0.00298211])), ('1bp', array([9.99005964e-01, 9.94035785e-04])), ('1p', array([0.7849167, 0.2150833])), ('1pb', array([0.99331835, 0.00668165])), ('1pbb', array([9.99479161e-01, 5.20839148e-04])), ('1pbp', array([9.99479161e-01, 5.20839148e-04])), ('1pp', array([0.69773539, 0.30226461])), ('1ppb', array([0.99138473, 0.00861527])), ('1ppbb', array([9.99397911e-01, 6.02089105e-04])), ('1ppbp', array([9.99397911e-01, 6.02089105e-04])), ('2', array([0.97397726, 0.02602274])), ('2b', array([0.89535718, 0.10464282])), ('2bb', array([9.99007937e-01, 9.92063492e-04])), ('2bp', array([0.28521814, 0.71478186])), ('2p', array([0.96868831, 0.03131169])), ('2pb', array([0.89218413, 0.10781587])), ('2pbb', array([0.90631115, 0.09368885])), ('2pbp', array([0.45623448, 0.54376552])), ('2pp', array([0.99588657, 0.00411343])), ('2ppb', array([0.59083002, 0.40916998])), ('2ppbb', array([0.8056462, 0.1943538])), ('2ppbp', array([0.49902098, 0.50097902])), ('3', array([0.87033803, 0.12966197])), ('3b', array([9.96015936e-04, 9.99003984e-01])), ('3bb', array([9.78473581e-04, 9.99021526e-01])), ('3bp', array([9.78473581e-04, 9.99021526e-01])), ('3p', array([0.08068251, 0.91931749])), ('3pb', array([9.78473581e-04, 9.99021526e-01])), ('3pbb', array([5.75640714e-04, 9.99424359e-01])), ('3pbp', array([5.75640714e-04, 9.99424359e-01])), ('3pp', array([9.78473581e-04, 9.99021526e-01])), ('3ppb', array([5.75640714e-04, 9.99424359e-01])), ('3ppbb', array([0.00617244, 0.99382756])), ('3ppbp', array([0.00617244, 0.99382756]))])
# OrderedDict([('0', array([0.9831307, 0.0168693])), ('0b', array([9.99019608e-01, 9.80392157e-04])), ('0bb', array([0.99894737, 0.00105263])), ('0bp', array([0.99894737, 0.00105263])), ('0p', array([0.97907776, 0.02092224])), ('0pb', array([0.99578947, 0.00421053])), ('0pbb', array([9.99458958e-01, 5.41041892e-04])), ('0pbp', array([9.99458958e-01, 5.41041892e-04])), ('0pp', array([0.44957052, 0.55042948])), ('0ppb', array([9.99458958e-01, 5.41041892e-04])), ('0ppbb', array([0.99749664, 0.00250336])), ('0ppbp', array([0.99449262, 0.00550738])), ('1', array([0.92705748, 0.07294252])), ('1b', array([0.98614639, 0.01385361])), ('1bb', array([9.99067164e-01, 9.32835821e-04])), ('1bp', array([9.99067164e-01, 9.32835821e-04])), ('1p', array([0.74969818, 0.25030182])), ('1pb', array([0.99160448, 0.00839552])), ('1pbb', array([9.99496884e-01, 5.03116497e-04])), ('1pbp', array([9.99496884e-01, 5.03116497e-04])), ('1pp', array([0.94739424, 0.05260576])), ('1ppb', array([0.92837273, 0.07162727])), ('1ppbb', array([9.99294995e-01, 7.05005350e-04])), ('1ppbp', array([0.97768605, 0.02231395])), ('2', array([0.9756265, 0.0243735])), ('2b', array([0.5477467, 0.4522533])), ('2bb', array([0.65918594, 0.34081406])), ('2bp', array([0.59469823, 0.40530177])), ('2p', array([0.97150305, 0.02849695])), ('2pb', array([0.72497348, 0.27502652])), ('2pbb', array([0.98095011, 0.01904989])), ('2pbp', array([0.50514681, 0.49485319])), ('2pp', array([0.94593449, 0.05406551])), ('2ppb', array([0.19191816, 0.80808184])), ('2ppbb', array([0.99264109, 0.00735891])), ('2ppbp', array([0.7713573, 0.2286427])), ('3', array([0.81626475, 0.18373525])), ('3b', array([0.00199601, 0.99800399])), ('3bb', array([0.0010142, 0.9989858])), ('3bp', array([0.0010142, 0.9989858])), ('3p', array([0.27318544, 0.72681456])), ('3pb', array([0.0010142, 0.9989858])), ('3pbb', array([6.04089108e-04, 9.99395911e-01])), ('3pbp', array([6.04089108e-04, 9.99395911e-01])), ('3pp', array([0.0010142, 0.9989858])), ('3ppb', array([6.04089108e-04, 9.99395911e-01])), ('3ppbb', array([0.01312415, 0.98687585])), ('3ppbp', array([0.00182661, 0.99817339]))])
# Ejecución 2 completada. Políticas almacenadas.
#
# --- Iniciando Ejecución 3/10 ---
# OrderedDict([('0', array([0.98056788, 0.01943212])), ('0b', array([0.99897959, 0.00102041])), ('0bb', array([0.99350649, 0.00649351])), ('0bp', array([0.99350649, 0.00649351])), ('0p', array([0.62462295, 0.37537705])), ('0pb', array([0.99891775, 0.00108225])), ('0pbb', array([9.99504943e-01, 4.95056900e-04])), ('0pbp', array([9.99504943e-01, 4.95056900e-04])), ('0pp', array([0.78398753, 0.21601247])), ('0ppb', array([9.99504943e-01, 4.95056900e-04])), ('0ppbb', array([9.99183181e-01, 8.16819297e-04])), ('0ppbp', array([9.99183181e-01, 8.16819297e-04])), ('1', array([0.93570858, 0.06429142])), ('1b', array([0.98122673, 0.01877327])), ('1bb', array([0.99800797, 0.00199203])), ('1bp', array([0.93186798, 0.06813202])), ('1p', array([0.9189666, 0.0810334])), ('1pb', array([0.93608109, 0.06391891])), ('1pbb', array([9.99476123e-01, 5.23876863e-04])), ('1pbp', array([9.99476123e-01, 5.23876863e-04])), ('1pp', array([0.81165021, 0.18834979])), ('1ppb', array([0.89390574, 0.10609426])), ('1ppbb', array([0.99780609, 0.00219391])), ('1ppbp', array([0.99451523, 0.00548477])), ('2', array([0.998998, 0.001002])), ('2b', array([0.91912126, 0.08087874])), ('2bb', array([0.98917323, 0.01082677])), ('2bp', array([0.09557883, 0.90442117])), ('2p', array([0.9788128, 0.0211872])), ('2pb', array([0.67175415, 0.32824585])), ('2pbb', array([0.31224937, 0.68775063])), ('2pbp', array([0.63910287, 0.36089713])), ('2pp', array([0.99409449, 0.00590551])), ('2ppb', array([0.56636672, 0.43363328])), ('2ppbb', array([0.61400531, 0.38599469])), ('2ppbp', array([0.474052, 0.525948])), ('3', array([0.81416833, 0.18583167])), ('3b', array([0.0010352, 0.9989648])), ('3bb', array([9.46969697e-04, 9.99053030e-01])), ('3bp', array([9.46969697e-04, 9.99053030e-01])), ('3p', array([0.26592949, 0.73407051])), ('3pb', array([0.00189394, 0.99810606])), ('3pbb', array([6.45087832e-04, 9.99354912e-01])), ('3pbp', array([0.00305625, 0.99694375])), ('3pp', array([0.00189394, 0.99810606])), ('3ppb', array([6.45087832e-04, 9.99354912e-01])), ('3ppbb', array([0.00194637, 0.99805363])), ('3ppbp', array([0.00194637, 0.99805363]))])
# OrderedDict([('0', array([0.99888889, 0.00111111])), ('0b', array([0.99893617, 0.00106383])), ('0bb', array([0.99896266, 0.00103734])), ('0bp', array([0.99792531, 0.00207469])), ('0p', array([0.68825617, 0.31174383])), ('0pb', array([0.99792531, 0.00207469])), ('0pbb', array([9.99443826e-01, 5.56173526e-04])), ('0pbp', array([9.99443826e-01, 5.56173526e-04])), ('0pp', array([0.741066, 0.258934])), ('0ppb', array([0.99610679, 0.00389321])), ('0ppbb', array([9.99227156e-01, 7.72844354e-04])), ('0ppbp', array([9.99227156e-01, 7.72844354e-04])), ('1', array([0.87911106, 0.12088894])), ('1b', array([0.9955104, 0.0044896])), ('1bb', array([0.99701789, 0.00298211])), ('1bp', array([9.99005964e-01, 9.94035785e-04])), ('1p', array([0.7849167, 0.2150833])), ('1pb', array([0.99331835, 0.00668165])), ('1pbb', array([9.99479161e-01, 5.20839148e-04])), ('1pbp', array([9.99479161e-01, 5.20839148e-04])), ('1pp', array([0.69773539, 0.30226461])), ('1ppb', array([0.99138473, 0.00861527])), ('1ppbb', array([9.99397911e-01, 6.02089105e-04])), ('1ppbp', array([9.99397911e-01, 6.02089105e-04])), ('2', array([0.97397726, 0.02602274])), ('2b', array([0.89535718, 0.10464282])), ('2bb', array([9.99007937e-01, 9.92063492e-04])), ('2bp', array([0.28521814, 0.71478186])), ('2p', array([0.96868831, 0.03131169])), ('2pb', array([0.89218413, 0.10781587])), ('2pbb', array([0.90631115, 0.09368885])), ('2pbp', array([0.45623448, 0.54376552])), ('2pp', array([0.99588657, 0.00411343])), ('2ppb', array([0.59083002, 0.40916998])), ('2ppbb', array([0.8056462, 0.1943538])), ('2ppbp', array([0.49902098, 0.50097902])), ('3', array([0.87033803, 0.12966197])), ('3b', array([9.96015936e-04, 9.99003984e-01])), ('3bb', array([9.78473581e-04, 9.99021526e-01])), ('3bp', array([9.78473581e-04, 9.99021526e-01])), ('3p', array([0.08068251, 0.91931749])), ('3pb', array([9.78473581e-04, 9.99021526e-01])), ('3pbb', array([5.75640714e-04, 9.99424359e-01])), ('3pbp', array([5.75640714e-04, 9.99424359e-01])), ('3pp', array([9.78473581e-04, 9.99021526e-01])), ('3ppb', array([5.75640714e-04, 9.99424359e-01])), ('3ppbb', array([0.00617244, 0.99382756])), ('3ppbp', array([0.00617244, 0.99382756]))])
# OrderedDict([('0', array([0.9831307, 0.0168693])), ('0b', array([9.99019608e-01, 9.80392157e-04])), ('0bb', array([0.99894737, 0.00105263])), ('0bp', array([0.99894737, 0.00105263])), ('0p', array([0.97907776, 0.02092224])), ('0pb', array([0.99578947, 0.00421053])), ('0pbb', array([9.99458958e-01, 5.41041892e-04])), ('0pbp', array([9.99458958e-01, 5.41041892e-04])), ('0pp', array([0.44957052, 0.55042948])), ('0ppb', array([9.99458958e-01, 5.41041892e-04])), ('0ppbb', array([0.99749664, 0.00250336])), ('0ppbp', array([0.99449262, 0.00550738])), ('1', array([0.92705748, 0.07294252])), ('1b', array([0.98614639, 0.01385361])), ('1bb', array([9.99067164e-01, 9.32835821e-04])), ('1bp', array([9.99067164e-01, 9.32835821e-04])), ('1p', array([0.74969818, 0.25030182])), ('1pb', array([0.99160448, 0.00839552])), ('1pbb', array([9.99496884e-01, 5.03116497e-04])), ('1pbp', array([9.99496884e-01, 5.03116497e-04])), ('1pp', array([0.94739424, 0.05260576])), ('1ppb', array([0.92837273, 0.07162727])), ('1ppbb', array([9.99294995e-01, 7.05005350e-04])), ('1ppbp', array([0.97768605, 0.02231395])), ('2', array([0.9756265, 0.0243735])), ('2b', array([0.5477467, 0.4522533])), ('2bb', array([0.65918594, 0.34081406])), ('2bp', array([0.59469823, 0.40530177])), ('2p', array([0.97150305, 0.02849695])), ('2pb', array([0.72497348, 0.27502652])), ('2pbb', array([0.98095011, 0.01904989])), ('2pbp', array([0.50514681, 0.49485319])), ('2pp', array([0.94593449, 0.05406551])), ('2ppb', array([0.19191816, 0.80808184])), ('2ppbb', array([0.99264109, 0.00735891])), ('2ppbp', array([0.7713573, 0.2286427])), ('3', array([0.81626475, 0.18373525])), ('3b', array([0.00199601, 0.99800399])), ('3bb', array([0.0010142, 0.9989858])), ('3bp', array([0.0010142, 0.9989858])), ('3p', array([0.27318544, 0.72681456])), ('3pb', array([0.0010142, 0.9989858])), ('3pbb', array([6.04089108e-04, 9.99395911e-01])), ('3pbp', array([6.04089108e-04, 9.99395911e-01])), ('3pp', array([0.0010142, 0.9989858])), ('3ppb', array([6.04089108e-04, 9.99395911e-01])), ('3ppbb', array([0.01312415, 0.98687585])), ('3ppbp', array([0.00182661, 0.99817339]))])
# Ejecución 2 completada. Políticas almacenadas.
#
# --- Iniciando Ejecución 3/10 ---
# OrderedDict([('0', array([9.99007937e-01, 9.92063492e-04])), ('0b', array([9.99025341e-01, 9.74658869e-04])), ('0bb', array([0.99899598, 0.00100402])), ('0bp', array([0.99899598, 0.00100402])), ('0p', array([0.93544132, 0.06455868])), ('0pb', array([0.99698795, 0.00301205])), ('0pbb', array([9.99503476e-01, 4.96524330e-04])), ('0pbp', array([0.99851043, 0.00148957])), ('0pp', array([0.99698795, 0.00301205])), ('0ppb', array([9.99503476e-01, 4.96524330e-04])), ('0ppbb', array([9.99479038e-01, 5.20962058e-04])), ('0ppbp', array([9.99479038e-01, 5.20962058e-04])), ('1', array([0.99649022, 0.00350978])), ('1b', array([0.99890351, 0.00109649])), ('1bb', array([9.99021526e-01, 9.78473581e-04])), ('1bp', array([9.99021526e-01, 9.78473581e-04])), ('1p', array([0.49193864, 0.50806136])), ('1pb', array([0.99608611, 0.00391389])), ('1pbb', array([0.99844816, 0.00155184])), ('1pbp', array([0.92287785, 0.07712215])), ('1pp', array([0.58527301, 0.41472699])), ('1ppb', array([0.9856146, 0.0143854])), ('1ppbb', array([0.99777108, 0.00222892])), ('1ppbp', array([0.99777108, 0.00222892])), ('2', array([0.95957585, 0.04042415])), ('2b', array([0.99709302, 0.00290698])), ('2bb', array([9.99015748e-01, 9.84251969e-04])), ('2bp', array([0.1588955, 0.8411045])), ('2p', array([0.98662283, 0.01337717])), ('2pb', array([0.63138748, 0.36861252])), ('2pbb', array([0.95830619, 0.04169381])), ('2pbp', array([0.83636163, 0.16363837])), ('2pp', array([0.96628937, 0.03371063])), ('2ppb', array([0.79857521, 0.20142479])), ('2ppbb', array([9.99508935e-01, 4.91065189e-04])), ('2ppbp', array([0.38516854, 0.61483146])), ('3', array([0.97291036, 0.02708964])), ('3b', array([9.70873786e-04, 9.99029126e-01])), ('3bb', array([0.0010352, 0.9989648])), ('3bp', array([0.0010352, 0.9989648])), ('3p', array([0.0364134, 0.9635866])), ('3pb', array([0.0010352, 0.9989648])), ('3pbb', array([4.99924085e-04, 9.99500076e-01])), ('3pbp', array([4.99924085e-04, 9.99500076e-01])), ('3pp', array([0.0010352, 0.9989648])), ('3ppb', array([4.99924085e-04, 9.99500076e-01])), ('3ppbb', array([0.02666254, 0.97333746])), ('3ppbp', array([0.02666254, 0.97333746]))])
# OrderedDict([('0', array([0.99300285, 0.00699715])), ('0b', array([0.9989858, 0.0010142])), ('0bb', array([0.99709302, 0.00290698])), ('0bp', array([9.99031008e-01, 9.68992248e-04])), ('0p', array([0.98868536, 0.01131464])), ('0pb', array([0.99515504, 0.00484496])), ('0pbb', array([9.99522274e-01, 4.77726024e-04])), ('0pbp', array([0.99874597, 0.00125403])), ('0pp', array([0.68117362, 0.31882638])), ('0ppb', array([9.99522274e-01, 4.77726024e-04])), ('0ppbb', array([9.99487097e-01, 5.12902702e-04])), ('0ppbp', array([9.99487097e-01, 5.12902702e-04])), ('1', array([0.92695645, 0.07304355])), ('1b', array([0.89662614, 0.10337386])), ('1bb', array([0.9989899, 0.0010101])), ('1bp', array([0.94949495, 0.05050505])), ('1p', array([0.49727168, 0.50272832])), ('1pb', array([0.89660184, 0.10339816])), ('1pbb', array([9.99452942e-01, 5.47058484e-04])), ('1pbp', array([0.98542189, 0.01457811])), ('1pp', array([0.83918766, 0.16081234])), ('1ppb', array([0.95564773, 0.04435227])), ('1ppbb', array([9.99033186e-01, 9.66814018e-04])), ('1ppbp', array([9.99033186e-01, 9.66814018e-04])), ('2', array([0.99367096, 0.00632904])), ('2b', array([0.99897119, 0.00102881])), ('2bb', array([0.99894958, 0.00105042])), ('2bp', array([0.31768614, 0.68231386])), ('2p', array([0.96935072, 0.03064928])), ('2pb', array([0.93193778, 0.06806222])), ('2pbb', array([9.99478024e-01, 5.21975803e-04])), ('2pbp', array([0.39315584, 0.60684416])), ('2pp', array([0.97689076, 0.02310924])), ('2ppb', array([0.23428994, 0.76571006])), ('2ppbb', array([0.99628532, 0.00371468])), ('2ppbp', array([0.47853296, 0.52146704])), ('3', array([0.75069044, 0.24930956])), ('3b', array([9.98003992e-04, 9.99001996e-01])), ('3bb', array([9.74658869e-04, 9.99025341e-01])), ('3bp', array([0.00194932, 0.99805068])), ('3p', array([0.00112275, 0.99887725])), ('3pb', array([9.74658869e-04, 9.99025341e-01])), ('3pbb', array([6.68728418e-04, 9.99331272e-01])), ('3pbp', array([6.68728418e-04, 9.99331272e-01])), ('3pp', array([0.00584795, 0.99415205])), ('3ppb', array([6.68728418e-04, 9.99331272e-01])), ('3ppbb', array([0.44444444, 0.55555556])), ('3ppbp', array([0.44444444, 0.55555556]))])
# OrderedDict([('0', array([0.94734991, 0.05265009])), ('0b', array([0.9989648, 0.0010352])), ('0bb', array([9.99047619e-01, 9.52380952e-04])), ('0bp', array([9.99047619e-01, 9.52380952e-04])), ('0p', array([0.93451119, 0.06548881])), ('0pb', array([0.99714286, 0.00285714])), ('0pbb', array([9.99454764e-01, 5.45235633e-04])), ('0pbp', array([9.99454764e-01, 5.45235633e-04])), ('0pp', array([0.69064123, 0.30935877])), ('0ppb', array([9.99454764e-01, 5.45235633e-04])), ('0ppbb', array([0.99889226, 0.00110774])), ('0ppbp', array([0.99335355, 0.00664645])), ('1', array([0.94698428, 0.05301572])), ('1b', array([9.99108734e-01, 8.91265597e-04])), ('1bb', array([0.99897331, 0.00102669])), ('1bp', array([0.99281314, 0.00718686])), ('1p', array([0.85515877, 0.14484123])), ('1pb', array([0.99691992, 0.00308008])), ('1pbb', array([9.99461233e-01, 5.38767215e-04])), ('1pbp', array([9.99461233e-01, 5.38767215e-04])), ('1pp', array([0.46317651, 0.53682349])), ('1ppb', array([0.99659151, 0.00340849])), ('1ppbb', array([0.99791556, 0.00208444])), ('1ppbp', array([0.9575128, 0.0424872])), ('2', array([0.98740571, 0.01259429])), ('2b', array([0.73521148, 0.26478852])), ('2bb', array([0.65963163, 0.34036837])), ('2bp', array([0.72078423, 0.27921577])), ('2p', array([0.96478715, 0.03521285])), ('2pb', array([0.69638289, 0.30361711])), ('2pbb', array([0.94877659, 0.05122341])), ('2pbp', array([0.41161229, 0.58838771])), ('2pp', array([0.99417865, 0.00582135])), ('2ppb', array([0.53370843, 0.46629157])), ('2ppbb', array([0.95925395, 0.04074605])), ('2ppbp', array([0.73089782, 0.26910218])), ('3', array([0.80873358, 0.19126642])), ('3b', array([9.94035785e-04, 9.99005964e-01])), ('3bb', array([9.82318271e-04, 9.99017682e-01])), ('3bp', array([9.82318271e-04, 9.99017682e-01])), ('3p', array([0.65732382, 0.34267618])), ('3pb', array([9.82318271e-04, 9.99017682e-01])), ('3pbb', array([5.99080011e-04, 9.99400920e-01])), ('3pbp', array([5.99080011e-04, 9.99400920e-01])), ('3pp', array([9.82318271e-04, 9.99017682e-01])), ('3ppb', array([5.99080011e-04, 9.99400920e-01])), ('3ppbb', array([0.00226837, 0.99773163])), ('3ppbp', array([0.00226837, 0.99773163]))])
# Ejecución 3 completada. Políticas almacenadas.
#
# --- Iniciando Ejecución 4/10 ---
# OrderedDict([('0', array([9.99007937e-01, 9.92063492e-04])), ('0b', array([9.99025341e-01, 9.74658869e-04])), ('0bb', array([0.99899598, 0.00100402])), ('0bp', array([0.99899598, 0.00100402])), ('0p', array([0.93544132, 0.06455868])), ('0pb', array([0.99698795, 0.00301205])), ('0pbb', array([9.99503476e-01, 4.96524330e-04])), ('0pbp', array([0.99851043, 0.00148957])), ('0pp', array([0.99698795, 0.00301205])), ('0ppb', array([9.99503476e-01, 4.96524330e-04])), ('0ppbb', array([9.99479038e-01, 5.20962058e-04])), ('0ppbp', array([9.99479038e-01, 5.20962058e-04])), ('1', array([0.99649022, 0.00350978])), ('1b', array([0.99890351, 0.00109649])), ('1bb', array([9.99021526e-01, 9.78473581e-04])), ('1bp', array([9.99021526e-01, 9.78473581e-04])), ('1p', array([0.49193864, 0.50806136])), ('1pb', array([0.99608611, 0.00391389])), ('1pbb', array([0.99844816, 0.00155184])), ('1pbp', array([0.92287785, 0.07712215])), ('1pp', array([0.58527301, 0.41472699])), ('1ppb', array([0.9856146, 0.0143854])), ('1ppbb', array([0.99777108, 0.00222892])), ('1ppbp', array([0.99777108, 0.00222892])), ('2', array([0.95957585, 0.04042415])), ('2b', array([0.99709302, 0.00290698])), ('2bb', array([9.99015748e-01, 9.84251969e-04])), ('2bp', array([0.1588955, 0.8411045])), ('2p', array([0.98662283, 0.01337717])), ('2pb', array([0.63138748, 0.36861252])), ('2pbb', array([0.95830619, 0.04169381])), ('2pbp', array([0.83636163, 0.16363837])), ('2pp', array([0.96628937, 0.03371063])), ('2ppb', array([0.79857521, 0.20142479])), ('2ppbb', array([9.99508935e-01, 4.91065189e-04])), ('2ppbp', array([0.38516854, 0.61483146])), ('3', array([0.97291036, 0.02708964])), ('3b', array([9.70873786e-04, 9.99029126e-01])), ('3bb', array([0.0010352, 0.9989648])), ('3bp', array([0.0010352, 0.9989648])), ('3p', array([0.0364134, 0.9635866])), ('3pb', array([0.0010352, 0.9989648])), ('3pbb', array([4.99924085e-04, 9.99500076e-01])), ('3pbp', array([4.99924085e-04, 9.99500076e-01])), ('3pp', array([0.0010352, 0.9989648])), ('3ppb', array([4.99924085e-04, 9.99500076e-01])), ('3ppbb', array([0.02666254, 0.97333746])), ('3ppbp', array([0.02666254, 0.97333746]))])
# OrderedDict([('0', array([0.99300285, 0.00699715])), ('0b', array([0.9989858, 0.0010142])), ('0bb', array([0.99709302, 0.00290698])), ('0bp', array([9.99031008e-01, 9.68992248e-04])), ('0p', array([0.98868536, 0.01131464])), ('0pb', array([0.99515504, 0.00484496])), ('0pbb', array([9.99522274e-01, 4.77726024e-04])), ('0pbp', array([0.99874597, 0.00125403])), ('0pp', array([0.68117362, 0.31882638])), ('0ppb', array([9.99522274e-01, 4.77726024e-04])), ('0ppbb', array([9.99487097e-01, 5.12902702e-04])), ('0ppbp', array([9.99487097e-01, 5.12902702e-04])), ('1', array([0.92695645, 0.07304355])), ('1b', array([0.89662614, 0.10337386])), ('1bb', array([0.9989899, 0.0010101])), ('1bp', array([0.94949495, 0.05050505])), ('1p', array([0.49727168, 0.50272832])), ('1pb', array([0.89660184, 0.10339816])), ('1pbb', array([9.99452942e-01, 5.47058484e-04])), ('1pbp', array([0.98542189, 0.01457811])), ('1pp', array([0.83918766, 0.16081234])), ('1ppb', array([0.95564773, 0.04435227])), ('1ppbb', array([9.99033186e-01, 9.66814018e-04])), ('1ppbp', array([9.99033186e-01, 9.66814018e-04])), ('2', array([0.99367096, 0.00632904])), ('2b', array([0.99897119, 0.00102881])), ('2bb', array([0.99894958, 0.00105042])), ('2bp', array([0.31768614, 0.68231386])), ('2p', array([0.96935072, 0.03064928])), ('2pb', array([0.93193778, 0.06806222])), ('2pbb', array([9.99478024e-01, 5.21975803e-04])), ('2pbp', array([0.39315584, 0.60684416])), ('2pp', array([0.97689076, 0.02310924])), ('2ppb', array([0.23428994, 0.76571006])), ('2ppbb', array([0.99628532, 0.00371468])), ('2ppbp', array([0.47853296, 0.52146704])), ('3', array([0.75069044, 0.24930956])), ('3b', array([9.98003992e-04, 9.99001996e-01])), ('3bb', array([9.74658869e-04, 9.99025341e-01])), ('3bp', array([0.00194932, 0.99805068])), ('3p', array([0.00112275, 0.99887725])), ('3pb', array([9.74658869e-04, 9.99025341e-01])), ('3pbb', array([6.68728418e-04, 9.99331272e-01])), ('3pbp', array([6.68728418e-04, 9.99331272e-01])), ('3pp', array([0.00584795, 0.99415205])), ('3ppb', array([6.68728418e-04, 9.99331272e-01])), ('3ppbb', array([0.44444444, 0.55555556])), ('3ppbp', array([0.44444444, 0.55555556]))])
# OrderedDict([('0', array([0.94734991, 0.05265009])), ('0b', array([0.9989648, 0.0010352])), ('0bb', array([9.99047619e-01, 9.52380952e-04])), ('0bp', array([9.99047619e-01, 9.52380952e-04])), ('0p', array([0.93451119, 0.06548881])), ('0pb', array([0.99714286, 0.00285714])), ('0pbb', array([9.99454764e-01, 5.45235633e-04])), ('0pbp', array([9.99454764e-01, 5.45235633e-04])), ('0pp', array([0.69064123, 0.30935877])), ('0ppb', array([9.99454764e-01, 5.45235633e-04])), ('0ppbb', array([0.99889226, 0.00110774])), ('0ppbp', array([0.99335355, 0.00664645])), ('1', array([0.94698428, 0.05301572])), ('1b', array([9.99108734e-01, 8.91265597e-04])), ('1bb', array([0.99897331, 0.00102669])), ('1bp', array([0.99281314, 0.00718686])), ('1p', array([0.85515877, 0.14484123])), ('1pb', array([0.99691992, 0.00308008])), ('1pbb', array([9.99461233e-01, 5.38767215e-04])), ('1pbp', array([9.99461233e-01, 5.38767215e-04])), ('1pp', array([0.46317651, 0.53682349])), ('1ppb', array([0.99659151, 0.00340849])), ('1ppbb', array([0.99791556, 0.00208444])), ('1ppbp', array([0.9575128, 0.0424872])), ('2', array([0.98740571, 0.01259429])), ('2b', array([0.73521148, 0.26478852])), ('2bb', array([0.65963163, 0.34036837])), ('2bp', array([0.72078423, 0.27921577])), ('2p', array([0.96478715, 0.03521285])), ('2pb', array([0.69638289, 0.30361711])), ('2pbb', array([0.94877659, 0.05122341])), ('2pbp', array([0.41161229, 0.58838771])), ('2pp', array([0.99417865, 0.00582135])), ('2ppb', array([0.53370843, 0.46629157])), ('2ppbb', array([0.95925395, 0.04074605])), ('2ppbp', array([0.73089782, 0.26910218])), ('3', array([0.80873358, 0.19126642])), ('3b', array([9.94035785e-04, 9.99005964e-01])), ('3bb', array([9.82318271e-04, 9.99017682e-01])), ('3bp', array([9.82318271e-04, 9.99017682e-01])), ('3p', array([0.65732382, 0.34267618])), ('3pb', array([9.82318271e-04, 9.99017682e-01])), ('3pbb', array([5.99080011e-04, 9.99400920e-01])), ('3pbp', array([5.99080011e-04, 9.99400920e-01])), ('3pp', array([9.82318271e-04, 9.99017682e-01])), ('3ppb', array([5.99080011e-04, 9.99400920e-01])), ('3ppbb', array([0.00226837, 0.99773163])), ('3ppbp', array([0.00226837, 0.99773163]))])
# Ejecución 3 completada. Políticas almacenadas.
#
# --- Iniciando Ejecución 4/10 ---
# OrderedDict([('0', array([0.98964323, 0.01035677])), ('0b', array([0.99809524, 0.00190476])), ('0bb', array([9.99061914e-01, 9.38086304e-04])), ('0bp', array([9.99061914e-01, 9.38086304e-04])), ('0p', array([0.80517893, 0.19482107])), ('0pb', array([9.99061914e-01, 9.38086304e-04])), ('0pbb', array([0.9951231, 0.0048769])), ('0pbp', array([9.99494767e-01, 5.05232577e-04])), ('0pp', array([0.65222777, 0.34777223])), ('0ppb', array([0.99216408, 0.00783592])), ('0ppbb', array([9.99408590e-01, 5.91409507e-04])), ('0ppbp', array([9.99408590e-01, 5.91409507e-04])), ('1', array([0.86335723, 0.13664277])), ('1b', array([0.97795401, 0.02204599])), ('1bb', array([0.9989899, 0.0010101])), ('1bp', array([0.9989899, 0.0010101])), ('1p', array([0.765935, 0.234065])), ('1pb', array([0.9725511, 0.0274489])), ('1pbb', array([0.99601774, 0.00398226])), ('1pbp', array([9.99431106e-01, 5.68894447e-04])), ('1pp', array([0.91169657, 0.08830343])), ('1ppb', array([0.85034615, 0.14965385])), ('1ppbb', array([9.99298068e-01, 7.01932155e-04])), ('1ppbp', array([0.96347732, 0.03652268])), ('2', array([0.99895178, 0.00104822])), ('2b', array([0.56198022, 0.43801978])), ('2bb', array([9.99038462e-01, 9.61538462e-04])), ('2bp', array([0.84372738, 0.15627262])), ('2p', array([9.99015748e-01, 9.84251969e-04])), ('2pb', array([0.58397228, 0.41602772])), ('2pbb', array([0.99737671, 0.00262329])), ('2pbp', array([0.62362144, 0.37637856])), ('2pp', array([0.99807692, 0.00192308])), ('2ppb', array([0.41116577, 0.58883423])), ('2ppbb', array([9.99507389e-01, 4.92610837e-04])), ('2ppbp', array([0.71619377, 0.28380623])), ('3', array([0.91618922, 0.08381078])), ('3b', array([9.96015936e-04, 9.99003984e-01])), ('3bb', array([0.00110619, 0.99889381])), ('3bp', array([0.00110619, 0.99889381])), ('3p', array([0.02100294, 0.97899706])), ('3pb', array([0.00110619, 0.99889381])), ('3pbb', array([5.30874315e-04, 9.99469126e-01])), ('3pbp', array([5.30874315e-04, 9.99469126e-01])), ('3pp', array([0.00110619, 0.99889381])), ('3ppb', array([5.30874315e-04, 9.99469126e-01])), ('3ppbb', array([0.02371134, 0.97628866])), ('3ppbp', array([0.02371134, 0.97628866]))])
# OrderedDict([('0', array([0.9912366, 0.0087634])), ('0b', array([0.99899396, 0.00100604])), ('0bb', array([0.99894958, 0.00105042])), ('0bp', array([0.99894958, 0.00105042])), ('0p', array([0.99081992, 0.00918008])), ('0pb', array([0.99894958, 0.00105042])), ('0pbb', array([9.99487378e-01, 5.12622395e-04])), ('0pbp', array([9.99487378e-01, 5.12622395e-04])), ('0pp', array([0.76532057, 0.23467943])), ('0ppb', array([9.99487378e-01, 5.12622395e-04])), ('0ppbb', array([9.99492321e-01, 5.07678639e-04])), ('0ppbp', array([9.99492321e-01, 5.07678639e-04])), ('1', array([0.91913747, 0.08086253])), ('1b', array([9.99027237e-01, 9.72762646e-04])), ('1bb', array([0.99895397, 0.00104603])), ('1bp', array([0.99686192, 0.00313808])), ('1p', array([0.63812904, 0.36187096])), ('1pb', array([0.99790795, 0.00209205])), ('1pbb', array([9.99465630e-01, 5.34369614e-04])), ('1pbp', array([0.9862655, 0.0137345])), ('1pp', array([0.71854267, 0.28145733])), ('1ppb', array([0.95589493, 0.04410507])), ('1ppbb', array([0.99542681, 0.00457319])), ('1ppbp', array([0.99542681, 0.00457319])), ('2', array([0.96744152, 0.03255848])), ('2b', array([0.63763266, 0.36236734])), ('2bb', array([0.72990401, 0.27009599])), ('2bp', array([0.22673912, 0.77326088])), ('2p', array([0.96078195, 0.03921805])), ('2pb', array([0.84938537, 0.15061463])), ('2pbb', array([0.94856884, 0.05143116])), ('2pbp', array([0.4626166, 0.5373834])), ('2pp', array([0.98677633, 0.01322367])), ('2ppb', array([0.36446902, 0.63553098])), ('2ppbb', array([0.99138247, 0.00861753])), ('2ppbp', array([0.57018727, 0.42981273])), ('3', array([0.79999788, 0.20000212])), ('3b', array([0.00102249, 0.99897751])), ('3bb', array([9.32835821e-04, 9.99067164e-01])), ('3bp', array([9.32835821e-04, 9.99067164e-01])), ('3p', array([0.20238169, 0.79761831])), ('3pb', array([0.00373134, 0.99626866])), ('3pbb', array([5.95239675e-04, 9.99404760e-01])), ('3pbp', array([5.95239675e-04, 9.99404760e-01])), ('3pp', array([0.00373134, 0.99626866])), ('3ppb', array([5.95239675e-04, 9.99404760e-01])), ('3ppbb', array([0.00505231, 0.99494769])), ('3ppbp', array([0.00505231, 0.99494769]))])
# OrderedDict([('0', array([0.94180056, 0.05819944])), ('0b', array([9.99045802e-01, 9.54198473e-04])), ('0bb', array([0.99894958, 0.00105042])), ('0bp', array([0.99894958, 0.00105042])), ('0p', array([0.71660099, 0.28339901])), ('0pb', array([0.9947479, 0.0052521])), ('0pbb', array([9.99457160e-01, 5.42840455e-04])), ('0pbp', array([0.9972858, 0.0027142])), ('0pp', array([0.53686572, 0.46313428])), ('0ppb', array([9.99457160e-01, 5.42840455e-04])), ('0ppbb', array([0.99866844, 0.00133156])), ('0ppbp', array([0.99866844, 0.00133156])), ('1', array([0.9969773, 0.0030227])), ('1b', array([0.9989899, 0.0010101])), ('1bb', array([9.99045802e-01, 9.54198473e-04])), ('1bp', array([0.9980916, 0.0019084])), ('1p', array([0.83372494, 0.16627506])), ('1pb', array([9.99045802e-01, 9.54198473e-04])), ('1pbb', array([9.99525977e-01, 4.74022618e-04])), ('1pbp', array([0.86537953, 0.13462047])), ('1pp', array([0.94173898, 0.05826102])), ('1ppb', array([0.99649018, 0.00350982])), ('1ppbb', array([0.99454802, 0.00545198])), ('1ppbp', array([0.99818267, 0.00181733])), ('2', array([0.97968092, 0.02031908])), ('2b', array([0.89129504, 0.10870496])), ('2bb', array([9.99040307e-01, 9.59692898e-04])), ('2bp', array([0.39323511, 0.60676489])), ('2p', array([0.98841851, 0.01158149])), ('2pb', array([0.97486335, 0.02513665])), ('2pbb', array([9.99453565e-01, 5.46434961e-04])), ('2pbp', array([0.23761005, 0.76238995])), ('2pp', array([0.98278551, 0.01721449])), ('2ppb', array([0.37052117, 0.62947883])), ('2ppbb', array([9.99493128e-01, 5.06872340e-04])), ('2ppbp', array([0.55721161, 0.44278839])), ('3', array([0.83844535, 0.16155465])), ('3b', array([0.00103734, 0.99896266])), ('3bb', array([0.00104384, 0.99895616])), ('3bp', array([0.00208768, 0.99791232])), ('3p', array([0.02843811, 0.97156189])), ('3pb', array([0.00104384, 0.99895616])), ('3pbb', array([5.78972612e-04, 9.99421027e-01])), ('3pbp', array([5.78972612e-04, 9.99421027e-01])), ('3pp', array([0.00835073, 0.99164927])), ('3ppb', array([5.78972612e-04, 9.99421027e-01])), ('3ppbb', array([0.03647726, 0.96352274])), ('3ppbp', array([0.03647726, 0.96352274]))])
# Ejecución 4 completada. Políticas almacenadas.
#
# --- Iniciando Ejecución 5/10 ---
# OrderedDict([('0', array([0.98964323, 0.01035677])), ('0b', array([0.99809524, 0.00190476])), ('0bb', array([9.99061914e-01, 9.38086304e-04])), ('0bp', array([9.99061914e-01, 9.38086304e-04])), ('0p', array([0.80517893, 0.19482107])), ('0pb', array([9.99061914e-01, 9.38086304e-04])), ('0pbb', array([0.9951231, 0.0048769])), ('0pbp', array([9.99494767e-01, 5.05232577e-04])), ('0pp', array([0.65222777, 0.34777223])), ('0ppb', array([0.99216408, 0.00783592])), ('0ppbb', array([9.99408590e-01, 5.91409507e-04])), ('0ppbp', array([9.99408590e-01, 5.91409507e-04])), ('1', array([0.86335723, 0.13664277])), ('1b', array([0.97795401, 0.02204599])), ('1bb', array([0.9989899, 0.0010101])), ('1bp', array([0.9989899, 0.0010101])), ('1p', array([0.765935, 0.234065])), ('1pb', array([0.9725511, 0.0274489])), ('1pbb', array([0.99601774, 0.00398226])), ('1pbp', array([9.99431106e-01, 5.68894447e-04])), ('1pp', array([0.91169657, 0.08830343])), ('1ppb', array([0.85034615, 0.14965385])), ('1ppbb', array([9.99298068e-01, 7.01932155e-04])), ('1ppbp', array([0.96347732, 0.03652268])), ('2', array([0.99895178, 0.00104822])), ('2b', array([0.56198022, 0.43801978])), ('2bb', array([9.99038462e-01, 9.61538462e-04])), ('2bp', array([0.84372738, 0.15627262])), ('2p', array([9.99015748e-01, 9.84251969e-04])), ('2pb', array([0.58397228, 0.41602772])), ('2pbb', array([0.99737671, 0.00262329])), ('2pbp', array([0.62362144, 0.37637856])), ('2pp', array([0.99807692, 0.00192308])), ('2ppb', array([0.41116577, 0.58883423])), ('2ppbb', array([9.99507389e-01, 4.92610837e-04])), ('2ppbp', array([0.71619377, 0.28380623])), ('3', array([0.91618922, 0.08381078])), ('3b', array([9.96015936e-04, 9.99003984e-01])), ('3bb', array([0.00110619, 0.99889381])), ('3bp', array([0.00110619, 0.99889381])), ('3p', array([0.02100294, 0.97899706])), ('3pb', array([0.00110619, 0.99889381])), ('3pbb', array([5.30874315e-04, 9.99469126e-01])), ('3pbp', array([5.30874315e-04, 9.99469126e-01])), ('3pp', array([0.00110619, 0.99889381])), ('3ppb', array([5.30874315e-04, 9.99469126e-01])), ('3ppbb', array([0.02371134, 0.97628866])), ('3ppbp', array([0.02371134, 0.97628866]))])
# ...
# OrderedDict([('0', array([0.99680398, 0.00319602])), ('0b', array([9.99056604e-01, 9.43396226e-04])), ('0bb', array([9.99049430e-01, 9.50570342e-04])), ('0bp', array([9.99049430e-01, 9.50570342e-04])), ('0p', array([0.90471372, 0.09528628])), ('0pb', array([0.99619772, 0.00380228])), ('0pbb', array([9.99524997e-01, 4.75002969e-04])), ('0pbp', array([9.99524997e-01, 4.75002969e-04])), ('0pp', array([0.77084067, 0.22915933])), ('0ppb', array([9.99524997e-01, 4.75002969e-04])), ('0ppbb', array([0.99791449, 0.00208551])), ('0ppbp', array([0.99791449, 0.00208551])), ('1', array([0.87921723, 0.12078277])), ('1b', array([0.97744462, 0.02255538])), ('1bb', array([0.99891304, 0.00108696])), ('1bp', array([0.98741223, 0.01258777])), ('1p', array([0.57546543, 0.42453457])), ('1pb', array([0.99673913, 0.00326087])), ('1pbb', array([9.99408849e-01, 5.91151427e-04])), ('1pbp', array([9.99408849e-01, 5.91151427e-04])), ('1pp', array([0.73791014, 0.26208986])), ('1ppb', array([0.9931312, 0.0068688])), ('1ppbb', array([0.99193839, 0.00806161])), ('1ppbp', array([0.98972662, 0.01027338])), ('2', array([0.9780122, 0.0219878])), ('2b', array([0.7586979, 0.2413021])), ('2bb', array([0.99896907, 0.00103093])), ('2bp', array([0.56004507, 0.43995493])), ('2p', array([0.96813443, 0.03186557])), ('2pb', array([0.93610539, 0.06389461])), ('2pbb', array([9.99516785e-01, 4.83214618e-04])), ('2pbp', array([0.32666549, 0.67333451])), ('2pp', array([0.93707546, 0.06292454])), ('2ppb', array([0.7899456, 0.2100544])), ('2ppbb', array([9.99498585e-01, 5.01414761e-04])), ('2ppbp', array([0.23011433, 0.76988567])), ('3', array([0.86992717, 0.13007283])), ('3b', array([0.00106383, 0.99893617])), ('3bb', array([9.45179584e-04, 9.99054820e-01])), ('3bp', array([0.00189036, 0.99810964])), ('3p', array([0.00319149, 0.99680851])), ('3pb', array([0.0047259, 0.9952741])), ('3pbb', array([6.22035452e-04, 9.99377965e-01])), ('3pbp', array([6.22035452e-04, 9.99377965e-01])), ('3pp', array([0.00378072, 0.99621928])), ('3ppb', array([6.22035452e-04, 9.99377965e-01])), ('3ppbb', array([0.5, 0.5])), ('3ppbp', array([0.5, 0.5]))])
# Ejecución 9 completada. Políticas almacenadas.
#
# --- Iniciando Ejecución 10/10 ---
# OrderedDict([('0', array([0.89398504, 0.10601496])), ('0b', array([0.9989858, 0.0010142])), ('0bb', array([9.99001996e-01, 9.98003992e-04])), ('0bp', array([9.99001996e-01, 9.98003992e-04])), ('0p', array([0.64787952, 0.35212048])), ('0pb', array([9.99001996e-01, 9.98003992e-04])), ('0pbb', array([9.99430455e-01, 5.69545292e-04])), ('0pbp', array([9.99430455e-01, 5.69545292e-04])), ('0pp', array([0.76123098, 0.23876902])), ('0ppb', array([9.99430455e-01, 5.69545292e-04])), ('0ppbb', array([0.99060752, 0.00939248])), ('0ppbp', array([0.99843459, 0.00156541])), ('1', array([0.98789531, 0.01210469])), ('1b', array([0.99608559, 0.00391441])), ('1bb', array([0.99627561, 0.00372439])), ('1bp', array([0.75121637, 0.24878363])), ('1p', array([0.91409652, 0.08590348])), ('1pb', array([0.96804749, 0.03195251])), ('1pbb', array([9.99491841e-01, 5.08159141e-04])), ('1pbp', array([0.98325272, 0.01674728])), ('1pp', array([0.77864967, 0.22135033])), ('1ppb', array([9.99491841e-01, 5.08159141e-04])), ('1ppbb', array([9.99429031e-01, 5.70968884e-04])), ('1ppbp', array([9.99429031e-01, 5.70968884e-04])), ('2', array([0.98727519, 0.01272481])), ('2b', array([0.91957689, 0.08042311])), ('2bb', array([0.9989858, 0.0010142])), ('2bp', array([0.47430293, 0.52569707])), ('2p', array([0.92594002, 0.07405998])), ('2pb', array([0.97489858, 0.02510142])), ('2pbb', array([9.99500548e-01, 4.99452080e-04])), ('2pbp', array([0.30778432, 0.69221568])), ('2pp', array([0.97870183, 0.02129817])), ('2ppb', array([0.08874624, 0.91125376])), ('2ppbb', array([0.99579189, 0.00420811])), ('2ppbp', array([0.71467745, 0.28532255])), ('3', array([0.80443513, 0.19556487])), ('3b', array([9.48766603e-04, 9.99051233e-01])), ('3bb', array([0.0010661, 0.9989339])), ('3bp', array([0.0010661, 0.9989339])), ('3p', array([0.04498756, 0.95501244])), ('3pb', array([0.0010661, 0.9989339])), ('3pbb', array([6.73191939e-04, 9.99326808e-01])), ('3pbp', array([6.16621188e-04, 9.99383379e-01])), ('3pp', array([0.0010661, 0.9989339])), ('3ppb', array([6.16621188e-04, 9.99383379e-01])), ('3ppbb', array([0.10544766, 0.89455234])), ('3ppbp', array([0.10544766, 0.89455234]))])
# OrderedDict([('0', array([0.99647552, 0.00352448])), ('0b', array([9.99038462e-01, 9.61538462e-04])), ('0bb', array([0.99800399, 0.00199601])), ('0bp', array([9.99001996e-01, 9.98003992e-04])), ('0p', array([0.68457105, 0.31542895])), ('0pb', array([0.99500998, 0.00499002])), ('0pbb', array([9.99526634e-01, 4.73366482e-04])), ('0pbp', array([0.9985799, 0.0014201])), ('0pp', array([0.87764506, 0.12235494])), ('0ppb', array([0.9985799, 0.0014201])), ('0ppbb', array([0.99438166, 0.00561834])), ('0ppbp', array([0.99859541, 0.00140459])), ('1', array([0.98329937, 0.01670063])), ('1b', array([0.999, 0.001])), ('1bb', array([0.99808061, 0.00191939])), ('1bp', array([0.99616123, 0.00383877])), ('1p', array([0.87040738, 0.12959262])), ('1pb', array([9.99040307e-01, 9.59692898e-04])), ('1pbb', array([9.99517560e-01, 4.82440361e-04])), ('1pbp', array([0.98003087, 0.01996913])), ('1pp', array([0.68676936, 0.31323064])), ('1ppb', array([9.99517560e-01, 4.82440361e-04])), ('1ppbb', array([0.99770223, 0.00229777])), ('1ppbp', array([0.99770223, 0.00229777])), ('2', array([0.93803563, 0.06196437])), ('2b', array([0.50388544, 0.49611456])), ('2bb', array([0.87423935, 0.12576065])), ('2bp', array([0.99087221, 0.00912779])), ('2p', array([0.9860313, 0.0139687])), ('2pb', array([0.99275922, 0.00724078])), ('2pbb', array([0.99726381, 0.00273619])), ('2pbp', array([0.28307892, 0.71692108])), ('2pp', array([0.9989858, 0.0010142])), ('2ppb', array([0.2555864, 0.7444136])), ('2ppbb', array([0.94998537, 0.05001463])), ('2ppbp', array([0.489021, 0.510979])), ('3', array([0.88857397, 0.11142603])), ('3b', array([0.00102459, 0.99897541])), ('3bb', array([0.00103093, 0.99896907])), ('3bp', array([0.00103093, 0.99896907])), ('3p', array([0.18348316, 0.81651684])), ('3pb', array([0.00103093, 0.99896907])), ('3pbb', array([6.02461839e-04, 9.99397538e-01])), ('3pbp', array([6.02461839e-04, 9.99397538e-01])), ('3pp', array([0.00103093, 0.99896907])), ('3ppb', array([6.02461839e-04, 9.99397538e-01])), ('3ppbb', array([0.00279206, 0.99720794])), ('3ppbp', array([0.00279206, 0.99720794]))])
# OrderedDict([('0', array([0.9563611, 0.0436389])), ('0b', array([0.998998, 0.001002])), ('0bb', array([0.99282787, 0.00717213])), ('0bp', array([0.99487705, 0.00512295])), ('0p', array([0.9924367, 0.0075633])), ('0pb', array([0.99897541, 0.00102459])), ('0pbb', array([9.99457661e-01, 5.42339287e-04])), ('0pbp', array([0.9972883, 0.0027117])), ('0pp', array([0.79751298, 0.20248702])), ('0ppb', array([9.99457661e-01, 5.42339287e-04])), ('0ppbb', array([0.99697108, 0.00302892])), ('0ppbp', array([0.99899036, 0.00100964])), ('1', array([0.9906853, 0.0093147])), ('1b', array([9.99017682e-01, 9.82318271e-04])), ('1bb', array([9.99023438e-01, 9.76562500e-04])), ('1bp', array([0.99511719, 0.00488281])), ('1p', array([0.51968745, 0.48031255])), ('1pb', array([9.99023438e-01, 9.76562500e-04])), ('1pbb', array([9.99496306e-01, 5.03693754e-04])), ('1pbp', array([0.99748153, 0.00251847])), ('1pp', array([0.7417335, 0.2582665])), ('1ppb', array([0.93339064, 0.06660936])), ('1ppbb', array([0.99810979, 0.00189021])), ('1ppbp', array([0.65615935, 0.34384065])), ('2', array([0.97259631, 0.02740369])), ('2b', array([0.96444216, 0.03555784])), ('2bb', array([0.95010538, 0.04989462])), ('2bp', array([0.0799303, 0.9200697])), ('2p', array([0.98628709, 0.01371291])), ('2pb', array([0.42645737, 0.57354263])), ('2pbb', array([9.99495992e-01, 5.04007753e-04])), ('2pbp', array([0.86148704, 0.13851296])), ('2pp', array([0.96694305, 0.03305695])), ('2ppb', array([0.632852, 0.367148])), ('2ppbb', array([0.99830495, 0.00169505])), ('2ppbp', array([0.29358299, 0.70641701])), ('3', array([0.94698451, 0.05301549])), ('3b', array([9.88142292e-04, 9.99011858e-01])), ('3bb', array([0.00617284, 0.99382716])), ('3bp', array([0.00514403, 0.99485597])), ('3p', array([0.09466032, 0.90533968])), ('3pb', array([0.00102881, 0.99897119])), ('3pbb', array([5.20701914e-04, 9.99479298e-01])), ('3pbp', array([5.20701914e-04, 9.99479298e-01])), ('3pp', array([0.00308642, 0.99691358])), ('3ppb', array([5.20701914e-04, 9.99479298e-01])), ('3ppbb', array([0.00521941, 0.99478059])), ('3ppbp', array([0.00521941, 0.99478059]))])
# Ejecución 10 completada. Políticas almacenadas.
# OrderedDict([('0', array([0.89398504, 0.10601496])), ('0b', array([0.9989858, 0.0010142])), ('0bb', array([9.99001996e-01, 9.98003992e-04])), ('0bp', array([9.99001996e-01, 9.98003992e-04])), ('0p', array([0.64787952, 0.35212048])), ('0pb', array([9.99001996e-01, 9.98003992e-04])), ('0pbb', array([9.99430455e-01, 5.69545292e-04])), ('0pbp', array([9.99430455e-01, 5.69545292e-04])), ('0pp', array([0.76123098, 0.23876902])), ('0ppb', array([9.99430455e-01, 5.69545292e-04])), ('0ppbb', array([0.99060752, 0.00939248])), ('0ppbp', array([0.99843459, 0.00156541])), ('1', array([0.98789531, 0.01210469])), ('1b', array([0.99608559, 0.00391441])), ('1bb', array([0.99627561, 0.00372439])), ('1bp', array([0.75121637, 0.24878363])), ('1p', array([0.91409652, 0.08590348])), ('1pb', array([0.96804749, 0.03195251])), ('1pbb', array([9.99491841e-01, 5.08159141e-04])), ('1pbp', array([0.98325272, 0.01674728])), ('1pp', array([0.77864967, 0.22135033])), ('1ppb', array([9.99491841e-01, 5.08159141e-04])), ('1ppbb', array([9.99429031e-01, 5.70968884e-04])), ('1ppbp', array([9.99429031e-01, 5.70968884e-04])), ('2', array([0.98727519, 0.01272481])), ('2b', array([0.91957689, 0.08042311])), ('2bb', array([0.9989858, 0.0010142])), ('2bp', array([0.47430293, 0.52569707])), ('2p', array([0.92594002, 0.07405998])), ('2pb', array([0.97489858, 0.02510142])), ('2pbb', array([9.99500548e-01, 4.99452080e-04])), ('2pbp', array([0.30778432, 0.69221568])), ('2pp', array([0.97870183, 0.02129817])), ('2ppb', array([0.08874624, 0.91125376])), ('2ppbb', array([0.99579189, 0.00420811])), ('2ppbp', array([0.71467745, 0.28532255])), ('3', array([0.80443513, 0.19556487])), ('3b', array([9.48766603e-04, 9.99051233e-01])), ('3bb', array([0.0010661, 0.9989339])), ('3bp', array([0.0010661, 0.9989339])), ('3p', array([0.04498756, 0.95501244])), ('3pb', array([0.0010661, 0.9989339])), ('3pbb', array([6.73191939e-04, 9.99326808e-01])), ('3pbp', array([6.16621188e-04, 9.99383379e-01])), ('3pp', array([0.0010661, 0.9989339])), ('3ppb', array([6.16621188e-04, 9.99383379e-01])), ('3ppbb', array([0.10544766, 0.89455234])), ('3ppbp', array([0.10544766, 0.89455234]))])
# OrderedDict([('0', array([0.99647552, 0.00352448])), ('0b', array([9.99038462e-01, 9.61538462e-04])), ('0bb', array([0.99800399, 0.00199601])), ('0bp', array([9.99001996e-01, 9.98003992e-04])), ('0p', array([0.68457105, 0.31542895])), ('0pb', array([0.99500998, 0.00499002])), ('0pbb', array([9.99526634e-01, 4.73366482e-04])), ('0pbp', array([0.9985799, 0.0014201])), ('0pp', array([0.87764506, 0.12235494])), ('0ppb', array([0.9985799, 0.0014201])), ('0ppbb', array([0.99438166, 0.00561834])), ('0ppbp', array([0.99859541, 0.00140459])), ('1', array([0.98329937, 0.01670063])), ('1b', array([0.999, 0.001])), ('1bb', array([0.99808061, 0.00191939])), ('1bp', array([0.99616123, 0.00383877])), ('1p', array([0.87040738, 0.12959262])), ('1pb', array([9.99040307e-01, 9.59692898e-04])), ('1pbb', array([9.99517560e-01, 4.82440361e-04])), ('1pbp', array([0.98003087, 0.01996913])), ('1pp', array([0.68676936, 0.31323064])), ('1ppb', array([9.99517560e-01, 4.82440361e-04])), ('1ppbb', array([0.99770223, 0.00229777])), ('1ppbp', array([0.99770223, 0.00229777])), ('2', array([0.93803563, 0.06196437])), ('2b', array([0.50388544, 0.49611456])), ('2bb', array([0.87423935, 0.12576065])), ('2bp', array([0.99087221, 0.00912779])), ('2p', array([0.9860313, 0.0139687])), ('2pb', array([0.99275922, 0.00724078])), ('2pbb', array([0.99726381, 0.00273619])), ('2pbp', array([0.28307892, 0.71692108])), ('2pp', array([0.9989858, 0.0010142])), ('2ppb', array([0.2555864, 0.7444136])), ('2ppbb', array([0.94998537, 0.05001463])), ('2ppbp', array([0.489021, 0.510979])), ('3', array([0.88857397, 0.11142603])), ('3b', array([0.00102459, 0.99897541])), ('3bb', array([0.00103093, 0.99896907])), ('3bp', array([0.00103093, 0.99896907])), ('3p', array([0.18348316, 0.81651684])), ('3pb', array([0.00103093, 0.99896907])), ('3pbb', array([6.02461839e-04, 9.99397538e-01])), ('3pbp', array([6.02461839e-04, 9.99397538e-01])), ('3pp', array([0.00103093, 0.99896907])), ('3ppb', array([6.02461839e-04, 9.99397538e-01])), ('3ppbb', array([0.00279206, 0.99720794])), ('3ppbp', array([0.00279206, 0.99720794]))])
# OrderedDict([('0', array([0.9563611, 0.0436389])), ('0b', array([0.998998, 0.001002])), ('0bb', array([0.99282787, 0.00717213])), ('0bp', array([0.99487705, 0.00512295])), ('0p', array([0.9924367, 0.0075633])), ('0pb', array([0.99897541, 0.00102459])), ('0pbb', array([9.99457661e-01, 5.42339287e-04])), ('0pbp', array([0.9972883, 0.0027117])), ('0pp', array([0.79751298, 0.20248702])), ('0ppb', array([9.99457661e-01, 5.42339287e-04])), ('0ppbb', array([0.99697108, 0.00302892])), ('0ppbp', array([0.99899036, 0.00100964])), ('1', array([0.9906853, 0.0093147])), ('1b', array([9.99017682e-01, 9.82318271e-04])), ('1bb', array([9.99023438e-01, 9.76562500e-04])), ('1bp', array([0.99511719, 0.00488281])), ('1p', array([0.51968745, 0.48031255])), ('1pb', array([9.99023438e-01, 9.76562500e-04])), ('1pbb', array([9.99496306e-01, 5.03693754e-04])), ('1pbp', array([0.99748153, 0.00251847])), ('1pp', array([0.7417335, 0.2582665])), ('1ppb', array([0.93339064, 0.06660936])), ('1ppbb', array([0.99810979, 0.00189021])), ('1ppbp', array([0.65615935, 0.34384065])), ('2', array([0.97259631, 0.02740369])), ('2b', array([0.96444216, 0.03555784])), ('2bb', array([0.95010538, 0.04989462])), ('2bp', array([0.0799303, 0.9200697])), ('2p', array([0.98628709, 0.01371291])), ('2pb', array([0.42645737, 0.57354263])), ('2pbb', array([9.99495992e-01, 5.04007753e-04])), ('2pbp', array([0.86148704, 0.13851296])), ('2pp', array([0.96694305, 0.03305695])), ('2ppb', array([0.632852, 0.367148])), ('2ppbb', array([0.99830495, 0.00169505])), ('2ppbp', array([0.29358299, 0.70641701])), ('3', array([0.94698451, 0.05301549])), ('3b', array([9.88142292e-04, 9.99011858e-01])), ('3bb', array([0.00617284, 0.99382716])), ('3bp', array([0.00514403, 0.99485597])), ('3p', array([0.09466032, 0.90533968])), ('3pb', array([0.00102881, 0.99897119])), ('3pbb', array([5.20701914e-04, 9.99479298e-01])), ('3pbp', array([5.20701914e-04, 9.99479298e-01])), ('3pp', array([0.00308642, 0.99691358])), ('3ppb', array([5.20701914e-04, 9.99479298e-01])), ('3ppbb', array([0.00521941, 0.99478059])), ('3ppbp', array([0.00521941, 0.99478059]))])
# Ejecución 10 completada. Políticas almacenadas.

# %% [markdown]
# ### Comparar contra los valores teóricos
#
# Los valores teóricos se calculan solo para los casos en los que existe un valor teórico para el Information Set. Existen casos como '2p' en el que el valor teórico es diferente según si el oponente tiene una Q o una J y por lo tanto no se puede calcular un valor teórico único.

# %%
def get_theoretical_values(alpha):
    """
    Devuelve los valores teóricos de las políticas para el Kuhn Poker dado un alpha.
    """
    return {
        '0': np.array([1 - alpha, alpha]),          # J: Bet alpha
        '1': np.array([1.0, 0.0]),                  # Q: Pass
        '2': np.array([max(0, 1 - 3*alpha), min(1, 3*alpha)]), # K: Bet 3*alpha (con clipping)
        '1pb': np.array([2/3-alpha, alpha+1/3]),                # Q, p-b: Fold (Pass)
        '2pb': np.array([0.0, 1.0]),                 # K, p-b: Call (Bet)
    }

# %%
# Calculate the average policy across all runs
average_policies = {}

for agent_name in g.agents:
    info_sets = all_policies[0][agent_name].keys()
    average_policies[agent_name] = {
        info_set: np.mean([run[agent_name][info_set] for run in all_policies], axis=0)
        for info_set in info_sets
    }

print("\n--- Verificando Políticas Promedio contra Valores Teóricos ---")
all_match = True
tolerance = 0.05

for agent_name, avg_policy in average_policies.items():
    print(f"\nVerificando Agente: {agent_name}")

    # Get alpha from the agent's policy of InfoSet '0', probability of Bet
    alpha = avg_policy['0'][1]
    print(f"  -> Alpha extraído: {alpha:.4f}")
    theoretical_policies = get_theoretical_values(alpha)

    for info_set, avg_actions in avg_policy.items():
        if info_set in theoretical_policies:
            theoretic_actions = theoretical_policies[info_set]
            if np.allclose(avg_actions, theoretic_actions, atol=tolerance):
                print(f"  InfoSet '{info_set}': OK.       Promedio: {np.round(avg_actions, 3)}, Teórico: {np.round(theoretic_actions, 3)}")
            else:
                all_match = False
                print(f"  InfoSet '{info_set}': FALLO.    Promedio: {np.round(avg_actions, 3)}, Teórico: {np.round(theoretic_actions, 3)}")

if all_match:
    print("\n¡Éxito! Todas las políticas promedio coinciden con los valores teóricos dentro de la tolerancia.")
else:
    print("\nAlgunas políticas promedio no coinciden con los valores teóricos.")
# Out:
# --- Verificando Políticas Promedio contra Valores Teóricos ---
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0544
#   InfoSet '0': OK.       Promedio: [0.946 0.054], Teórico: [0.946 0.054]
#   InfoSet '1': FALLO.    Promedio: [0.948 0.052], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Promedio: [0.965 0.035], Teórico: [0.612 0.388]
#   InfoSet '2': FALLO.    Promedio: [0.974 0.026], Teórico: [0.837 0.163]
#   InfoSet '2pb': FALLO.    Promedio: [0.713 0.287], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0207
#   InfoSet '0': OK.       Promedio: [0.979 0.021], Teórico: [0.979 0.021]
#   InfoSet '1': FALLO.    Promedio: [0.921 0.079], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Promedio: [0.988 0.012], Teórico: [0.646 0.354]
#   InfoSet '2': OK.       Promedio: [0.974 0.026], Teórico: [0.938 0.062]
#   InfoSet '2pb': FALLO.    Promedio: [0.849 0.151], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0313
#   InfoSet '0': OK.       Promedio: [0.969 0.031], Teórico: [0.969 0.031]
#   InfoSet '1': OK.       Promedio: [0.958 0.042], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Promedio: [0.971 0.029], Teórico: [0.635 0.365]
#   InfoSet '2': FALLO.    Promedio: [0.975 0.025], Teórico: [0.906 0.094]
#   InfoSet '2pb': FALLO.    Promedio: [0.774 0.226], Teórico: [0. 1.]
#
# Algunas políticas promedio no coinciden con los valores teóricos.

# %%
print("\n--- Verificando Cada Ejecución contra Valores Teóricos ---")
all_match = True
tolerance = 0.05

for i, run_policies in enumerate(all_policies):
    print(f"\nEjecución {i+1}:")
    for agent_name, learned_policy in run_policies.items():
        print(f"\nVerificando Agente: {agent_name}")

        # Get alpha from the agent's policy of InfoSet '0', probability of Bet
        alpha = learned_policy['0'][1]
        print(f"  -> Alpha extraído: {alpha:.4f}")
        theoretical_policies = get_theoretical_values(alpha)

        for info_set, learned_actions in learned_policy.items():
            if info_set in theoretical_policies:
                theoretic_actions = theoretical_policies[info_set]
                if np.allclose(learned_actions, theoretic_actions, atol=tolerance):
                    print(f"  InfoSet '{info_set}': OK.       Aprendido: {np.round(learned_actions, 3)}, Teórico: {np.round(theoretic_actions, 3)}")
                else:
                    all_match = False
                    print(f"  InfoSet '{info_set}': FALLO.    Aprendido: {np.round(learned_actions, 3)}, Teórico: {np.round(theoretic_actions, 3)}")

if all_match:
    print("\n¡Éxito! Todas las políticas aprendidas en cada ejecución coinciden con los valores teóricos dentro de la tolerancia.")
else:
    print("\nAlgunas políticas aprendidas en las ejecuciones no coinciden con los valores teóricos.")
# Out:
# --- Verificando Cada Ejecución contra Valores Teóricos ---
#
# Ejecución 1:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.1005
#   InfoSet '0': OK.       Aprendido: [0.899 0.101], Teórico: [0.899 0.101]
#   InfoSet '1': FALLO.    Aprendido: [0.917 0.083], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.904 0.096], Teórico: [0.566 0.434]
#   InfoSet '2': FALLO.    Aprendido: [0.961 0.039], Teórico: [0.698 0.302]
#   InfoSet '2pb': FALLO.    Aprendido: [0.658 0.342], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0009
#   InfoSet '0': OK.       Aprendido: [0.999 0.001], Teórico: [0.999 0.001]
#   InfoSet '1': FALLO.    Aprendido: [0.817 0.183], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.666 0.334]
#   InfoSet '2': OK.       Aprendido: [0.965 0.035], Teórico: [0.997 0.003]
#   InfoSet '2pb': FALLO.    Aprendido: [0.607 0.393], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0049
#   InfoSet '0': OK.       Aprendido: [0.995 0.005], Teórico: [0.995 0.005]
#   InfoSet '1': OK.       Aprendido: [0.986 0.014], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.997 0.003], Teórico: [0.662 0.338]
#   InfoSet '2': OK.       Aprendido: [0.991 0.009], Teórico: [0.985 0.015]
#   InfoSet '2pb': FALLO.    Aprendido: [0.449 0.551], Teórico: [0. 1.]
#
# Ejecución 2:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0194
#   InfoSet '0': OK.       Aprendido: [0.981 0.019], Teórico: [0.981 0.019]
#   InfoSet '1': FALLO.    Aprendido: [0.936 0.064], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.936 0.064], Teórico: [0.647 0.353]
#   InfoSet '2': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.942 0.058]
#   InfoSet '2pb': FALLO.    Aprendido: [0.672 0.328], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0011
#   InfoSet '0': OK.       Aprendido: [0.999 0.001], Teórico: [0.999 0.001]
#   InfoSet '1': FALLO.    Aprendido: [0.879 0.121], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.993 0.007], Teórico: [0.666 0.334]
#   InfoSet '2': OK.       Aprendido: [0.974 0.026], Teórico: [0.997 0.003]
#   InfoSet '2pb': FALLO.    Aprendido: [0.892 0.108], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0169
#   InfoSet '0': OK.       Aprendido: [0.983 0.017], Teórico: [0.983 0.017]
#   InfoSet '1': FALLO.    Aprendido: [0.927 0.073], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.992 0.008], Teórico: [0.65 0.35]
#   InfoSet '2': OK.       Aprendido: [0.976 0.024], Teórico: [0.949 0.051]
#   InfoSet '2pb': FALLO.    Aprendido: [0.725 0.275], Teórico: [0. 1.]
#
# Ejecución 3:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0010
#   InfoSet '0': OK.       Aprendido: [0.999 0.001], Teórico: [0.999 0.001]
#   InfoSet '1': OK.       Aprendido: [0.996 0.004], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.996 0.004], Teórico: [0.666 0.334]
#   InfoSet '2': OK.       Aprendido: [0.96 0.04], Teórico: [0.997 0.003]
#   InfoSet '2pb': FALLO.    Aprendido: [0.631 0.369], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0070
#   InfoSet '0': OK.       Aprendido: [0.993 0.007], Teórico: [0.993 0.007]
#   InfoSet '1': FALLO.    Aprendido: [0.927 0.073], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.897 0.103], Teórico: [0.66 0.34]
#   InfoSet '2': OK.       Aprendido: [0.994 0.006], Teórico: [0.979 0.021]
#   InfoSet '2pb': FALLO.    Aprendido: [0.932 0.068], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0527
#   InfoSet '0': OK.       Aprendido: [0.947 0.053], Teórico: [0.947 0.053]
#   InfoSet '1': FALLO.    Aprendido: [0.947 0.053], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.997 0.003], Teórico: [0.614 0.386]
#   InfoSet '2': FALLO.    Aprendido: [0.987 0.013], Teórico: [0.842 0.158]
#   InfoSet '2pb': FALLO.    Aprendido: [0.696 0.304], Teórico: [0. 1.]
#
# Ejecución 4:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0104
#   InfoSet '0': OK.       Aprendido: [0.99 0.01], Teórico: [0.99 0.01]
#   InfoSet '1': FALLO.    Aprendido: [0.863 0.137], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.973 0.027], Teórico: [0.656 0.344]
#   InfoSet '2': OK.       Aprendido: [0.999 0.001], Teórico: [0.969 0.031]
#   InfoSet '2pb': FALLO.    Aprendido: [0.584 0.416], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0088
#   InfoSet '0': OK.       Aprendido: [0.991 0.009], Teórico: [0.991 0.009]
#   InfoSet '1': FALLO.    Aprendido: [0.919 0.081], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.998 0.002], Teórico: [0.658 0.342]
#   InfoSet '2': OK.       Aprendido: [0.967 0.033], Teórico: [0.974 0.026]
#   InfoSet '2pb': FALLO.    Aprendido: [0.849 0.151], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0582
#   InfoSet '0': OK.       Aprendido: [0.942 0.058], Teórico: [0.942 0.058]
#   InfoSet '1': OK.       Aprendido: [0.997 0.003], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.608 0.392]
#   InfoSet '2': FALLO.    Aprendido: [0.98 0.02], Teórico: [0.825 0.175]
#   InfoSet '2pb': FALLO.    Aprendido: [0.975 0.025], Teórico: [0. 1.]
#
# Ejecución 5:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0924
#   InfoSet '0': OK.       Aprendido: [0.908 0.092], Teórico: [0.908 0.092]
#   InfoSet '1': OK.       Aprendido: [0.975 0.025], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.981 0.019], Teórico: [0.574 0.426]
#   InfoSet '2': FALLO.    Aprendido: [0.975 0.025], Teórico: [0.723 0.277]
#   InfoSet '2pb': FALLO.    Aprendido: [0.49 0.51], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0141
#   InfoSet '0': OK.       Aprendido: [0.986 0.014], Teórico: [0.986 0.014]
#   InfoSet '1': FALLO.    Aprendido: [0.93 0.07], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.653 0.347]
#   InfoSet '2': OK.       Aprendido: [0.989 0.011], Teórico: [0.958 0.042]
#   InfoSet '2pb': FALLO.    Aprendido: [0.974 0.026], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0258
#   InfoSet '0': OK.       Aprendido: [0.974 0.026], Teórico: [0.974 0.026]
#   InfoSet '1': OK.       Aprendido: [0.96 0.04], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.998 0.002], Teórico: [0.641 0.359]
#   InfoSet '2': FALLO.    Aprendido: [0.986 0.014], Teórico: [0.923 0.077]
#   InfoSet '2pb': FALLO.    Aprendido: [0.919 0.081], Teórico: [0. 1.]
#
# Ejecución 6:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0163
#   InfoSet '0': OK.       Aprendido: [0.984 0.016], Teórico: [0.984 0.016]
#   InfoSet '1': OK.       Aprendido: [0.994 0.006], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.951 0.049], Teórico: [0.65 0.35]
#   InfoSet '2': OK.       Aprendido: [0.946 0.054], Teórico: [0.951 0.049]
#   InfoSet '2pb': FALLO.    Aprendido: [0.95 0.05], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0054
#   InfoSet '0': OK.       Aprendido: [0.995 0.005], Teórico: [0.995 0.005]
#   InfoSet '1': FALLO.    Aprendido: [0.938 0.062], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.661 0.339]
#   InfoSet '2': OK.       Aprendido: [0.989 0.011], Teórico: [0.984 0.016]
#   InfoSet '2pb': FALLO.    Aprendido: [0.979 0.021], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0295
#   InfoSet '0': OK.       Aprendido: [0.97 0.03], Teórico: [0.97 0.03]
#   InfoSet '1': OK.       Aprendido: [0.988 0.012], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.637 0.363]
#   InfoSet '2': OK.       Aprendido: [0.956 0.044], Teórico: [0.911 0.089]
#   InfoSet '2pb': FALLO.    Aprendido: [0.852 0.148], Teórico: [0. 1.]
#
# Ejecución 7:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0034
#   InfoSet '0': OK.       Aprendido: [0.997 0.003], Teórico: [0.997 0.003]
#   InfoSet '1': FALLO.    Aprendido: [0.84 0.16], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.996 0.004], Teórico: [0.663 0.337]
#   InfoSet '2': OK.       Aprendido: [0.948 0.052], Teórico: [0.99 0.01]
#   InfoSet '2pb': FALLO.    Aprendido: [0.79 0.21], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0040
#   InfoSet '0': OK.       Aprendido: [0.996 0.004], Teórico: [0.996 0.004]
#   InfoSet '1': OK.       Aprendido: [0.965 0.035], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.998 0.002], Teórico: [0.663 0.337]
#   InfoSet '2': OK.       Aprendido: [0.989 0.011], Teórico: [0.988 0.012]
#   InfoSet '2pb': FALLO.    Aprendido: [0.832 0.168], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0560
#   InfoSet '0': OK.       Aprendido: [0.944 0.056], Teórico: [0.944 0.056]
#   InfoSet '1': OK.       Aprendido: [0.973 0.027], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.902 0.098], Teórico: [0.611 0.389]
#   InfoSet '2': FALLO.    Aprendido: [0.977 0.023], Teórico: [0.832 0.168]
#   InfoSet '2pb': FALLO.    Aprendido: [0.912 0.088], Teórico: [0. 1.]
#
# Ejecución 8:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.1570
#   InfoSet '0': OK.       Aprendido: [0.843 0.157], Teórico: [0.843 0.157]
#   InfoSet '1': OK.       Aprendido: [0.983 0.017], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.952 0.048], Teórico: [0.51 0.49]
#   InfoSet '2': FALLO.    Aprendido: [0.985 0.015], Teórico: [0.529 0.471]
#   InfoSet '2pb': FALLO.    Aprendido: [0.419 0.581], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0879
#   InfoSet '0': OK.       Aprendido: [0.912 0.088], Teórico: [0.912 0.088]
#   InfoSet '1': OK.       Aprendido: [0.953 0.047], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.998 0.002], Teórico: [0.579 0.421]
#   InfoSet '2': FALLO.    Aprendido: [0.94 0.06], Teórico: [0.736 0.264]
#   InfoSet '2pb': FALLO.    Aprendido: [0.679 0.321], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0221
#   InfoSet '0': OK.       Aprendido: [0.978 0.022], Teórico: [0.978 0.022]
#   InfoSet '1': FALLO.    Aprendido: [0.934 0.066], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.833 0.167], Teórico: [0.645 0.355]
#   InfoSet '2': OK.       Aprendido: [0.949 0.051], Teórico: [0.934 0.066]
#   InfoSet '2pb': FALLO.    Aprendido: [0.845 0.155], Teórico: [0. 1.]
#
# Ejecución 9:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0380
#   InfoSet '0': OK.       Aprendido: [0.962 0.038], Teórico: [0.962 0.038]
#   InfoSet '1': OK.       Aprendido: [0.988 0.012], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.629 0.371]
#   InfoSet '2': FALLO.    Aprendido: [0.982 0.018], Teórico: [0.886 0.114]
#   InfoSet '2pb': FALLO.    Aprendido: [0.965 0.035], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0743
#   InfoSet '0': OK.       Aprendido: [0.926 0.074], Teórico: [0.926 0.074]
#   InfoSet '1': FALLO.    Aprendido: [0.896 0.104], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.998 0.002], Teórico: [0.592 0.408]
#   InfoSet '2': FALLO.    Aprendido: [0.996 0.004], Teórico: [0.777 0.223]
#   InfoSet '2pb': FALLO.    Aprendido: [0.749 0.251], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0032
#   InfoSet '0': OK.       Aprendido: [0.997 0.003], Teórico: [0.997 0.003]
#   InfoSet '1': FALLO.    Aprendido: [0.879 0.121], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.997 0.003], Teórico: [0.663 0.337]
#   InfoSet '2': OK.       Aprendido: [0.978 0.022], Teórico: [0.99 0.01]
#   InfoSet '2pb': FALLO.    Aprendido: [0.936 0.064], Teórico: [0. 1.]
#
# Ejecución 10:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.1060
#   InfoSet '0': OK.       Aprendido: [0.894 0.106], Teórico: [0.894 0.106]
#   InfoSet '1': OK.       Aprendido: [0.988 0.012], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.968 0.032], Teórico: [0.561 0.439]
#   InfoSet '2': FALLO.    Aprendido: [0.987 0.013], Teórico: [0.682 0.318]
#   InfoSet '2pb': FALLO.    Aprendido: [0.975 0.025], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0035
#   InfoSet '0': OK.       Aprendido: [0.996 0.004], Teórico: [0.996 0.004]
#   InfoSet '1': OK.       Aprendido: [0.983 0.017], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.663 0.337]
#   InfoSet '2': FALLO.    Aprendido: [0.938 0.062], Teórico: [0.989 0.011]
#   InfoSet '2pb': FALLO.    Aprendido: [0.993 0.007], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0436
#   InfoSet '0': OK.       Aprendido: [0.956 0.044], Teórico: [0.956 0.044]
#   InfoSet '1': OK.       Aprendido: [0.991 0.009], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.623 0.377]
#   InfoSet '2': FALLO.    Aprendido: [0.973 0.027], Teórico: [0.869 0.131]
#   InfoSet '2pb': FALLO.    Aprendido: [0.426 0.574], Teórico: [0. 1.]
#
# Algunas políticas aprendidas en las ejecuciones no coinciden con los valores teóricos.

# %%
# Define the theoretical policies (adjust alpha dynamically if needed)
alpha = 1/3  # Replace with dynamically calculated alpha if required
theoretical_policies = {
    'agent_0': {
        '0': np.array([1 - alpha, alpha]),          # J: Bet alpha
        '1': np.array([1.0, 0.0]),                  # Q: Pass
        '2': np.array([1 - 3*alpha, 3*alpha]),      # K: Bet 3*alpha
        '1pb': np.array([1.0, 0.0]),                # Q, p-b: Fold
        '2pb': np.array([0.0, 1.0])                 # K, p-b: Call
    },
    'agent_1': {
        '0': np.array([1 - alpha, alpha]),          # J: Bet alpha
        '1': np.array([1.0, 0.0]),                  # Q: Pass
        '2': np.array([1 - 3*alpha, 3*alpha]),      # K: Bet 3*alpha
        '1pb': np.array([1.0, 0.0]),                # Q, p-b: Fold
        '2pb': np.array([0.0, 1.0])                 # K, p-b: Call
    }
}

# Create plots for each agent
for agent_name, theoretical_policy in theoretical_policies.items():
    info_sets = list(theoretical_policy.keys())
    num_info_sets = len(info_sets)
    nrows = 2
    ncols = (num_info_sets + 1) // 2  # Ensure all info sets fit into 2 rows
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5 * ncols, 5 * nrows), sharey=True)
    fig.suptitle(f"Comparison for {agent_name}", fontsize=16)

    # Flatten axes for easier indexing
    axes = axes.flatten()

    for idx, info_set in enumerate(info_sets):
        ax = axes[idx]
        theoretic_actions = theoretical_policy[info_set]
        learned_values = [run[agent_name][info_set] for run in all_policies if info_set in run[agent_name]]

        if not learned_values:
            ax.set_title(f"InfoSet: {info_set}")
            ax.text(0.5, 0.5, "No Data", horizontalalignment='center', verticalalignment='center', fontsize=12)
            ax.axis('off')
            continue

        x = np.arange(len(learned_values))
        width = 0.35

        # Plot learned values
        for action_idx, action_name in enumerate(['Pass', 'Bet']):
            ax.bar(x + width * action_idx, [values[action_idx] for values in learned_values], width, label=f'Learned {action_name}')

        # Plot theoretical values
        colors = ['r', 'g']
        for action_idx, action_name in enumerate(['Pass', 'Bet']):
            ax.axhline(y=theoretic_actions[action_idx], color=colors[action_idx], linestyle='--', label=f'Theoretical {action_name}')

        # Add labels and legend
        ax.set_title(f"InfoSet: {info_set}")
        ax.set_xlabel("Training Session")
        ax.set_ylabel("Probability")
        ax.set_xticks(x + width / 2)
        ax.set_xticklabels([f"Run {i+1}" for i in range(len(learned_values))])
        ax.legend()
        ax.grid(axis='y', linestyle='--', alpha=0.7)

    # Hide unused subplots
    for idx in range(len(info_sets), len(axes)):
        axes[idx].axis('off')

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %% [markdown]
# ## Análisis del entrenamiento

# %%
g = KuhnPoker3(initial_player=0) 
agent_classes = [CounterFactualRegret, CounterFactualRegret, CounterFactualRegret]
my_agents = {}
g.reset()
for i, agent in enumerate(g.agents):
    my_agents[agent] = agent_classes[i](
        game=g, 
        agent=agent, 
        track_frequency=1,
        seed=42,
    )

# %%
for agent in g.agents:
    print('Training agent ' + agent)
    my_agents[agent].train(10000)
    print('Agent ' + agent + ' policies:')
    print(OrderedDict(map(lambda n: (n, my_agents[agent].node_dict[n].policy()), sorted(my_agents[agent].node_dict.keys()))))
    print('')
# Out:
# Training agent agent_0
# Agent agent_0 policies:
# OrderedDict([('0', array([0.97026317, 0.02973683])), ('0b', array([9.99802839e-01, 1.97160883e-04])), ('0bb', array([9.99803227e-01, 1.96772924e-04])), ('0bp', array([9.99409681e-01, 5.90318772e-04])), ('0p', array([0.79871966, 0.20128034])), ('0pb', array([9.99803227e-01, 1.96772924e-04])), ('0pbb', array([9.99898438e-01, 1.01561708e-04])), ('0pbp', array([9.99898438e-01, 1.01561708e-04])), ('0pp', array([0.73743138, 0.26256862])), ('0ppb', array([9.99898438e-01, 1.01561708e-04])), ('0ppbb', array([9.99629731e-01, 3.70269246e-04])), ('0ppbp', array([9.99148694e-01, 8.51305645e-04])), ('1', array([0.92507138, 0.07492862])), ('1b', array([0.9964927, 0.0035073])), ('1bb', array([9.99797653e-01, 2.02347228e-04])), ('1bp', array([0.94988805, 0.05011195])), ('1p', array([0.96914632, 0.03085368])), ('1pb', array([9.99797653e-01, 2.02347228e-04])), ('1pbb', array([9.99890187e-01, 1.09812846e-04])), ('1pbp', array([0.94499933, 0.05500067])), ('1pp', array([0.73747765, 0.26252235])), ('1ppb', array([0.88084605, 0.11915395])), ('1ppbb', array([9.99590704e-01, 4.09296284e-04])), ('1ppbp', array([9.99590704e-01, 4.09296284e-04])), ('2', array([0.99798495, 0.00201505])), ('2b', array([0.96958163, 0.03041837])), ('2bb', array([0.90600959, 0.09399041])), ('2bp', array([0.50867768, 0.49132232])), ('2p', array([0.99897792, 0.00102208])), ('2pb', array([0.96529385, 0.03470615])), ('2pbb', array([0.9980544, 0.0019456])), ('2pbp', array([0.37638622, 0.62361378])), ('2pp', array([0.99881797, 0.00118203])), ('2ppb', array([0.4912263, 0.5087737])), ('2ppbb', array([0.99785144, 0.00214856])), ('2ppbp', array([0.73440701, 0.26559299])), ('3', array([0.82747311, 0.17252689])), ('3b', array([2.00240288e-04, 9.99799760e-01])), ('3bb', array([2.04081633e-04, 9.99795918e-01])), ('3bp', array([2.04081633e-04, 9.99795918e-01])), ('3p', array([0.54556754, 0.45443246])), ('3pb', array([2.04081633e-04, 9.99795918e-01])), ('3pbb', array([1.20176858e-04, 9.99879823e-01])), ('3pbp', array([1.20176858e-04, 9.99879823e-01])), ('3pp', array([2.04081633e-04, 9.99795918e-01])), ('3ppb', array([1.20176858e-04, 9.99879823e-01])), ('3ppbb', array([0.00204492, 0.99795508])), ('3ppbp', array([5.50546739e-04, 9.99449453e-01]))])
#
# Training agent agent_1
# Agent agent_0 policies:
# OrderedDict([('0', array([0.97026317, 0.02973683])), ('0b', array([9.99802839e-01, 1.97160883e-04])), ('0bb', array([9.99803227e-01, 1.96772924e-04])), ('0bp', array([9.99409681e-01, 5.90318772e-04])), ('0p', array([0.79871966, 0.20128034])), ('0pb', array([9.99803227e-01, 1.96772924e-04])), ('0pbb', array([9.99898438e-01, 1.01561708e-04])), ('0pbp', array([9.99898438e-01, 1.01561708e-04])), ('0pp', array([0.73743138, 0.26256862])), ('0ppb', array([9.99898438e-01, 1.01561708e-04])), ('0ppbb', array([9.99629731e-01, 3.70269246e-04])), ('0ppbp', array([9.99148694e-01, 8.51305645e-04])), ('1', array([0.92507138, 0.07492862])), ('1b', array([0.9964927, 0.0035073])), ('1bb', array([9.99797653e-01, 2.02347228e-04])), ('1bp', array([0.94988805, 0.05011195])), ('1p', array([0.96914632, 0.03085368])), ('1pb', array([9.99797653e-01, 2.02347228e-04])), ('1pbb', array([9.99890187e-01, 1.09812846e-04])), ('1pbp', array([0.94499933, 0.05500067])), ('1pp', array([0.73747765, 0.26252235])), ('1ppb', array([0.88084605, 0.11915395])), ('1ppbb', array([9.99590704e-01, 4.09296284e-04])), ('1ppbp', array([9.99590704e-01, 4.09296284e-04])), ('2', array([0.99798495, 0.00201505])), ('2b', array([0.96958163, 0.03041837])), ('2bb', array([0.90600959, 0.09399041])), ('2bp', array([0.50867768, 0.49132232])), ('2p', array([0.99897792, 0.00102208])), ('2pb', array([0.96529385, 0.03470615])), ('2pbb', array([0.9980544, 0.0019456])), ('2pbp', array([0.37638622, 0.62361378])), ('2pp', array([0.99881797, 0.00118203])), ('2ppb', array([0.4912263, 0.5087737])), ('2ppbb', array([0.99785144, 0.00214856])), ('2ppbp', array([0.73440701, 0.26559299])), ('3', array([0.82747311, 0.17252689])), ('3b', array([2.00240288e-04, 9.99799760e-01])), ('3bb', array([2.04081633e-04, 9.99795918e-01])), ('3bp', array([2.04081633e-04, 9.99795918e-01])), ('3p', array([0.54556754, 0.45443246])), ('3pb', array([2.04081633e-04, 9.99795918e-01])), ('3pbb', array([1.20176858e-04, 9.99879823e-01])), ('3pbp', array([1.20176858e-04, 9.99879823e-01])), ('3pp', array([2.04081633e-04, 9.99795918e-01])), ('3ppb', array([1.20176858e-04, 9.99879823e-01])), ('3ppbb', array([0.00204492, 0.99795508])), ('3ppbp', array([5.50546739e-04, 9.99449453e-01]))])
#
# Training agent agent_1
# Agent agent_1 policies:
# OrderedDict([('0', array([0.99360635, 0.00639365])), ('0b', array([9.99792703e-01, 2.07296849e-04])), ('0bb', array([9.99799679e-01, 2.00320513e-04])), ('0bp', array([9.99198718e-01, 8.01282051e-04])), ('0p', array([0.78091428, 0.21908572])), ('0pb', array([9.99799679e-01, 2.00320513e-04])), ('0pbb', array([9.99899155e-01, 1.00845170e-04])), ('0pbp', array([9.99899155e-01, 1.00845170e-04])), ('0pp', array([0.5012705, 0.4987295])), ('0ppb', array([9.99899155e-01, 1.00845170e-04])), ('0ppbb', array([9.99867273e-01, 1.32727020e-04])), ('0ppbp', array([9.99867273e-01, 1.32727020e-04])), ('1', array([9.99794998e-01, 2.05002050e-04])), ('1b', array([9.99799358e-01, 2.00642055e-04])), ('1bb', array([9.99799438e-01, 2.00561572e-04])), ('1bp', array([0.99501124, 0.00498876])), ('1p', array([0.9060502, 0.0939498])), ('1pb', array([9.99398315e-01, 6.01684717e-04])), ('1pbb', array([9.99897478e-01, 1.02522042e-04])), ('1pbp', array([0.99809309, 0.00190691])), ('1pp', array([0.95403991, 0.04596009])), ('1ppb', array([0.97893072, 0.02106928])), ('1ppbb', array([9.99054630e-01, 9.45370132e-04])), ('1ppbp', array([0.99519078, 0.00480922])), ('2', array([0.98752986, 0.01247014])), ('2b', array([0.37772382, 0.62227618])), ('2bb', array([0.21096989, 0.78903011])), ('2bp', array([0.82050906, 0.17949094])), ('2p', array([0.98601902, 0.01398098])), ('2pb', array([0.77981975, 0.22018025])), ('2pbb', array([9.99899060e-01, 1.00939754e-04])), ('2pbp', array([0.61939703, 0.38060297])), ('2pp', array([0.99575329, 0.00424671])), ('2ppb', array([0.95464256, 0.04535744])), ('2ppbb', array([0.99818636, 0.00181364])), ('2ppbp', array([0.30987157, 0.69012843])), ('3', array([0.98344629, 0.01655371])), ('3b', array([3.94788788e-04, 9.99605211e-01])), ('3bb', array([0.397578, 0.602422])), ('3bp', array([2.05254516e-04, 9.99794745e-01])), ('3p', array([0.33665618, 0.66334382])), ('3pb', array([4.10509031e-04, 9.99589491e-01])), ('3pbb', array([9.93776724e-05, 9.99900622e-01])), ('3pbp', array([9.93776724e-05, 9.99900622e-01])), ('3pp', array([4.10509031e-04, 9.99589491e-01])), ('3ppb', array([9.93776724e-05, 9.99900622e-01])), ('3ppbb', array([8.20861176e-04, 9.99179139e-01])), ('3ppbp', array([2.93169124e-04, 9.99706831e-01]))])
#
# Training agent agent_2
# Agent agent_1 policies:
# OrderedDict([('0', array([0.99360635, 0.00639365])), ('0b', array([9.99792703e-01, 2.07296849e-04])), ('0bb', array([9.99799679e-01, 2.00320513e-04])), ('0bp', array([9.99198718e-01, 8.01282051e-04])), ('0p', array([0.78091428, 0.21908572])), ('0pb', array([9.99799679e-01, 2.00320513e-04])), ('0pbb', array([9.99899155e-01, 1.00845170e-04])), ('0pbp', array([9.99899155e-01, 1.00845170e-04])), ('0pp', array([0.5012705, 0.4987295])), ('0ppb', array([9.99899155e-01, 1.00845170e-04])), ('0ppbb', array([9.99867273e-01, 1.32727020e-04])), ('0ppbp', array([9.99867273e-01, 1.32727020e-04])), ('1', array([9.99794998e-01, 2.05002050e-04])), ('1b', array([9.99799358e-01, 2.00642055e-04])), ('1bb', array([9.99799438e-01, 2.00561572e-04])), ('1bp', array([0.99501124, 0.00498876])), ('1p', array([0.9060502, 0.0939498])), ('1pb', array([9.99398315e-01, 6.01684717e-04])), ('1pbb', array([9.99897478e-01, 1.02522042e-04])), ('1pbp', array([0.99809309, 0.00190691])), ('1pp', array([0.95403991, 0.04596009])), ('1ppb', array([0.97893072, 0.02106928])), ('1ppbb', array([9.99054630e-01, 9.45370132e-04])), ('1ppbp', array([0.99519078, 0.00480922])), ('2', array([0.98752986, 0.01247014])), ('2b', array([0.37772382, 0.62227618])), ('2bb', array([0.21096989, 0.78903011])), ('2bp', array([0.82050906, 0.17949094])), ('2p', array([0.98601902, 0.01398098])), ('2pb', array([0.77981975, 0.22018025])), ('2pbb', array([9.99899060e-01, 1.00939754e-04])), ('2pbp', array([0.61939703, 0.38060297])), ('2pp', array([0.99575329, 0.00424671])), ('2ppb', array([0.95464256, 0.04535744])), ('2ppbb', array([0.99818636, 0.00181364])), ('2ppbp', array([0.30987157, 0.69012843])), ('3', array([0.98344629, 0.01655371])), ('3b', array([3.94788788e-04, 9.99605211e-01])), ('3bb', array([0.397578, 0.602422])), ('3bp', array([2.05254516e-04, 9.99794745e-01])), ('3p', array([0.33665618, 0.66334382])), ('3pb', array([4.10509031e-04, 9.99589491e-01])), ('3pbb', array([9.93776724e-05, 9.99900622e-01])), ('3pbp', array([9.93776724e-05, 9.99900622e-01])), ('3pp', array([4.10509031e-04, 9.99589491e-01])), ('3ppb', array([9.93776724e-05, 9.99900622e-01])), ('3ppbb', array([8.20861176e-04, 9.99179139e-01])), ('3ppbp', array([2.93169124e-04, 9.99706831e-01]))])
#
# Training agent agent_2
# Agent agent_2 policies:
# OrderedDict([('0', array([9.99797489e-01, 2.02511138e-04])), ('0b', array([9.99796500e-01, 2.03500204e-04])), ('0bb', array([0.9988554, 0.0011446])), ('0bp', array([9.99809233e-01, 1.90766883e-04])), ('0p', array([0.94031804, 0.05968196])), ('0pb', array([9.99809233e-01, 1.90766883e-04])), ('0pbb', array([9.99898724e-01, 1.01276079e-04])), ('0pbp', array([9.99898724e-01, 1.01276079e-04])), ('0pp', array([0.77163453, 0.22836547])), ('0ppb', array([9.99898724e-01, 1.01276079e-04])), ('0ppbb', array([9.99783584e-01, 2.16416356e-04])), ('0ppbp', array([9.99134335e-01, 8.65665425e-04])), ('1', array([0.97190732, 0.02809268])), ('1b', array([0.99864947, 0.00135053])), ('1bb', array([0.99720112, 0.00279888])), ('1bp', array([0.99454666, 0.00545334])), ('1p', array([0.66546446, 0.33453554])), ('1pb', array([9.99800080e-01, 1.99920032e-04])), ('1pbb', array([9.99896488e-01, 1.03511538e-04])), ('1pbp', array([9.99258167e-01, 7.41832690e-04])), ('1pp', array([0.80063102, 0.19936898])), ('1ppb', array([9.99882953e-01, 1.17047077e-04])), ('1ppbb', array([9.99850208e-01, 1.49791651e-04])), ('1ppbp', array([0.98715909, 0.01284091])), ('2', array([0.99792908, 0.00207092])), ('2b', array([0.37034186, 0.62965814])), ('2bb', array([9.99592003e-01, 4.07996736e-04])), ('2bp', array([0.79113425, 0.20886575])), ('2p', array([0.99875431, 0.00124569])), ('2pb', array([0.78735392, 0.21264608])), ('2pbb', array([9.99898780e-01, 1.01219719e-04])), ('2pbp', array([0.66954031, 0.33045969])), ('2pp', array([0.99615481, 0.00384519])), ('2ppb', array([0.60038543, 0.39961457])), ('2ppbb', array([0.99889667, 0.00110333])), ('2ppbp', array([0.41364511, 0.58635489])), ('3', array([0.95352614, 0.04647386])), ('3b', array([2.06100577e-04, 9.99793899e-01])), ('3bb', array([2.06015657e-04, 9.99793984e-01])), ('3bp', array([2.06015657e-04, 9.99793984e-01])), ('3p', array([0.13872491, 0.86127509])), ('3pb', array([2.06015657e-04, 9.99793984e-01])), ('3pbb', array([1.01977727e-04, 9.99898022e-01])), ('3pbp', array([1.01977727e-04, 9.99898022e-01])), ('3pp', array([2.06015657e-04, 9.99793984e-01])), ('3ppb', array([1.01977727e-04, 9.99898022e-01])), ('3ppbb', array([7.42839083e-04, 9.99257161e-01])), ('3ppbp', array([7.42839083e-04, 9.99257161e-01]))])
#
# Agent agent_2 policies:
# OrderedDict([('0', array([9.99797489e-01, 2.02511138e-04])), ('0b', array([9.99796500e-01, 2.03500204e-04])), ('0bb', array([0.9988554, 0.0011446])), ('0bp', array([9.99809233e-01, 1.90766883e-04])), ('0p', array([0.94031804, 0.05968196])), ('0pb', array([9.99809233e-01, 1.90766883e-04])), ('0pbb', array([9.99898724e-01, 1.01276079e-04])), ('0pbp', array([9.99898724e-01, 1.01276079e-04])), ('0pp', array([0.77163453, 0.22836547])), ('0ppb', array([9.99898724e-01, 1.01276079e-04])), ('0ppbb', array([9.99783584e-01, 2.16416356e-04])), ('0ppbp', array([9.99134335e-01, 8.65665425e-04])), ('1', array([0.97190732, 0.02809268])), ('1b', array([0.99864947, 0.00135053])), ('1bb', array([0.99720112, 0.00279888])), ('1bp', array([0.99454666, 0.00545334])), ('1p', array([0.66546446, 0.33453554])), ('1pb', array([9.99800080e-01, 1.99920032e-04])), ('1pbb', array([9.99896488e-01, 1.03511538e-04])), ('1pbp', array([9.99258167e-01, 7.41832690e-04])), ('1pp', array([0.80063102, 0.19936898])), ('1ppb', array([9.99882953e-01, 1.17047077e-04])), ('1ppbb', array([9.99850208e-01, 1.49791651e-04])), ('1ppbp', array([0.98715909, 0.01284091])), ('2', array([0.99792908, 0.00207092])), ('2b', array([0.37034186, 0.62965814])), ('2bb', array([9.99592003e-01, 4.07996736e-04])), ('2bp', array([0.79113425, 0.20886575])), ('2p', array([0.99875431, 0.00124569])), ('2pb', array([0.78735392, 0.21264608])), ('2pbb', array([9.99898780e-01, 1.01219719e-04])), ('2pbp', array([0.66954031, 0.33045969])), ('2pp', array([0.99615481, 0.00384519])), ('2ppb', array([0.60038543, 0.39961457])), ('2ppbb', array([0.99889667, 0.00110333])), ('2ppbp', array([0.41364511, 0.58635489])), ('3', array([0.95352614, 0.04647386])), ('3b', array([2.06100577e-04, 9.99793899e-01])), ('3bb', array([2.06015657e-04, 9.99793984e-01])), ('3bp', array([2.06015657e-04, 9.99793984e-01])), ('3p', array([0.13872491, 0.86127509])), ('3pb', array([2.06015657e-04, 9.99793984e-01])), ('3pbb', array([1.01977727e-04, 9.99898022e-01])), ('3pbp', array([1.01977727e-04, 9.99898022e-01])), ('3pp', array([2.06015657e-04, 9.99793984e-01])), ('3ppb', array([1.01977727e-04, 9.99898022e-01])), ('3ppbb', array([7.42839083e-04, 9.99257161e-01])), ('3ppbp', array([7.42839083e-04, 9.99257161e-01]))])

# %% [markdown]
# ### Evolución de la política durante el entrenamiento

# %% [markdown]
# **Agente 0**

# %%
theoretical_JX_bet = 1/3

strategy_history = my_agents['agent_0'].strategy_history
iteration_history = my_agents['agent_0'].iteration_history

plot_strategy_evolution(strategy_history, iteration_history, 
                        action_names={0: 'Pass', 1: 'Bet'})

plot_convergence_analysis(strategy_history, iteration_history, info_set_key='0', 
                          action_names={0: 'Pass', 1: 'Bet'}, 
                          theoretical_values={0: 1 - theoretical_JX_bet, 1: theoretical_JX_bet},
                          figsize=(12, 6))
# Out:
# c:\Users\marrt\Documents\sistemas-multiagente\Alternating Games\plot_utils.py:56: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# **Agente 1**

# %%
theoretical_JX_bet = 1/3

strategy_history = my_agents['agent_1'].strategy_history
iteration_history = my_agents['agent_1'].iteration_history

plot_strategy_evolution(strategy_history, iteration_history, 
                        action_names={0: 'Pass', 1: 'Bet'})

plot_convergence_analysis(strategy_history, iteration_history, info_set_key='0', 
                          action_names={0: 'Pass', 1: 'Bet'}, 
                          theoretical_values={0: 1 - theoretical_JX_bet, 1: theoretical_JX_bet},
                          figsize=(12, 6))

# %% [markdown]
# ### Ejecutar partidas CFR vs CFR

# %%
cum_rewards = dict(map(lambda agent: (agent, 0.), g.agents))
niter = 20000
for _ in range(niter):
    g.reset()
    turn = 0
    while not g.done():
        # print('Turn: ', turn)
        # print('\tPlayer: ', g.agent_selection)
        # print('\tObservation: ', g.observe(g.agent_selection))
        a = my_agents[g.agent_selection].action()
        # print('\tAction: ', g._moves[a])
        g.step(action=a)
        turn += 1
    #print('Rewards: ', g.rewards)
    for agent in g.agents:
        cum_rewards[agent] += g.rewards[agent]
print('Average rewards:', dict(map(lambda agent: (agent, cum_rewards[agent]/niter), g.agents)))
print('Teoretical rewards: ', {g.agents[0]: np.round(-1/18, 3), g.agents[1]: np.round(1/18, 3), g.agents[2]: 0})
# Out:
# Average rewards: {'agent_0': np.float64(-0.05785), 'agent_1': np.float64(-0.0041), 'agent_2': np.float64(0.06195)}
# Teoretical rewards:  {'agent_0': np.float64(-0.056), 'agent_1': np.float64(0.056), 'agent_2': 0}
