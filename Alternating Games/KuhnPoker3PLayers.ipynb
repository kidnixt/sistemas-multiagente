# %% [markdown]
# # Khun Poker - 3 Jugadores

# %% [markdown]
# ## Imports

# %%
from games.kuhn.kuhn3 import KuhnPoker3
from agents.counterfactual_regret import CounterFactualRegret
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt

from plot_utils import plot_strategy_evolution, plot_convergence_analysis

# %% [markdown]
# ## Chequear la política aprendida

# %% [markdown]
# ### Entrenar 10 veces

# %%
num_runs = 10
training_iterations = 2000
all_policies = []

print(f"Ejecutando {num_runs} sesiones de entrenamiento de {training_iterations} iteraciones cada una...")

for i in range(num_runs):
    print(f"\n--- Iniciando Ejecución {i+1}/{num_runs} ---")
    # Reinicializar el juego y los agentes para una ejecución limpia
    g = KuhnPoker3(initial_player=0)  # Semilla fija para el juego para reproducibilidad
    agent_classes = [CounterFactualRegret, CounterFactualRegret, CounterFactualRegret]
    my_agents = {}
    g.reset()
    for agent_id, agent_name in enumerate(g.agents):
        my_agents[agent_name] = agent_classes[agent_id](
            game=g, 
            agent=agent_name, 
            seed=24  # Usar una semilla diferente para el agente en cada ejecución
        )

    # Entrenar agentes
    for agent_name in g.agents:
        my_agents[agent_name].train(training_iterations)

    # Almacenar las políticas de esta ejecución
    run_policies = {}
    for agent_name in g.agents:
        # Extraer la política final del diccionario de nodos del agente
        policy = OrderedDict(
            (n, my_agents[agent_name].node_dict[n].policy()) 
            for n in sorted(my_agents[agent_name].node_dict.keys())
        )
        print(policy)
        run_policies[agent_name] = policy
    all_policies.append(run_policies)
    print(f"Ejecución {i+1} completada. Políticas almacenadas.")
# Out:
# Ejecutando 10 sesiones de entrenamiento de 2000 iteraciones cada una...
#
# --- Iniciando Ejecución 1/10 ---
# OrderedDict([('0', array([0.92620181, 0.07379819])), ('0b', array([0.99897331, 0.00102669])), ('0bb', array([0.997921, 0.002079])), ('0bp', array([0.995842, 0.004158])), ('0p', array([0.63072378, 0.36927622])), ('0pb', array([0.9989605, 0.0010395])), ('0pbb', array([9.99446886e-01, 5.53113886e-04])), ('0pbp', array([9.99446886e-01, 5.53113886e-04])), ('0pp', array([0.81190028, 0.18809972])), ('0ppb', array([9.99446886e-01, 5.53113886e-04])), ('0ppbb', array([9.99186099e-01, 8.13901492e-04])), ('0ppbp', array([9.99186099e-01, 8.13901492e-04])), ('1', array([0.90977435, 0.09022565])), ('1b', array([0.99899598, 0.00100402])), ('1bb', array([9.99021526e-01, 9.78473581e-04])), ('1bp', array([0.97392567, 0.02607433])), ('1p', array([0.88293435, 0.11706565])), ('1pb', array([0.90247955, 0.09752045])), ('1pbb', array([9.99454775e-01, 5.45225027e-04])), ('1pbp', array([0.99073117, 0.00926883])), ('1pp', array([0.59197407, 0.40802593])), ('1ppb', array([9.99454775e-01, 5.45225027e-04])), ('1ppbb', array([0.99658859, 0.00341141])), ('1ppbp', array([0.99772573, 0.00227427])), ('2', array([0.95580312, 0.04419688])), ('2b', array([0.89411997, 0.10588003])), ('2bb', array([9.99036609e-01, 9.63391137e-04])), ('2bp', array([0.2855276, 0.7144724])), ('2p', array([0.99168561, 0.00831439])), ('2pb', array([0.62139627, 0.37860373])), ('2pbb', array([0.96084584, 0.03915416])), ('2pbp', array([0.81486393, 0.18513607])), ('2pp', array([0.99094779, 0.00905221])), ('2ppb', array([0.58418938, 0.41581062])), ('2ppbb', array([9.99508585e-01, 4.91415253e-04])), ('2ppbp', array([0.35057845, 0.64942155])), ('3', array([0.76235666, 0.23764334])), ('3b', array([9.96015936e-04, 9.99003984e-01])), ('3bb', array([0.00102249, 0.99897751])), ('3bp', array([0.00102249, 0.99897751])), ('3p', array([0.0263563, 0.9736437])), ('3pb', array([0.00204499, 0.99795501])), ('3pbb', array([6.91836497e-04, 9.99308164e-01])), ('3pbp', array([6.91836497e-04, 9.99308164e-01])), ('3pp', array([0.00408998, 0.99591002])), ('3ppb', array([8.64795621e-04, 9.99135204e-01])), ('3ppbb', array([0.01889522, 0.98110478])), ('3ppbp', array([0.01889522, 0.98110478]))])
# OrderedDict([('0', array([0.99645483, 0.00354517])), ('0b', array([9.99009901e-01, 9.90099010e-04])), ('0bb', array([0.98118812, 0.01881188])), ('0bp', array([0.9980198, 0.0019802])), ('0p', array([0.91981345, 0.08018655])), ('0pb', array([9.99009901e-01, 9.90099010e-04])), ('0pbb', array([9.99472921e-01, 5.27078666e-04])), ('0pbp', array([9.99472921e-01, 5.27078666e-04])), ('0pp', array([0.81239737, 0.18760263])), ('0ppb', array([9.99472921e-01, 5.27078666e-04])), ('0ppbb', array([0.99892359, 0.00107641])), ('0ppbp', array([0.99892359, 0.00107641])), ('1', array([0.95393232, 0.04606768])), ('1b', array([9.99021526e-01, 9.78473581e-04])), ('1bb', array([0.998998, 0.001002])), ('1bp', array([0.98840896, 0.01159104])), ('1p', array([0.76796058, 0.23203942])), ('1pb', array([0.97305933, 0.02694067])), ('1pbb', array([9.99501762e-01, 4.98237832e-04])), ('1pbp', array([0.98473579, 0.01526421])), ('1pp', array([0.64084669, 0.35915331])), ('1ppb', array([0.92034944, 0.07965056])), ('1ppbb', array([0.99490352, 0.00509648])), ('1ppbp', array([0.99872588, 0.00127412])), ('2', array([0.97120535, 0.02879465])), ('2b', array([0.65289236, 0.34710764])), ('2bb', array([0.68202516, 0.31797484])), ('2bp', array([0.82223769, 0.17776231])), ('2p', array([0.95089761, 0.04910239])), ('2pb', array([0.87539123, 0.12460877])), ('2pbb', array([0.85481045, 0.14518955])), ('2pbp', array([0.41268775, 0.58731225])), ('2pp', array([0.99180328, 0.00819672])), ('2ppb', array([0.45131691, 0.54868309])), ('2ppbb', array([0.99435163, 0.00564837])), ('2ppbp', array([0.5885002, 0.4114998])), ('3', array([0.84896967, 0.15103033])), ('3b', array([0.00107527, 0.99892473])), ('3bb', array([0.45177165, 0.54822835])), ('3bp', array([9.84251969e-04, 9.99015748e-01])), ('3p', array([0.32900676, 0.67099324])), ('3pb', array([9.84251969e-04, 9.99015748e-01])), ('3pbb', array([5.75145696e-04, 9.99424854e-01])), ('3pbp', array([5.75145696e-04, 9.99424854e-01])), ('3pp', array([9.84251969e-04, 9.99015748e-01])), ('3ppb', array([5.75145696e-04, 9.99424854e-01])), ('3ppbb', array([0.00163411, 0.99836589])), ('3ppbp', array([0.00163411, 0.99836589]))])
# OrderedDict([('0', array([0.98642655, 0.01357345])), ('0b', array([9.99021526e-01, 9.78473581e-04])), ('0bb', array([0.99804688, 0.00195312])), ('0bp', array([0.98925781, 0.01074219])), ('0p', array([0.83898961, 0.16101039])), ('0pb', array([9.99023438e-01, 9.76562500e-04])), ('0pbb', array([9.99501102e-01, 4.98897746e-04])), ('0pbp', array([0.98852535, 0.01147465])), ('0pp', array([0.91365638, 0.08634362])), ('0ppb', array([0.99850331, 0.00149669])), ('0ppbb', array([9.99416874e-01, 5.83126160e-04])), ('0ppbp', array([9.99416874e-01, 5.83126160e-04])), ('1', array([0.90304737, 0.09695263])), ('1b', array([0.97044409, 0.02955591])), ('1bb', array([0.99894737, 0.00105263])), ('1bp', array([0.83670114, 0.16329886])), ('1p', array([0.78694526, 0.21305474])), ('1pb', array([0.97990469, 0.02009531])), ('1pbb', array([9.99465559e-01, 5.34440939e-04])), ('1pbp', array([0.99839668, 0.00160332])), ('1pp', array([0.68467771, 0.31532229])), ('1ppb', array([0.9989905, 0.0010095])), ('1ppbb', array([9.99356915e-01, 6.43085232e-04])), ('1ppbp', array([0.96705069, 0.03294931])), ('2', array([0.96970772, 0.03029228])), ('2b', array([0.86826739, 0.13173261])), ('2bb', array([0.39027254, 0.60972746])), ('2bp', array([0.47623281, 0.52376719])), ('2p', array([0.91704536, 0.08295464])), ('2pb', array([0.78951466, 0.21048534])), ('2pbb', array([9.99471702e-01, 5.28298444e-04])), ('2pbp', array([0.56032347, 0.43967653])), ('2pp', array([0.99191548, 0.00808452])), ('2ppb', array([0.60630163, 0.39369837])), ('2ppbb', array([0.9661302, 0.0338698])), ('2ppbp', array([0.4489219, 0.5510781])), ('3', array([0.73415183, 0.26584817])), ('3b', array([9.72762646e-04, 9.99027237e-01])), ('3bb', array([9.84251969e-04, 9.99015748e-01])), ('3bp', array([0.0019685, 0.9980315])), ('3p', array([0.46662854, 0.53337146])), ('3pb', array([9.84251969e-04, 9.99015748e-01])), ('3pbb', array([7.00676990e-04, 9.99299323e-01])), ('3pbp', array([7.00676990e-04, 9.99299323e-01])), ('3pp', array([0.00492126, 0.99507874])), ('3ppb', array([7.00676990e-04, 9.99299323e-01])), ('3ppbb', array([0.00104233, 0.99895767])), ('3ppbp', array([0.00104233, 0.99895767]))])
# Ejecución 1 completada. Políticas almacenadas.
#
# --- Iniciando Ejecución 2/10 ---
# OrderedDict([('0', array([0.99101633, 0.00898367])), ('0b', array([0.9989605, 0.0010395])), ('0bb', array([9.99040307e-01, 9.59692898e-04])), ('0bp', array([9.99040307e-01, 9.59692898e-04])), ('0p', array([0.82346938, 0.17653062])), ('0pb', array([9.99040307e-01, 9.59692898e-04])), ('0pbb', array([9.99467793e-01, 5.32207333e-04])), ('0pbp', array([9.99467793e-01, 5.32207333e-04])), ('0pp', array([0.94432122, 0.05567878])), ('0ppb', array([9.99467793e-01, 5.32207333e-04])), ('0ppbb', array([9.99368828e-01, 6.31171642e-04])), ('0ppbp', array([9.99368828e-01, 6.31171642e-04])), ('1', array([0.84309502, 0.15690498])), ('1b', array([9.99013807e-01, 9.86193294e-04])), ('1bb', array([0.999, 0.001])), ('1bp', array([0.997, 0.003])), ('1p', array([0.77571283, 0.22428717])), ('1pb', array([0.99378638, 0.00621362])), ('1pbb', array([9.99380947e-01, 6.19053200e-04])), ('1pbp', array([0.91336501, 0.08663499])), ('1pp', array([0.5370183, 0.4629817])), ('1ppb', array([0.84581551, 0.15418449])), ('1ppbb', array([9.99364331e-01, 6.35669066e-04])), ('1ppbp', array([9.99364331e-01, 6.35669066e-04])), ('2', array([0.98392548, 0.01607452])), ('2b', array([0.75534107, 0.24465893])), ('2bb', array([0.99896907, 0.00103093])), ('2bp', array([0.62404616, 0.37595384])), ('2p', array([0.98653347, 0.01346653])), ('2pb', array([0.76664294, 0.23335706])), ('2pbb', array([0.9220652, 0.0779348])), ('2pbp', array([0.50520159, 0.49479841])), ('2pp', array([0.98762887, 0.01237113])), ('2ppb', array([0.22058377, 0.77941623])), ('2ppbb', array([0.99557299, 0.00442701])), ('2ppbp', array([0.79503419, 0.20496581])), ('3', array([0.62324145, 0.37675855])), ('3b', array([0.00103306, 0.99896694])), ('3bb', array([0.00101215, 0.99898785])), ('3bp', array([0.00101215, 0.99898785])), ('3p', array([0.06627719, 0.93372281])), ('3pb', array([0.00202429, 0.99797571])), ('3pbb', array([7.95890171e-04, 9.99204110e-01])), ('3pbp', array([7.95890171e-04, 9.99204110e-01])), ('3pp', array([0.00607287, 0.99392713])), ('3ppb', array([7.95890171e-04, 9.99204110e-01])), ('3ppbb', array([0.00779346, 0.99220654])), ('3ppbp', array([0.00779346, 0.99220654]))])
# OrderedDict([('0', array([0.996625, 0.003375])), ('0b', array([0.99898785, 0.00101215])), ('0bb', array([9.99085923e-01, 9.14076782e-04])), ('0bp', array([9.99085923e-01, 9.14076782e-04])), ('0p', array([0.92667669, 0.07332331])), ('0pb', array([0.99725777, 0.00274223])), ('0pbb', array([9.99498307e-01, 5.01693215e-04])), ('0pbp', array([9.99498307e-01, 5.01693215e-04])), ('0pp', array([0.74855297, 0.25144703])), ('0ppb', array([9.99498307e-01, 5.01693215e-04])), ('0ppbb', array([9.99453884e-01, 5.46115898e-04])), ('0ppbp', array([9.99453884e-01, 5.46115898e-04])), ('1', array([0.96528072, 0.03471928])), ('1b', array([0.99475997, 0.00524003])), ('1bb', array([0.98953975, 0.01046025])), ('1bp', array([0.99895397, 0.00104603])), ('1p', array([0.52593695, 0.47406305])), ('1pb', array([0.99790795, 0.00209205])), ('1pbb', array([9.99462672e-01, 5.37327835e-04])), ('1pbp', array([0.98016161, 0.01983839])), ('1pp', array([0.66135637, 0.33864363])), ('1ppb', array([0.97686324, 0.02313676])), ('1ppbb', array([0.99614327, 0.00385673])), ('1ppbp', array([0.4439898, 0.5560102])), ('2', array([0.95022924, 0.04977076])), ('2b', array([0.99818881, 0.00181119])), ('2bb', array([0.9884696, 0.0115304])), ('2bp', array([0.45776056, 0.54223944])), ('2p', array([0.98771934, 0.01228066])), ('2pb', array([0.78612859, 0.21387141])), ('2pbb', array([9.99472757e-01, 5.27243306e-04])), ('2pbp', array([0.53417707, 0.46582293])), ('2pp', array([0.97274633, 0.02725367])), ('2ppb', array([0.69893802, 0.30106198])), ('2ppbb', array([0.5776173, 0.4223827])), ('2ppbp', array([0.2523136, 0.7476864])), ('3', array([0.86206986, 0.13793014])), ('3b', array([0.00390625, 0.99609375])), ('3bb', array([0.00100402, 0.99899598])), ('3bp', array([0.00100402, 0.99899598])), ('3p', array([0.09371778, 0.90628222])), ('3pb', array([0.00100402, 0.99899598])), ('3pbb', array([5.58766278e-04, 9.99441234e-01])), ('3pbp', array([5.58766278e-04, 9.99441234e-01])), ('3pp', array([0.00100402, 0.99899598])), ('3ppb', array([8.38149417e-04, 9.99161851e-01])), ('3ppbb', array([0.00521012, 0.99478988])), ('3ppbp', array([0.00521012, 0.99478988]))])
# OrderedDict([('0', array([0.86951064, 0.13048936])), ('0b', array([0.99899396, 0.00100604])), ('0bb', array([0.99898374, 0.00101626])), ('0bp', array([0.99898374, 0.00101626])), ('0p', array([0.61172188, 0.38827812])), ('0pb', array([0.99796748, 0.00203252])), ('0pbb', array([9.99447081e-01, 5.52919321e-04])), ('0pbp', array([9.99447081e-01, 5.52919321e-04])), ('0pp', array([0.80554244, 0.19445756])), ('0ppb', array([9.99447081e-01, 5.52919321e-04])), ('0ppbb', array([9.99177701e-01, 8.22298708e-04])), ('0ppbp', array([9.99177701e-01, 8.22298708e-04])), ('1', array([0.99897751, 0.00102249])), ('1b', array([0.9850087, 0.0149913])), ('1bb', array([0.99686192, 0.00313808])), ('1bp', array([0.9546077, 0.0453923])), ('1p', array([0.99316532, 0.00683468])), ('1pb', array([0.97103686, 0.02896314])), ('1pbb', array([9.99488229e-01, 5.11770727e-04])), ('1pbp', array([0.9964176, 0.0035824])), ('1pp', array([0.56614185, 0.43385815])), ('1ppb', array([9.99488229e-01, 5.11770727e-04])), ('1ppbb', array([9.99505461e-01, 4.94539153e-04])), ('1ppbp', array([0.98985267, 0.01014733])), ('2', array([0.97916682, 0.02083318])), ('2b', array([0.99897751, 0.00102249])), ('2bb', array([9.46969697e-04, 9.99053030e-01])), ('2bp', array([0.41196064, 0.58803936])), ('2p', array([0.98697468, 0.01302532])), ('2pb', array([0.51506861, 0.48493139])), ('2pbb', array([0.97940172, 0.02059828])), ('2pbp', array([0.92464275, 0.07535725])), ('2pp', array([0.98555871, 0.01444129])), ('2ppb', array([0.79000561, 0.20999439])), ('2ppbb', array([0.99741003, 0.00258997])), ('2ppbp', array([0.12091941, 0.87908059])), ('3', array([0.73985869, 0.26014131])), ('3b', array([9.90099010e-04, 9.99009901e-01])), ('3bb', array([0.0059761, 0.9940239])), ('3bp', array([9.96015936e-04, 9.99003984e-01])), ('3p', array([0.21591914, 0.78408086])), ('3pb', array([9.96015936e-04, 9.99003984e-01])), ('3pbb', array([6.75804726e-04, 9.99324195e-01])), ('3pbp', array([6.75804726e-04, 9.99324195e-01])), ('3pp', array([0.00398406, 0.99601594])), ('3ppb', array([6.75804726e-04, 9.99324195e-01])), ('3ppbb', array([0.00458551, 0.99541449])), ('3ppbp', array([0.00458551, 0.99541449]))])
# Ejecución 2 completada. Políticas almacenadas.
#
# --- Iniciando Ejecución 3/10 ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 23
#      21 # Entrenar agentes
#      22 for agent_name in g.agents:
# ---> 23     my_agents[agent_name].train(training_iterations)
#      25 # Almacenar las políticas de esta ejecución
#      26 run_policies = {}
#
# File c:\Users\marrt\Documents\sistemas-multiagente\Alternating Games\agents\counterfactual_regret.py:141, in CounterFactualRegret.train(self, iterations, track_strategies)
#     139 for i in range(iterations):
#     140     for player in self.game.agents:
# --> 141         self.game.reset()
#     142         reach_prob = {p: 1.0 for p in self.game.agents}
#     143         self.cfr(self.game, reach_prob, player, 1.0)
#
# File c:\Users\marrt\Documents\sistemas-multiagente\Alternating Games\games\kuhn\kuhn3.py:107, in KuhnPoker3.reset(self, seed, options)
#     106 def reset(self, seed: int | None = None, options: dict | None = None) -> None:
# --> 107     self._set_initial()
#     109     self.observations = dict(map(lambda agent: (agent, {'card': self._hand[self.agent_name_mapping[agent]], 'hist': self._hist}), self.agents))
#     110     self.rewards = dict(map(lambda agent: (agent, None), self.agents))
#
# File c:\Users\marrt\Documents\sistemas-multiagente\Alternating Games\games\kuhn\kuhn3.py:76, in KuhnPoker3._set_initial(self)
#      73 self._hist = self._start
#      75 # deal a card to each player
# ---> 76 np.random.seed(self.seed)
#      77 self._hand = np.random.choice(self._cards, size=self.num_agents, replace=False)
#      79 # reset agent selection
#
# File numpy\\random\\mtrand.pyx:4829, in numpy.random.mtrand.seed()
#
# File numpy\\random\\mtrand.pyx:254, in numpy.random.mtrand.RandomState.seed()
#
# File _mt19937.pyx:168, in numpy.random._mt19937.MT19937._legacy_seeding()
#
# File _mt19937.pyx:172, in numpy.random._mt19937.MT19937._legacy_seeding()
#
# File c:\Users\marrt\miniconda3\envs\pettingzoo_games\Lib\site-packages\numpy\_core\_ufunc_config.py:479, in errstate.__call__.<locals>.inner(*args, **kwargs)
#     476 _token = _extobj_contextvar.set(extobj)
#     477 try:
#     478     # Call the original, decorated, function:
# --> 479     return func(*args, **kwargs)
#     480 finally:
#     481     _extobj_contextvar.reset(_token)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Comparar contra los valores teóricos
#
# Los valores teóricos se calculan solo para los casos en los que existe un valor teórico para el Information Set. Existen casos como '2p' en el que el valor teórico es diferente según si el oponente tiene una Q o una J y por lo tanto no se puede calcular un valor teórico único.

# %%
def get_theoretical_values(alpha):
    """
    Devuelve los valores teóricos de las políticas para el Kuhn Poker dado un alpha.
    """
    return {
        '0': np.array([1 - alpha, alpha]),          # J: Bet alpha
        '1': np.array([1.0, 0.0]),                  # Q: Pass
        '2': np.array([max(0, 1 - 3*alpha), min(1, 3*alpha)]), # K: Bet 3*alpha (con clipping)
        '1pb': np.array([2/3-alpha, alpha+1/3]),                # Q, p-b: Fold (Pass)
        '2pb': np.array([0.0, 1.0]),                 # K, p-b: Call (Bet)
    }

# %%
# Calculate the average policy across all runs
average_policies = {}

for agent_name in g.agents:
    info_sets = all_policies[0][agent_name].keys()
    average_policies[agent_name] = {
        info_set: np.mean([run[agent_name][info_set] for run in all_policies], axis=0)
        for info_set in info_sets
    }

print("\n--- Verificando Políticas Promedio contra Valores Teóricos ---")
all_match = True
tolerance = 0.05

for agent_name, avg_policy in average_policies.items():
    print(f"\nVerificando Agente: {agent_name}")

    # Get alpha from the agent's policy of InfoSet '0', probability of Bet
    alpha = avg_policy['0'][1]
    print(f"  -> Alpha extraído: {alpha:.4f}")
    theoretical_policies = get_theoretical_values(alpha)

    for info_set, avg_actions in avg_policy.items():
        if info_set in theoretical_policies:
            theoretic_actions = theoretical_policies[info_set]
            if np.allclose(avg_actions, theoretic_actions, atol=tolerance):
                print(f"  InfoSet '{info_set}': OK.       Promedio: {np.round(avg_actions, 3)}, Teórico: {np.round(theoretic_actions, 3)}")
            else:
                all_match = False
                print(f"  InfoSet '{info_set}': FALLO.    Promedio: {np.round(avg_actions, 3)}, Teórico: {np.round(theoretic_actions, 3)}")

if all_match:
    print("\n¡Éxito! Todas las políticas promedio coinciden con los valores teóricos dentro de la tolerancia.")
else:
    print("\nAlgunas políticas promedio no coinciden con los valores teóricos.")
# Out:
# --- Verificando Políticas Promedio contra Valores Teóricos ---
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0544
#   InfoSet '0': OK.       Promedio: [0.946 0.054], Teórico: [0.946 0.054]
#   InfoSet '1': FALLO.    Promedio: [0.948 0.052], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Promedio: [0.965 0.035], Teórico: [0.612 0.388]
#   InfoSet '2': FALLO.    Promedio: [0.974 0.026], Teórico: [0.837 0.163]
#   InfoSet '2pb': FALLO.    Promedio: [0.713 0.287], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0207
#   InfoSet '0': OK.       Promedio: [0.979 0.021], Teórico: [0.979 0.021]
#   InfoSet '1': FALLO.    Promedio: [0.921 0.079], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Promedio: [0.988 0.012], Teórico: [0.646 0.354]
#   InfoSet '2': OK.       Promedio: [0.974 0.026], Teórico: [0.938 0.062]
#   InfoSet '2pb': FALLO.    Promedio: [0.849 0.151], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0313
#   InfoSet '0': OK.       Promedio: [0.969 0.031], Teórico: [0.969 0.031]
#   InfoSet '1': OK.       Promedio: [0.958 0.042], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Promedio: [0.971 0.029], Teórico: [0.635 0.365]
#   InfoSet '2': FALLO.    Promedio: [0.975 0.025], Teórico: [0.906 0.094]
#   InfoSet '2pb': FALLO.    Promedio: [0.774 0.226], Teórico: [0. 1.]
#
# Algunas políticas promedio no coinciden con los valores teóricos.

# %%
print("\n--- Verificando Cada Ejecución contra Valores Teóricos ---")
all_match = True
tolerance = 0.05

for i, run_policies in enumerate(all_policies):
    print(f"\nEjecución {i+1}:")
    for agent_name, learned_policy in run_policies.items():
        print(f"\nVerificando Agente: {agent_name}")

        # Get alpha from the agent's policy of InfoSet '0', probability of Bet
        alpha = learned_policy['0'][1]
        print(f"  -> Alpha extraído: {alpha:.4f}")
        theoretical_policies = get_theoretical_values(alpha)

        for info_set, learned_actions in learned_policy.items():
            if info_set in theoretical_policies:
                theoretic_actions = theoretical_policies[info_set]
                if np.allclose(learned_actions, theoretic_actions, atol=tolerance):
                    print(f"  InfoSet '{info_set}': OK.       Aprendido: {np.round(learned_actions, 3)}, Teórico: {np.round(theoretic_actions, 3)}")
                else:
                    all_match = False
                    print(f"  InfoSet '{info_set}': FALLO.    Aprendido: {np.round(learned_actions, 3)}, Teórico: {np.round(theoretic_actions, 3)}")

if all_match:
    print("\n¡Éxito! Todas las políticas aprendidas en cada ejecución coinciden con los valores teóricos dentro de la tolerancia.")
else:
    print("\nAlgunas políticas aprendidas en las ejecuciones no coinciden con los valores teóricos.")
# Out:
# --- Verificando Cada Ejecución contra Valores Teóricos ---
#
# Ejecución 1:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.1005
#   InfoSet '0': OK.       Aprendido: [0.899 0.101], Teórico: [0.899 0.101]
#   InfoSet '1': FALLO.    Aprendido: [0.917 0.083], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.904 0.096], Teórico: [0.566 0.434]
#   InfoSet '2': FALLO.    Aprendido: [0.961 0.039], Teórico: [0.698 0.302]
#   InfoSet '2pb': FALLO.    Aprendido: [0.658 0.342], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0009
#   InfoSet '0': OK.       Aprendido: [0.999 0.001], Teórico: [0.999 0.001]
#   InfoSet '1': FALLO.    Aprendido: [0.817 0.183], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.666 0.334]
#   InfoSet '2': OK.       Aprendido: [0.965 0.035], Teórico: [0.997 0.003]
#   InfoSet '2pb': FALLO.    Aprendido: [0.607 0.393], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0049
#   InfoSet '0': OK.       Aprendido: [0.995 0.005], Teórico: [0.995 0.005]
#   InfoSet '1': OK.       Aprendido: [0.986 0.014], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.997 0.003], Teórico: [0.662 0.338]
#   InfoSet '2': OK.       Aprendido: [0.991 0.009], Teórico: [0.985 0.015]
#   InfoSet '2pb': FALLO.    Aprendido: [0.449 0.551], Teórico: [0. 1.]
#
# Ejecución 2:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0194
#   InfoSet '0': OK.       Aprendido: [0.981 0.019], Teórico: [0.981 0.019]
#   InfoSet '1': FALLO.    Aprendido: [0.936 0.064], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.936 0.064], Teórico: [0.647 0.353]
#   InfoSet '2': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.942 0.058]
#   InfoSet '2pb': FALLO.    Aprendido: [0.672 0.328], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0011
#   InfoSet '0': OK.       Aprendido: [0.999 0.001], Teórico: [0.999 0.001]
#   InfoSet '1': FALLO.    Aprendido: [0.879 0.121], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.993 0.007], Teórico: [0.666 0.334]
#   InfoSet '2': OK.       Aprendido: [0.974 0.026], Teórico: [0.997 0.003]
#   InfoSet '2pb': FALLO.    Aprendido: [0.892 0.108], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0169
#   InfoSet '0': OK.       Aprendido: [0.983 0.017], Teórico: [0.983 0.017]
#   InfoSet '1': FALLO.    Aprendido: [0.927 0.073], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.992 0.008], Teórico: [0.65 0.35]
#   InfoSet '2': OK.       Aprendido: [0.976 0.024], Teórico: [0.949 0.051]
#   InfoSet '2pb': FALLO.    Aprendido: [0.725 0.275], Teórico: [0. 1.]
#
# Ejecución 3:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0010
#   InfoSet '0': OK.       Aprendido: [0.999 0.001], Teórico: [0.999 0.001]
#   InfoSet '1': OK.       Aprendido: [0.996 0.004], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.996 0.004], Teórico: [0.666 0.334]
#   InfoSet '2': OK.       Aprendido: [0.96 0.04], Teórico: [0.997 0.003]
#   InfoSet '2pb': FALLO.    Aprendido: [0.631 0.369], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0070
#   InfoSet '0': OK.       Aprendido: [0.993 0.007], Teórico: [0.993 0.007]
#   InfoSet '1': FALLO.    Aprendido: [0.927 0.073], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.897 0.103], Teórico: [0.66 0.34]
#   InfoSet '2': OK.       Aprendido: [0.994 0.006], Teórico: [0.979 0.021]
#   InfoSet '2pb': FALLO.    Aprendido: [0.932 0.068], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0527
#   InfoSet '0': OK.       Aprendido: [0.947 0.053], Teórico: [0.947 0.053]
#   InfoSet '1': FALLO.    Aprendido: [0.947 0.053], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.997 0.003], Teórico: [0.614 0.386]
#   InfoSet '2': FALLO.    Aprendido: [0.987 0.013], Teórico: [0.842 0.158]
#   InfoSet '2pb': FALLO.    Aprendido: [0.696 0.304], Teórico: [0. 1.]
#
# Ejecución 4:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0104
#   InfoSet '0': OK.       Aprendido: [0.99 0.01], Teórico: [0.99 0.01]
#   InfoSet '1': FALLO.    Aprendido: [0.863 0.137], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.973 0.027], Teórico: [0.656 0.344]
#   InfoSet '2': OK.       Aprendido: [0.999 0.001], Teórico: [0.969 0.031]
#   InfoSet '2pb': FALLO.    Aprendido: [0.584 0.416], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0088
#   InfoSet '0': OK.       Aprendido: [0.991 0.009], Teórico: [0.991 0.009]
#   InfoSet '1': FALLO.    Aprendido: [0.919 0.081], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.998 0.002], Teórico: [0.658 0.342]
#   InfoSet '2': OK.       Aprendido: [0.967 0.033], Teórico: [0.974 0.026]
#   InfoSet '2pb': FALLO.    Aprendido: [0.849 0.151], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0582
#   InfoSet '0': OK.       Aprendido: [0.942 0.058], Teórico: [0.942 0.058]
#   InfoSet '1': OK.       Aprendido: [0.997 0.003], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.608 0.392]
#   InfoSet '2': FALLO.    Aprendido: [0.98 0.02], Teórico: [0.825 0.175]
#   InfoSet '2pb': FALLO.    Aprendido: [0.975 0.025], Teórico: [0. 1.]
#
# Ejecución 5:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0924
#   InfoSet '0': OK.       Aprendido: [0.908 0.092], Teórico: [0.908 0.092]
#   InfoSet '1': OK.       Aprendido: [0.975 0.025], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.981 0.019], Teórico: [0.574 0.426]
#   InfoSet '2': FALLO.    Aprendido: [0.975 0.025], Teórico: [0.723 0.277]
#   InfoSet '2pb': FALLO.    Aprendido: [0.49 0.51], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0141
#   InfoSet '0': OK.       Aprendido: [0.986 0.014], Teórico: [0.986 0.014]
#   InfoSet '1': FALLO.    Aprendido: [0.93 0.07], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.653 0.347]
#   InfoSet '2': OK.       Aprendido: [0.989 0.011], Teórico: [0.958 0.042]
#   InfoSet '2pb': FALLO.    Aprendido: [0.974 0.026], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0258
#   InfoSet '0': OK.       Aprendido: [0.974 0.026], Teórico: [0.974 0.026]
#   InfoSet '1': OK.       Aprendido: [0.96 0.04], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.998 0.002], Teórico: [0.641 0.359]
#   InfoSet '2': FALLO.    Aprendido: [0.986 0.014], Teórico: [0.923 0.077]
#   InfoSet '2pb': FALLO.    Aprendido: [0.919 0.081], Teórico: [0. 1.]
#
# Ejecución 6:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0163
#   InfoSet '0': OK.       Aprendido: [0.984 0.016], Teórico: [0.984 0.016]
#   InfoSet '1': OK.       Aprendido: [0.994 0.006], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.951 0.049], Teórico: [0.65 0.35]
#   InfoSet '2': OK.       Aprendido: [0.946 0.054], Teórico: [0.951 0.049]
#   InfoSet '2pb': FALLO.    Aprendido: [0.95 0.05], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0054
#   InfoSet '0': OK.       Aprendido: [0.995 0.005], Teórico: [0.995 0.005]
#   InfoSet '1': FALLO.    Aprendido: [0.938 0.062], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.661 0.339]
#   InfoSet '2': OK.       Aprendido: [0.989 0.011], Teórico: [0.984 0.016]
#   InfoSet '2pb': FALLO.    Aprendido: [0.979 0.021], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0295
#   InfoSet '0': OK.       Aprendido: [0.97 0.03], Teórico: [0.97 0.03]
#   InfoSet '1': OK.       Aprendido: [0.988 0.012], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.637 0.363]
#   InfoSet '2': OK.       Aprendido: [0.956 0.044], Teórico: [0.911 0.089]
#   InfoSet '2pb': FALLO.    Aprendido: [0.852 0.148], Teórico: [0. 1.]
#
# Ejecución 7:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0034
#   InfoSet '0': OK.       Aprendido: [0.997 0.003], Teórico: [0.997 0.003]
#   InfoSet '1': FALLO.    Aprendido: [0.84 0.16], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.996 0.004], Teórico: [0.663 0.337]
#   InfoSet '2': OK.       Aprendido: [0.948 0.052], Teórico: [0.99 0.01]
#   InfoSet '2pb': FALLO.    Aprendido: [0.79 0.21], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0040
#   InfoSet '0': OK.       Aprendido: [0.996 0.004], Teórico: [0.996 0.004]
#   InfoSet '1': OK.       Aprendido: [0.965 0.035], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.998 0.002], Teórico: [0.663 0.337]
#   InfoSet '2': OK.       Aprendido: [0.989 0.011], Teórico: [0.988 0.012]
#   InfoSet '2pb': FALLO.    Aprendido: [0.832 0.168], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0560
#   InfoSet '0': OK.       Aprendido: [0.944 0.056], Teórico: [0.944 0.056]
#   InfoSet '1': OK.       Aprendido: [0.973 0.027], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.902 0.098], Teórico: [0.611 0.389]
#   InfoSet '2': FALLO.    Aprendido: [0.977 0.023], Teórico: [0.832 0.168]
#   InfoSet '2pb': FALLO.    Aprendido: [0.912 0.088], Teórico: [0. 1.]
#
# Ejecución 8:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.1570
#   InfoSet '0': OK.       Aprendido: [0.843 0.157], Teórico: [0.843 0.157]
#   InfoSet '1': OK.       Aprendido: [0.983 0.017], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.952 0.048], Teórico: [0.51 0.49]
#   InfoSet '2': FALLO.    Aprendido: [0.985 0.015], Teórico: [0.529 0.471]
#   InfoSet '2pb': FALLO.    Aprendido: [0.419 0.581], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0879
#   InfoSet '0': OK.       Aprendido: [0.912 0.088], Teórico: [0.912 0.088]
#   InfoSet '1': OK.       Aprendido: [0.953 0.047], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.998 0.002], Teórico: [0.579 0.421]
#   InfoSet '2': FALLO.    Aprendido: [0.94 0.06], Teórico: [0.736 0.264]
#   InfoSet '2pb': FALLO.    Aprendido: [0.679 0.321], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0221
#   InfoSet '0': OK.       Aprendido: [0.978 0.022], Teórico: [0.978 0.022]
#   InfoSet '1': FALLO.    Aprendido: [0.934 0.066], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.833 0.167], Teórico: [0.645 0.355]
#   InfoSet '2': OK.       Aprendido: [0.949 0.051], Teórico: [0.934 0.066]
#   InfoSet '2pb': FALLO.    Aprendido: [0.845 0.155], Teórico: [0. 1.]
#
# Ejecución 9:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.0380
#   InfoSet '0': OK.       Aprendido: [0.962 0.038], Teórico: [0.962 0.038]
#   InfoSet '1': OK.       Aprendido: [0.988 0.012], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.629 0.371]
#   InfoSet '2': FALLO.    Aprendido: [0.982 0.018], Teórico: [0.886 0.114]
#   InfoSet '2pb': FALLO.    Aprendido: [0.965 0.035], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0743
#   InfoSet '0': OK.       Aprendido: [0.926 0.074], Teórico: [0.926 0.074]
#   InfoSet '1': FALLO.    Aprendido: [0.896 0.104], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.998 0.002], Teórico: [0.592 0.408]
#   InfoSet '2': FALLO.    Aprendido: [0.996 0.004], Teórico: [0.777 0.223]
#   InfoSet '2pb': FALLO.    Aprendido: [0.749 0.251], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0032
#   InfoSet '0': OK.       Aprendido: [0.997 0.003], Teórico: [0.997 0.003]
#   InfoSet '1': FALLO.    Aprendido: [0.879 0.121], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.997 0.003], Teórico: [0.663 0.337]
#   InfoSet '2': OK.       Aprendido: [0.978 0.022], Teórico: [0.99 0.01]
#   InfoSet '2pb': FALLO.    Aprendido: [0.936 0.064], Teórico: [0. 1.]
#
# Ejecución 10:
#
# Verificando Agente: agent_0
#   -> Alpha extraído: 0.1060
#   InfoSet '0': OK.       Aprendido: [0.894 0.106], Teórico: [0.894 0.106]
#   InfoSet '1': OK.       Aprendido: [0.988 0.012], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.968 0.032], Teórico: [0.561 0.439]
#   InfoSet '2': FALLO.    Aprendido: [0.987 0.013], Teórico: [0.682 0.318]
#   InfoSet '2pb': FALLO.    Aprendido: [0.975 0.025], Teórico: [0. 1.]
#
# Verificando Agente: agent_1
#   -> Alpha extraído: 0.0035
#   InfoSet '0': OK.       Aprendido: [0.996 0.004], Teórico: [0.996 0.004]
#   InfoSet '1': OK.       Aprendido: [0.983 0.017], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.663 0.337]
#   InfoSet '2': FALLO.    Aprendido: [0.938 0.062], Teórico: [0.989 0.011]
#   InfoSet '2pb': FALLO.    Aprendido: [0.993 0.007], Teórico: [0. 1.]
#
# Verificando Agente: agent_2
#   -> Alpha extraído: 0.0436
#   InfoSet '0': OK.       Aprendido: [0.956 0.044], Teórico: [0.956 0.044]
#   InfoSet '1': OK.       Aprendido: [0.991 0.009], Teórico: [1. 0.]
#   InfoSet '1pb': FALLO.    Aprendido: [0.999 0.001], Teórico: [0.623 0.377]
#   InfoSet '2': FALLO.    Aprendido: [0.973 0.027], Teórico: [0.869 0.131]
#   InfoSet '2pb': FALLO.    Aprendido: [0.426 0.574], Teórico: [0. 1.]
#
# Algunas políticas aprendidas en las ejecuciones no coinciden con los valores teóricos.

# %%
# Define the theoretical policies (adjust alpha dynamically if needed)
alpha = 1/3  # Replace with dynamically calculated alpha if required
theoretical_policies = {
    'agent_0': {
        '0': np.array([1 - alpha, alpha]),          # J: Bet alpha
        '1': np.array([1.0, 0.0]),                  # Q: Pass
        '2': np.array([1 - 3*alpha, 3*alpha]),      # K: Bet 3*alpha
        '1pb': np.array([1.0, 0.0]),                # Q, p-b: Fold
        '2pb': np.array([0.0, 1.0])                 # K, p-b: Call
    },
    'agent_1': {
        '0': np.array([1 - alpha, alpha]),          # J: Bet alpha
        '1': np.array([1.0, 0.0]),                  # Q: Pass
        '2': np.array([1 - 3*alpha, 3*alpha]),      # K: Bet 3*alpha
        '1pb': np.array([1.0, 0.0]),                # Q, p-b: Fold
        '2pb': np.array([0.0, 1.0])                 # K, p-b: Call
    }
}

# Create plots for each agent
for agent_name, theoretical_policy in theoretical_policies.items():
    info_sets = list(theoretical_policy.keys())
    num_info_sets = len(info_sets)
    nrows = 2
    ncols = (num_info_sets + 1) // 2  # Ensure all info sets fit into 2 rows
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5 * ncols, 5 * nrows), sharey=True)
    fig.suptitle(f"Comparison for {agent_name}", fontsize=16)

    # Flatten axes for easier indexing
    axes = axes.flatten()

    for idx, info_set in enumerate(info_sets):
        ax = axes[idx]
        theoretic_actions = theoretical_policy[info_set]
        learned_values = [run[agent_name][info_set] for run in all_policies if info_set in run[agent_name]]

        if not learned_values:
            ax.set_title(f"InfoSet: {info_set}")
            ax.text(0.5, 0.5, "No Data", horizontalalignment='center', verticalalignment='center', fontsize=12)
            ax.axis('off')
            continue

        x = np.arange(len(learned_values))
        width = 0.35

        # Plot learned values
        for action_idx, action_name in enumerate(['Pass', 'Bet']):
            ax.bar(x + width * action_idx, [values[action_idx] for values in learned_values], width, label=f'Learned {action_name}')

        # Plot theoretical values
        colors = ['r', 'g']
        for action_idx, action_name in enumerate(['Pass', 'Bet']):
            ax.axhline(y=theoretic_actions[action_idx], color=colors[action_idx], linestyle='--', label=f'Theoretical {action_name}')

        # Add labels and legend
        ax.set_title(f"InfoSet: {info_set}")
        ax.set_xlabel("Training Session")
        ax.set_ylabel("Probability")
        ax.set_xticks(x + width / 2)
        ax.set_xticklabels([f"Run {i+1}" for i in range(len(learned_values))])
        ax.legend()
        ax.grid(axis='y', linestyle='--', alpha=0.7)

    # Hide unused subplots
    for idx in range(len(info_sets), len(axes)):
        axes[idx].axis('off')

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %% [markdown]
# ## Análisis del entrenamiento

# %%
g = KuhnPoker3(initial_player=0) 
agent_classes = [CounterFactualRegret, CounterFactualRegret, CounterFactualRegret]
my_agents = {}
g.reset()
for i, agent in enumerate(g.agents):
    my_agents[agent] = agent_classes[i](
        game=g, 
        agent=agent, 
        track_frequency=1,
        seed=42,
    )

# %%
for agent in g.agents:
    print('Training agent ' + agent)
    my_agents[agent].train(10000)
    print('Agent ' + agent + ' policies:')
    print(OrderedDict(map(lambda n: (n, my_agents[agent].node_dict[n].policy()), sorted(my_agents[agent].node_dict.keys()))))
    print('')
# Out:
# Training agent agent_0
# Agent agent_0 policies:
# OrderedDict([('0', array([0.96276338, 0.03723662])), ('0b', array([9.99795250e-01, 2.04750205e-04])), ('0bb', array([9.99801035e-01, 1.98965380e-04])), ('0bp', array([9.99801035e-01, 1.98965380e-04])), ('0p', array([0.84900196, 0.15099804])), ('0pb', array([9.99005173e-01, 9.94826900e-04])), ('0pbb', array([9.99897445e-01, 1.02554978e-04])), ('0pbp', array([0.99866679, 0.00133321])), ('0pp', array([0.60287279, 0.39712721])), ('0ppb', array([9.99692335e-01, 3.07664934e-04])), ('0ppbb', array([9.99638251e-01, 3.61748645e-04])), ('0ppbp', array([9.99397086e-01, 6.02914408e-04])), ('1', array([0.92400254, 0.07599746])), ('1b', array([9.99807692e-01, 1.92307692e-04])), ('1bb', array([9.99800080e-01, 1.99920032e-04])), ('1bp', array([0.97784932, 0.02215068])), ('1p', array([0.81299152, 0.18700848])), ('1pb', array([9.99600160e-01, 3.99840064e-04])), ('1pbb', array([9.99893480e-01, 1.06520483e-04])), ('1pbp', array([0.99606121, 0.00393879])), ('1pp', array([0.86401559, 0.13598441])), ('1ppb', array([0.94177471, 0.05822529])), ('1ppbb', array([0.99893556, 0.00106444])), ('1ppbp', array([9.99645185e-01, 3.54814942e-04])), ('2', array([0.99843494, 0.00156506])), ('2b', array([0.67721078, 0.32278922])), ('2bb', array([0.99795835, 0.00204165])), ('2bp', array([0.60367485, 0.39632515])), ('2p', array([0.99814851, 0.00185149])), ('2pb', array([0.98115832, 0.01884168])), ('2pbb', array([0.93737359, 0.06262641])), ('2pbp', array([0.44600218, 0.55399782])), ('2pp', array([0.99729481, 0.00270519])), ('2ppb', array([0.74153597, 0.25846403])), ('2ppbb', array([0.8792293, 0.1207707])), ('2ppbp', array([0.44641247, 0.55358753])), ('3', array([0.7954019, 0.2045981])), ('3b', array([1.99600798e-04, 9.99800399e-01])), ('3bb', array([1.97083169e-04, 9.99802917e-01])), ('3bp', array([1.97083169e-04, 9.99802917e-01])), ('3p', array([0.39608964, 0.60391036])), ('3pb', array([1.97083169e-04, 9.99802917e-01])), ('3pbb', array([1.26481496e-04, 9.99873519e-01])), ('3pbp', array([1.26481496e-04, 9.99873519e-01])), ('3pp', array([1.97083169e-04, 9.99802917e-01])), ('3ppb', array([1.26481496e-04, 9.99873519e-01])), ('3ppbb', array([5.03928345e-04, 9.99496072e-01])), ('3ppbp', array([5.03928345e-04, 9.99496072e-01]))])
#
# Training agent agent_1
# Agent agent_1 policies:
# OrderedDict([('0', array([0.99562962, 0.00437038])), ('0b', array([9.99397106e-01, 6.02893891e-04])), ('0bb', array([9.99596774e-01, 4.03225806e-04])), ('0bp', array([9.99596774e-01, 4.03225806e-04])), ('0p', array([0.96371924, 0.03628076])), ('0pb', array([9.99798387e-01, 2.01612903e-04])), ('0pbb', array([9.99898423e-01, 1.01576614e-04])), ('0pbp', array([9.99622831e-01, 3.77169000e-04])), ('0pp', array([0.80614613, 0.19385387])), ('0ppb', array([9.99678341e-01, 3.21659278e-04])), ('0ppbb', array([9.99895735e-01, 1.04265133e-04])), ('0ppbp', array([9.99895735e-01, 1.04265133e-04])), ('1', array([0.957391, 0.042609])), ('1b', array([9.99043496e-01, 9.56504229e-04])), ('1bb', array([9.99595633e-01, 4.04367165e-04])), ('1bp', array([9.99595633e-01, 4.04367165e-04])), ('1p', array([0.6200472, 0.3799528])), ('1pb', array([9.99797816e-01, 2.02183583e-04])), ('1pbb', array([9.99894537e-01, 1.05462977e-04])), ('1pbp', array([9.99894537e-01, 1.05462977e-04])), ('1pp', array([0.71463943, 0.28536057])), ('1ppb', array([9.99683611e-01, 3.16388931e-04])), ('1ppbb', array([9.99837618e-01, 1.62382243e-04])), ('1ppbp', array([9.99837618e-01, 1.62382243e-04])), ('2', array([0.99458269, 0.00541731])), ('2b', array([0.97181267, 0.02818733])), ('2bb', array([0.98909128, 0.01090872])), ('2bp', array([0.29111162, 0.70888838])), ('2p', array([0.99697592, 0.00302408])), ('2pb', array([0.89959162, 0.10040838])), ('2pbb', array([0.9790796, 0.0209204])), ('2pbp', array([0.4873368, 0.5126632])), ('2pp', array([0.99687401, 0.00312599])), ('2ppb', array([0.39656896, 0.60343104])), ('2ppbb', array([9.99800193e-01, 1.99807422e-04])), ('2ppbp', array([0.62392183, 0.37607817])), ('3', array([0.83045804, 0.16954196])), ('3b', array([1.98491465e-04, 9.99801509e-01])), ('3bb', array([1.95160031e-04, 9.99804840e-01])), ('3bp', array([1.95160031e-04, 9.99804840e-01])), ('3p', array([0.18136249, 0.81863751])), ('3pb', array([1.95160031e-04, 9.99804840e-01])), ('3pbb', array([1.18940612e-04, 9.99881059e-01])), ('3pbp', array([1.18940612e-04, 9.99881059e-01])), ('3pp', array([1.95160031e-04, 9.99804840e-01])), ('3ppb', array([1.18940612e-04, 9.99881059e-01])), ('3ppbb', array([5.47223041e-04, 9.99452777e-01])), ('3ppbp', array([5.47223041e-04, 9.99452777e-01]))])
#
# Training agent agent_2
# Agent agent_2 policies:
# OrderedDict([('0', array([0.99864511, 0.00135489])), ('0b', array([9.99798306e-01, 2.01694232e-04])), ('0bb', array([9.99801272e-01, 1.98728140e-04])), ('0bp', array([9.99801272e-01, 1.98728140e-04])), ('0p', array([0.8941145, 0.1058855])), ('0pb', array([9.99602544e-01, 3.97456280e-04])), ('0pbb', array([9.99900620e-01, 9.93803822e-05])), ('0pbp', array([9.99900620e-01, 9.93803822e-05])), ('0pp', array([0.77569863, 0.22430137])), ('0ppb', array([9.99304337e-01, 6.95662675e-04])), ('0ppbb', array([9.99887210e-01, 1.12789935e-04])), ('0ppbp', array([9.99887210e-01, 1.12789935e-04])), ('1', array([0.97381417, 0.02618583])), ('1b', array([0.99872699, 0.00127301])), ('1bb', array([9.99799519e-01, 2.00481155e-04])), ('1bp', array([9.99398557e-01, 6.01443464e-04])), ('1p', array([0.61566106, 0.38433894])), ('1pb', array([9.99799519e-01, 2.00481155e-04])), ('1pbb', array([9.99898408e-01, 1.01591805e-04])), ('1pbp', array([0.93545948, 0.06454052])), ('1pp', array([0.77147345, 0.22852655])), ('1ppb', array([0.9975448, 0.0024552])), ('1ppbb', array([9.99840945e-01, 1.59055066e-04])), ('1ppbp', array([9.99840945e-01, 1.59055066e-04])), ('2', array([0.99146049, 0.00853951])), ('2b', array([0.93934032, 0.06065968])), ('2bb', array([9.99597424e-01, 4.02576490e-04])), ('2bp', array([0.48718708, 0.51281292])), ('2p', array([0.99450826, 0.00549174])), ('2pb', array([0.99771119, 0.00228881])), ('2pbb', array([9.99896361e-01, 1.03638826e-04])), ('2pbp', array([0.46973368, 0.53026632])), ('2pp', array([0.99899356, 0.00100644])), ('2ppb', array([0.28452159, 0.71547841])), ('2ppbb', array([0.96894256, 0.03105744])), ('2ppbp', array([0.6851678, 0.3148322])), ('3', array([0.95280983, 0.04719017])), ('3b', array([1.99203187e-04, 9.99800797e-01])), ('3bb', array([1.99521149e-04, 9.99800479e-01])), ('3bp', array([9.97605746e-04, 9.99002394e-01])), ('3p', array([0.12562833, 0.87437167])), ('3pb', array([1.99521149e-04, 9.99800479e-01])), ('3pbb', array([1.04078479e-04, 9.99895922e-01])), ('3pbp', array([1.04078479e-04, 9.99895922e-01])), ('3pp', array([3.99042298e-04, 9.99600958e-01])), ('3ppb', array([1.04078479e-04, 9.99895922e-01])), ('3ppbb', array([7.92827479e-04, 9.99207173e-01])), ('3ppbp', array([7.92827479e-04, 9.99207173e-01]))])

# %% [markdown]
# ### Evolución de la política durante el entrenamiento

# %% [markdown]
# **Agente 0**

# %%
theoretical_JX_bet = 1/3

strategy_history = my_agents['agent_0'].strategy_history
iteration_history = my_agents['agent_0'].iteration_history

plot_strategy_evolution(strategy_history, iteration_history, 
                        action_names={0: 'Pass', 1: 'Bet'},
                        info_set_keys=['0', '1', '2', '3'],)

plot_convergence_analysis(strategy_history, iteration_history, info_set_key='0', 
                          action_names={0: 'Pass', 1: 'Bet'}, 
                          theoretical_values={0: 1 - theoretical_JX_bet, 1: theoretical_JX_bet},
                          figsize=(12, 6))

# %% [markdown]
# **Agente 1**

# %%
theoretical_JX_bet = 1/3

strategy_history = my_agents['agent_1'].strategy_history
iteration_history = my_agents['agent_1'].iteration_history

plot_strategy_evolution(strategy_history, iteration_history, 
                        action_names={0: 'Pass', 1: 'Bet'})

plot_convergence_analysis(strategy_history, iteration_history, info_set_key='0', 
                          action_names={0: 'Pass', 1: 'Bet'}, 
                          theoretical_values={0: 1 - theoretical_JX_bet, 1: theoretical_JX_bet},
                          figsize=(12, 6))

# %% [markdown]
# ### Ejecutar partidas CFR vs CFR

# %%
cum_rewards = dict(map(lambda agent: (agent, 0.), g.agents))
niter = 20000
for _ in range(niter):
    g.reset()
    turn = 0
    while not g.done():
        # print('Turn: ', turn)
        # print('\tPlayer: ', g.agent_selection)
        # print('\tObservation: ', g.observe(g.agent_selection))
        a = my_agents[g.agent_selection].action()
        # print('\tAction: ', g._moves[a])
        g.step(action=a)
        turn += 1
    #print('Rewards: ', g.rewards)
    for agent in g.agents:
        cum_rewards[agent] += g.rewards[agent]
print('Average rewards:', dict(map(lambda agent: (agent, cum_rewards[agent]/niter), g.agents)))
# Out:
# Average rewards: {'agent_0': np.float64(-0.05785), 'agent_1': np.float64(-0.0041), 'agent_2': np.float64(0.06195)}
# Teoretical rewards:  {'agent_0': np.float64(-0.056), 'agent_1': np.float64(0.056), 'agent_2': 0}
