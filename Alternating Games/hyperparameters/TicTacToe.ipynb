# %% [markdown]
# # Imports y variables

# %%
import os
import sys
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

# %%
from games.tictactoe.tictactoe import TicTacToe
from agents.agent_random import RandomAgent
from agents.minimax import MiniMax
from agents.mcts_t import MonteCarloTreeSearch
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
import time
import pandas as pd
from datetime import datetime
import csv
import re

# %% [markdown]
# # HyperParameters

# %% [markdown]
# ## Setup

# %%
# --- Hiperparámetros a explorar (ajusta los rangos según necesites) ---
mcts_simulations_options = [10, 30, 50] 
mcts_rollouts_options = [1,2,3] 
mcts_depth_options = [1, 2, 3] 

minimax_depth_options = [1, 2, 3]

# Número de juegos por cada combinación de hiperparámetros y enfrentamiento
N_GAMES_PER_CONFIG = 50

# --- Definir los dos 'WEIGHT_TIME' ---
WEIGHT_TIME_WIN_PRIORITY = 0.00001
WEIGHT_TIME_SPEED_PRIORITY = 0.01

weight_time_configs = {
    "Priorizando Victoria": WEIGHT_TIME_WIN_PRIORITY,
    "Priorizando Velocidad": WEIGHT_TIME_SPEED_PRIORITY
}

# --- Estructuras para almacenar los resultados detallados ---
# all_results se inicializa globalmente y se llenará en las celdas de ejecución
all_results = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))
# detailed_csv_rows también se inicializa globalmente
detailed_csv_rows = []

# --- Configuración para guardar los resultados ---
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
main_results_dir = f"grid_search_results_tateti_{timestamp}"
os.makedirs(main_results_dir, exist_ok=True)
print(f"Creando directorio principal de resultados: {main_results_dir}")

# Archivo de resumen general y CSV detallado (se crearán al final)
summary_log_file = os.path.join(main_results_dir, "summary_log.txt")
summary_csv_file = os.path.join(main_results_dir, "detailed_results.csv")

# Instancia de tu juego (se puede re-inicializar si es necesario, pero una global es suficiente)
game = TicTacToe()

print("--- Configuración inicial completada ---")

# Helper para crear un nombre de carpeta amigable
def get_folder_name(agent1_type, agent2_type):
    name1 = agent1_type.split('(')[0]
    name2 = agent2_type.split('(')[0]
    return f"{name1}_vs_{name2}"

# Funciones de extracción de parámetros (centralizadas aquí)
def extract_mcts_params(config_str):
    match = re.search(r'MCTS\(S=(\d+),R=(\d+),D=(\d+)\)', config_str)
    if match:
        return int(match.group(1)), int(match.group(2)), int(match.group(3))
    return np.nan, np.nan, np.nan

def extract_minimax_params(config_str):
    match = re.search(r'MiniMax\(D=(\d+)\)', config_str)
    if match:
        return int(match.group(1))
    return np.nan

# Función para ejecutar una combinación (reutilizable)
def run_agent_combination(config_name, agent1_factory, agent2_factory, subfolder_name):
    global all_results, detailed_csv_rows # Para modificar las variables globales

    # --- LÓGICA DE CREACIÓN DE SUBCARPETAS ELIMINADA AQUÍ ---
    # Las siguientes dos líneas han sido removidas.
    # full_subfolder_path = os.path.join(main_results_dir, subfolder_name)
    # os.makedirs(full_subfolder_path, exist_ok=True)
    # --------------------------------------------------------

    # NO generamos un archivo .txt por cada configuración aquí, solo en el resumen final.
    # log_filename = config_name.replace(' vs ', '_vs_').replace('(', '').replace(')', '').replace(',', '_').replace('=', '')
    # config_log_path = os.path.join(full_subfolder_path, f"{log_filename}.txt") # Esta línea también es irrelevante ahora.

    print(f"\n--- Probando: {config_name} ({N_GAMES_PER_CONFIG} juegos) ---")

    # Inicializar contadores para esta configuración
    all_results[config_name][game.agents[0]] = {'rewards': [], 'times': [], 'wins': [], 'draws': [], 'losses': []}
    all_results[config_name][game.agents[1]] = {'rewards': [], 'times': [], 'wins': [], 'draws': [], 'losses': []}

    for i in range(N_GAMES_PER_CONFIG):
        if (i + 1) % 10 == 0:
            print(f"   Juego {i+1}/{N_GAMES_PER_CONFIG}")

        players = {
            game.agents[0]: agent1_factory(),
            game.agents[1]: agent2_factory()
        }

        game.reset()
        game_times = {agent: [] for agent in game.agents}

        while not game.terminated():
            current_agent = game.agent_selection

            start_time = time.time()
            action = players[current_agent].action()
            end_time = time.time()

            game_times[current_agent].append(end_time - start_time)
            game.step(action)

        for agent_name in game.agents:
            reward = game.reward(agent_name)
            all_results[config_name][agent_name]['rewards'].append(reward)

            if reward > 0:
                all_results[config_name][agent_name]['wins'].append(1)
                all_results[config_name][agent_name]['draws'].append(0)
                all_results[config_name][agent_name]['losses'].append(0)
            elif reward == 0:
                all_results[config_name][agent_name]['wins'].append(0)
                all_results[config_name][agent_name]['draws'].append(1)
                all_results[config_name][agent_name]['losses'].append(0)
            else:
                all_results[config_name][agent_name]['wins'].append(0)
                all_results[config_name][agent_name]['draws'].append(0)
                all_results[config_name][agent_name]['losses'].append(1)

            avg_game_time = np.mean(game_times[agent_name]) if game_times[agent_name] else 0
            all_results[config_name][agent_name]['times'].append(avg_game_time)

    # Imprimir resumen de la configuración actual
    summary_line = f"\nResultados Agregados para {config_name}:\n"
    print(summary_line)

    for agent_role, agent_data in all_results[config_name].items():
        avg_reward = np.mean(agent_data['rewards'])
        total_wins = sum(agent_data['wins'])
        total_draws = sum(agent_data['draws'])
        total_losses = sum(agent_data['losses'])
        avg_time_ms = np.mean(agent_data['times']) * 1000

        agent_summary = f"   Agente {agent_role}: Recompensa Promedio={avg_reward:.3f}, Victorias={total_wins}, Empates={total_draws}, Derrotas={total_losses}, Tiempo Promedio/Acción={avg_time_ms:.2f}ms\n"
        print(agent_summary)

        detailed_csv_rows.append({
            'Configuration': config_name,
            'Agent Role': agent_role,
            'Average Reward': avg_reward,
            'Total Wins': total_wins,
            'Total Draws': total_draws,
            'Total Losses': total_losses,
            'Average Time (ms)': avg_time_ms
        })
# Out:
# Creando directorio principal de resultados: grid_search_results_tateti_20250624_202015
# --- Configuración inicial completada ---

# %%
from itertools import product

def run_grid_search_vs(
    name_a: str,
    factory_a,
    params_a: dict,
    name_b: str,
    factory_b,
    params_b: dict,
    avoid_duplicates: bool = False
):
    keys_a = list(params_a.keys())
    keys_b = list(params_b.keys())

    values_a = list(params_a.values())
    values_b = list(params_b.values())

    for va in product(*values_a):
        for vb in product(*values_b):
            # Para evitar duplicados (solo en casos como MCTS vs MCTS)
            if avoid_duplicates and va > vb:
                continue

            args_a = dict(zip(keys_a, va))
            args_b = dict(zip(keys_b, vb))

            def build_args_str(name, args):
                if args:
                    params_str = ",".join(f"{k[0].upper()}={v}" for k, v in args.items())
                    return f"{name}({params_str})"
                else:
                    return name

            config_name = f"{build_args_str(name_a, args_a)} vs {build_args_str(name_b, args_b)}"

            run_agent_combination(
                config_name,
                lambda g=game, args=args_a: factory_a(g, args),
                lambda g=game, args=args_b: factory_b(g, args),
                get_folder_name(name_a, name_b)
            )

# %% [markdown]
# ## MCTS vs Random

# %%
run_grid_search_vs(
    "MCTS",
    lambda g, args: MonteCarloTreeSearch(game=g, agent=g.agents[0], **args),
    {"simulations": mcts_simulations_options, "rollouts": mcts_rollouts_options, "depth": mcts_depth_options},
    "Random",
    lambda g, args: RandomAgent(game=g, agent=g.agents[1]),
    {}
)
run_grid_search_vs(
    "Random",
    lambda g, args: RandomAgent(game=g, agent=g.agents[0]),
    {},
    "MCTS",
    lambda g, args: MonteCarloTreeSearch(game=g, agent=g.agents[1], **args),
    {"simulations": mcts_simulations_options, "rollouts": mcts_rollouts_options, "depth": mcts_depth_options}
)
# Out:
# --- Probando: MCTS(S=10,R=1,D=1) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs Random:
#
#    Agente X: Recompensa Promedio=0.520, Victorias=37, Empates=2, Derrotas=11, Tiempo Promedio/Acción=9.73ms
#
#    Agente O: Recompensa Promedio=-0.520, Victorias=11, Empates=2, Derrotas=37, Tiempo Promedio/Acción=0.04ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs Random:
#
#    Agente X: Recompensa Promedio=0.920, Victorias=47, Empates=2, Derrotas=1, Tiempo Promedio/Acción=8.46ms
#
#    Agente O: Recompensa Promedio=-0.920, Victorias=1, Empates=2, Derrotas=47, Tiempo Promedio/Acción=0.11ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs Random:
#
#    Agente X: Recompensa Promedio=0.740, Victorias=41, Empates=5, Derrotas=4, Tiempo Promedio/Acción=8.57ms
#
#    Agente O: Recompensa Promedio=-0.740, Victorias=4, Empates=5, Derrotas=41, Tiempo Promedio/Acción=0.05ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs Random:
#
#    Agente X: Recompensa Promedio=0.800, Victorias=43, Empates=4, Derrotas=3, Tiempo Promedio/Acción=15.40ms
#
#    Agente O: Recompensa Promedio=-0.800, Victorias=3, Empates=4, Derrotas=43, Tiempo Promedio/Acción=0.04ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs Random:
#
#    Agente X: Recompensa Promedio=0.840, Victorias=45, Empates=2, Derrotas=3, Tiempo Promedio/Acción=14.56ms
#
#    Agente O: Recompensa Promedio=-0.840, Victorias=3, Empates=2, Derrotas=45, Tiempo Promedio/Acción=0.05ms
#
#
# --- Probando: MCTS(S=10,R=2,D=3) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=3) vs Random:
#
#    Agente X: Recompensa Promedio=0.920, Victorias=47, Empates=2, Derrotas=1, Tiempo Promedio/Acción=13.25ms
#
#    Agente O: Recompensa Promedio=-0.920, Victorias=1, Empates=2, Derrotas=47, Tiempo Promedio/Acción=0.07ms
#
#
# --- Probando: MCTS(S=10,R=3,D=1) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=1) vs Random:
#
#    Agente X: Recompensa Promedio=0.640, Victorias=40, Empates=2, Derrotas=8, Tiempo Promedio/Acción=19.09ms
#
#    Agente O: Recompensa Promedio=-0.640, Victorias=8, Empates=2, Derrotas=40, Tiempo Promedio/Acción=0.04ms
#
#
# --- Probando: MCTS(S=10,R=3,D=2) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=2) vs Random:
#
#    Agente X: Recompensa Promedio=0.860, Victorias=46, Empates=1, Derrotas=3, Tiempo Promedio/Acción=19.80ms
#
#    Agente O: Recompensa Promedio=-0.860, Victorias=3, Empates=1, Derrotas=46, Tiempo Promedio/Acción=0.07ms
#
#
# --- Probando: MCTS(S=10,R=3,D=3) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=3) vs Random:
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=19.41ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=0.05ms
#
#
# --- Probando: MCTS(S=30,R=1,D=1) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=1) vs Random:
#
#    Agente X: Recompensa Promedio=0.880, Victorias=46, Empates=2, Derrotas=2, Tiempo Promedio/Acción=25.21ms
#
#    Agente O: Recompensa Promedio=-0.880, Victorias=2, Empates=2, Derrotas=46, Tiempo Promedio/Acción=0.07ms
#
#
# --- Probando: MCTS(S=30,R=1,D=2) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=2) vs Random:
#
#    Agente X: Recompensa Promedio=0.760, Victorias=41, Empates=6, Derrotas=3, Tiempo Promedio/Acción=23.33ms
#
#    Agente O: Recompensa Promedio=-0.760, Victorias=3, Empates=6, Derrotas=41, Tiempo Promedio/Acción=0.07ms
#
#
# --- Probando: MCTS(S=30,R=1,D=3) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=3) vs Random:
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=22.35ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=0.05ms
#
#
# --- Probando: MCTS(S=30,R=2,D=1) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=1) vs Random:
#
#    Agente X: Recompensa Promedio=0.820, Victorias=45, Empates=1, Derrotas=4, Tiempo Promedio/Acción=42.27ms
#
#    Agente O: Recompensa Promedio=-0.820, Victorias=4, Empates=1, Derrotas=45, Tiempo Promedio/Acción=0.06ms
#
#
# --- Probando: MCTS(S=30,R=2,D=2) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=2) vs Random:
#
#    Agente X: Recompensa Promedio=0.920, Victorias=46, Empates=4, Derrotas=0, Tiempo Promedio/Acción=38.28ms
#
#    Agente O: Recompensa Promedio=-0.920, Victorias=0, Empates=4, Derrotas=46, Tiempo Promedio/Acción=0.03ms
#
#
# --- Probando: MCTS(S=30,R=2,D=3) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=3) vs Random:
#
#    Agente X: Recompensa Promedio=0.860, Victorias=46, Empates=1, Derrotas=3, Tiempo Promedio/Acción=37.34ms
#
#    Agente O: Recompensa Promedio=-0.860, Victorias=3, Empates=1, Derrotas=46, Tiempo Promedio/Acción=0.08ms
#
#
# --- Probando: MCTS(S=30,R=3,D=1) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=1) vs Random:
#
#    Agente X: Recompensa Promedio=0.760, Victorias=44, Empates=0, Derrotas=6, Tiempo Promedio/Acción=56.87ms
#
#    Agente O: Recompensa Promedio=-0.760, Victorias=6, Empates=0, Derrotas=44, Tiempo Promedio/Acción=0.04ms
#
#
# --- Probando: MCTS(S=30,R=3,D=2) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=2) vs Random:
#
#    Agente X: Recompensa Promedio=0.920, Victorias=47, Empates=2, Derrotas=1, Tiempo Promedio/Acción=56.02ms
#
#    Agente O: Recompensa Promedio=-0.920, Victorias=1, Empates=2, Derrotas=47, Tiempo Promedio/Acción=0.03ms
#
#
# --- Probando: MCTS(S=30,R=3,D=3) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=3) vs Random:
#
#    Agente X: Recompensa Promedio=0.940, Victorias=48, Empates=1, Derrotas=1, Tiempo Promedio/Acción=51.12ms
#
#    Agente O: Recompensa Promedio=-0.940, Victorias=1, Empates=1, Derrotas=48, Tiempo Promedio/Acción=0.08ms
#
#
# --- Probando: MCTS(S=50,R=1,D=1) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=1) vs Random:
#
#    Agente X: Recompensa Promedio=0.820, Victorias=45, Empates=1, Derrotas=4, Tiempo Promedio/Acción=41.39ms
#
#    Agente O: Recompensa Promedio=-0.820, Victorias=4, Empates=1, Derrotas=45, Tiempo Promedio/Acción=0.09ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs Random:
#
#    Agente X: Recompensa Promedio=0.860, Victorias=46, Empates=1, Derrotas=3, Tiempo Promedio/Acción=39.58ms
#
#    Agente O: Recompensa Promedio=-0.860, Victorias=3, Empates=1, Derrotas=46, Tiempo Promedio/Acción=0.06ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs Random:
#
#    Agente X: Recompensa Promedio=0.880, Victorias=46, Empates=2, Derrotas=2, Tiempo Promedio/Acción=39.51ms
#
#    Agente O: Recompensa Promedio=-0.880, Victorias=2, Empates=2, Derrotas=46, Tiempo Promedio/Acción=0.09ms
#
#
# --- Probando: MCTS(S=50,R=2,D=1) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=1) vs Random:
#
#    Agente X: Recompensa Promedio=0.920, Victorias=47, Empates=2, Derrotas=1, Tiempo Promedio/Acción=69.70ms
#
#    Agente O: Recompensa Promedio=-0.920, Victorias=1, Empates=2, Derrotas=47, Tiempo Promedio/Acción=0.07ms
#
#
# --- Probando: MCTS(S=50,R=2,D=2) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=2) vs Random:
#
#    Agente X: Recompensa Promedio=0.960, Victorias=49, Empates=0, Derrotas=1, Tiempo Promedio/Acción=67.70ms
#
#    Agente O: Recompensa Promedio=-0.960, Victorias=1, Empates=0, Derrotas=49, Tiempo Promedio/Acción=0.04ms
#
#
# --- Probando: MCTS(S=50,R=2,D=3) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=3) vs Random:
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=67.36ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=0.05ms
#
#
# --- Probando: MCTS(S=50,R=3,D=1) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=1) vs Random:
#
#    Agente X: Recompensa Promedio=0.780, Victorias=43, Empates=3, Derrotas=4, Tiempo Promedio/Acción=97.84ms
#
#    Agente O: Recompensa Promedio=-0.780, Victorias=4, Empates=3, Derrotas=43, Tiempo Promedio/Acción=0.06ms
#
#
# --- Probando: MCTS(S=50,R=3,D=2) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=2) vs Random:
#
#    Agente X: Recompensa Promedio=0.800, Victorias=45, Empates=0, Derrotas=5, Tiempo Promedio/Acción=106.84ms
#
#    Agente O: Recompensa Promedio=-0.800, Victorias=5, Empates=0, Derrotas=45, Tiempo Promedio/Acción=0.09ms
#
#
# --- Probando: MCTS(S=50,R=3,D=3) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=3) vs Random:
#
#    Agente X: Recompensa Promedio=0.900, Victorias=46, Empates=3, Derrotas=1, Tiempo Promedio/Acción=95.78ms
#
#    Agente O: Recompensa Promedio=-0.900, Victorias=1, Empates=3, Derrotas=46, Tiempo Promedio/Acción=0.07ms
#
#
# --- Probando: Random vs MCTS(S=10,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=10,R=1,D=1):
#
#    Agente X: Recompensa Promedio=-0.240, Victorias=14, Empates=10, Derrotas=26, Tiempo Promedio/Acción=0.06ms
#
#    Agente O: Recompensa Promedio=0.240, Victorias=26, Empates=10, Derrotas=14, Tiempo Promedio/Acción=9.84ms
#
#
# --- Probando: Random vs MCTS(S=10,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=10,R=1,D=2):
#
#    Agente X: Recompensa Promedio=-0.400, Victorias=11, Empates=8, Derrotas=31, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.400, Victorias=31, Empates=8, Derrotas=11, Tiempo Promedio/Acción=9.72ms
#
#
# --- Probando: Random vs MCTS(S=10,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=10,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.360, Victorias=13, Empates=6, Derrotas=31, Tiempo Promedio/Acción=0.07ms
#
#    Agente O: Recompensa Promedio=0.360, Victorias=31, Empates=6, Derrotas=13, Tiempo Promedio/Acción=8.72ms
#
#
# --- Probando: Random vs MCTS(S=10,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=10,R=2,D=1):
#
#    Agente X: Recompensa Promedio=-0.100, Victorias=17, Empates=11, Derrotas=22, Tiempo Promedio/Acción=0.05ms
#
#    Agente O: Recompensa Promedio=0.100, Victorias=22, Empates=11, Derrotas=17, Tiempo Promedio/Acción=15.77ms
#
#
# --- Probando: Random vs MCTS(S=10,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=10,R=2,D=2):
#
#    Agente X: Recompensa Promedio=-0.320, Victorias=13, Empates=8, Derrotas=29, Tiempo Promedio/Acción=0.05ms
#
#    Agente O: Recompensa Promedio=0.320, Victorias=29, Empates=8, Derrotas=13, Tiempo Promedio/Acción=15.83ms
#
#
# --- Probando: Random vs MCTS(S=10,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=10,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.360, Victorias=11, Empates=10, Derrotas=29, Tiempo Promedio/Acción=0.08ms
#
#    Agente O: Recompensa Promedio=0.360, Victorias=29, Empates=10, Derrotas=11, Tiempo Promedio/Acción=13.36ms
#
#
# --- Probando: Random vs MCTS(S=10,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=10,R=3,D=1):
#
#    Agente X: Recompensa Promedio=-0.020, Victorias=21, Empates=7, Derrotas=22, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.020, Victorias=22, Empates=7, Derrotas=21, Tiempo Promedio/Acción=19.80ms
#
#
# --- Probando: Random vs MCTS(S=10,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=10,R=3,D=2):
#
#    Agente X: Recompensa Promedio=-0.340, Victorias=11, Empates=11, Derrotas=28, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.340, Victorias=28, Empates=11, Derrotas=11, Tiempo Promedio/Acción=17.55ms
#
#
# --- Probando: Random vs MCTS(S=10,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=10,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.380, Victorias=11, Empates=9, Derrotas=30, Tiempo Promedio/Acción=0.07ms
#
#    Agente O: Recompensa Promedio=0.380, Victorias=30, Empates=9, Derrotas=11, Tiempo Promedio/Acción=16.88ms
#
#
# --- Probando: Random vs MCTS(S=30,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=30,R=1,D=1):
#
#    Agente X: Recompensa Promedio=-0.280, Victorias=15, Empates=6, Derrotas=29, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.280, Victorias=29, Empates=6, Derrotas=15, Tiempo Promedio/Acción=23.11ms
#
#
# --- Probando: Random vs MCTS(S=30,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=30,R=1,D=2):
#
#    Agente X: Recompensa Promedio=-0.560, Victorias=6, Empates=10, Derrotas=34, Tiempo Promedio/Acción=0.07ms
#
#    Agente O: Recompensa Promedio=0.560, Victorias=34, Empates=10, Derrotas=6, Tiempo Promedio/Acción=21.40ms
#
#
# --- Probando: Random vs MCTS(S=30,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=30,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.520, Victorias=10, Empates=4, Derrotas=36, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.520, Victorias=36, Empates=4, Derrotas=10, Tiempo Promedio/Acción=20.95ms
#
#
# --- Probando: Random vs MCTS(S=30,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=30,R=2,D=1):
#
#    Agente X: Recompensa Promedio=-0.340, Victorias=12, Empates=9, Derrotas=29, Tiempo Promedio/Acción=0.05ms
#
#    Agente O: Recompensa Promedio=0.340, Victorias=29, Empates=9, Derrotas=12, Tiempo Promedio/Acción=39.63ms
#
#
# --- Probando: Random vs MCTS(S=30,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=30,R=2,D=2):
#
#    Agente X: Recompensa Promedio=-0.380, Victorias=8, Empates=15, Derrotas=27, Tiempo Promedio/Acción=0.06ms
#
#    Agente O: Recompensa Promedio=0.380, Victorias=27, Empates=15, Derrotas=8, Tiempo Promedio/Acción=34.96ms
#
#
# --- Probando: Random vs MCTS(S=30,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=30,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.760, Victorias=4, Empates=4, Derrotas=42, Tiempo Promedio/Acción=0.05ms
#
#    Agente O: Recompensa Promedio=0.760, Victorias=42, Empates=4, Derrotas=4, Tiempo Promedio/Acción=33.23ms
#
#
# --- Probando: Random vs MCTS(S=30,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=30,R=3,D=1):
#
#    Agente X: Recompensa Promedio=-0.340, Victorias=12, Empates=9, Derrotas=29, Tiempo Promedio/Acción=0.03ms
#
#    Agente O: Recompensa Promedio=0.340, Victorias=29, Empates=9, Derrotas=12, Tiempo Promedio/Acción=52.34ms
#
#
# --- Probando: Random vs MCTS(S=30,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=30,R=3,D=2):
#
#    Agente X: Recompensa Promedio=-0.520, Victorias=7, Empates=10, Derrotas=33, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.520, Victorias=33, Empates=10, Derrotas=7, Tiempo Promedio/Acción=48.12ms
#
#
# --- Probando: Random vs MCTS(S=30,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=30,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.660, Victorias=5, Empates=7, Derrotas=38, Tiempo Promedio/Acción=0.03ms
#
#    Agente O: Recompensa Promedio=0.660, Victorias=38, Empates=7, Derrotas=5, Tiempo Promedio/Acción=47.26ms
#
#
# --- Probando: Random vs MCTS(S=50,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=50,R=1,D=1):
#
#    Agente X: Recompensa Promedio=-0.220, Victorias=13, Empates=13, Derrotas=24, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.220, Victorias=24, Empates=13, Derrotas=13, Tiempo Promedio/Acción=38.86ms
#
#
# --- Probando: Random vs MCTS(S=50,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=50,R=1,D=2):
#
#    Agente X: Recompensa Promedio=-0.280, Victorias=14, Empates=8, Derrotas=28, Tiempo Promedio/Acción=0.05ms
#
#    Agente O: Recompensa Promedio=0.280, Victorias=28, Empates=8, Derrotas=14, Tiempo Promedio/Acción=38.24ms
#
#
# --- Probando: Random vs MCTS(S=50,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=50,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.820, Victorias=3, Empates=3, Derrotas=44, Tiempo Promedio/Acción=0.06ms
#
#    Agente O: Recompensa Promedio=0.820, Victorias=44, Empates=3, Derrotas=3, Tiempo Promedio/Acción=35.77ms
#
#
# --- Probando: Random vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=-0.200, Victorias=15, Empates=10, Derrotas=25, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.200, Victorias=25, Empates=10, Derrotas=15, Tiempo Promedio/Acción=63.74ms
#
#
# --- Probando: Random vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=-0.560, Victorias=7, Empates=8, Derrotas=35, Tiempo Promedio/Acción=0.03ms
#
#    Agente O: Recompensa Promedio=0.560, Victorias=35, Empates=8, Derrotas=7, Tiempo Promedio/Acción=55.86ms
#
#
# --- Probando: Random vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.740, Victorias=4, Empates=5, Derrotas=41, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.740, Victorias=41, Empates=5, Derrotas=4, Tiempo Promedio/Acción=54.10ms
#
#
# --- Probando: Random vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=-0.260, Victorias=15, Empates=7, Derrotas=28, Tiempo Promedio/Acción=0.05ms
#
#    Agente O: Recompensa Promedio=0.260, Victorias=28, Empates=7, Derrotas=15, Tiempo Promedio/Acción=85.62ms
#
#
# --- Probando: Random vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=-0.420, Victorias=6, Empates=17, Derrotas=27, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.420, Victorias=27, Empates=17, Derrotas=6, Tiempo Promedio/Acción=80.06ms
#
#
# --- Probando: Random vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.660, Victorias=6, Empates=5, Derrotas=39, Tiempo Promedio/Acción=0.05ms
#
#    Agente O: Recompensa Promedio=0.660, Victorias=39, Empates=5, Derrotas=6, Tiempo Promedio/Acción=77.65ms

# %% [markdown]
# ## Minimax vs Random (y viceversa)

# %%
run_grid_search_vs(
    "MiniMax",
    lambda g, args: MiniMax(game=g, agent=g.agents[0], depth=args["depth"]),
    {"depth": minimax_depth_options},
    "Random",
    lambda g, args: RandomAgent(game=g, agent=g.agents[1]),
    {}
)
run_grid_search_vs(
    "Random",
    lambda g, args: RandomAgent(game=g, agent=g.agents[0]),
    {},
    "MiniMax",
    lambda g, args: MiniMax(game=g, agent=g.agents[1], depth=args["depth"]),
    {"depth": minimax_depth_options}
)
# Out:
# --- Probando: MiniMax(D=1) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs Random:
#
#    Agente X: Recompensa Promedio=-0.340, Victorias=15, Empates=3, Derrotas=32, Tiempo Promedio/Acción=2.85ms
#
#    Agente O: Recompensa Promedio=0.340, Victorias=32, Empates=3, Derrotas=15, Tiempo Promedio/Acción=0.06ms
#
#
# --- Probando: MiniMax(D=2) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs Random:
#
#    Agente X: Recompensa Promedio=0.780, Victorias=42, Empates=5, Derrotas=3, Tiempo Promedio/Acción=16.56ms
#
#    Agente O: Recompensa Promedio=-0.780, Victorias=3, Empates=5, Derrotas=42, Tiempo Promedio/Acción=0.03ms
#
#
# --- Probando: MiniMax(D=3) vs Random (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs Random:
#
#    Agente X: Recompensa Promedio=0.900, Victorias=47, Empates=1, Derrotas=2, Tiempo Promedio/Acción=117.60ms
#
#    Agente O: Recompensa Promedio=-0.900, Victorias=2, Empates=1, Derrotas=47, Tiempo Promedio/Acción=0.07ms
#
#
# --- Probando: Random vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=0.860, Victorias=46, Empates=1, Derrotas=3, Tiempo Promedio/Acción=0.03ms
#
#    Agente O: Recompensa Promedio=-0.860, Victorias=3, Empates=1, Derrotas=46, Tiempo Promedio/Acción=2.57ms
#
#
# --- Probando: Random vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.260, Victorias=5, Empates=27, Derrotas=18, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.260, Victorias=18, Empates=27, Derrotas=5, Tiempo Promedio/Acción=12.71ms
#
#
# --- Probando: Random vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para Random vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.640, Victorias=5, Empates=8, Derrotas=37, Tiempo Promedio/Acción=0.04ms
#
#    Agente O: Recompensa Promedio=0.640, Victorias=37, Empates=8, Derrotas=5, Tiempo Promedio/Acción=71.27ms

# %% [markdown]
# ## MCTS vs Minimax (y viceversa)

# %%
run_grid_search_vs(
    "MCTS",
    lambda g, args: MonteCarloTreeSearch(game=g, agent=g.agents[0], **args),
    {"simulations": mcts_simulations_options, "rollouts": mcts_rollouts_options, "depth": mcts_depth_options},
    "MiniMax",
    lambda g, args: MiniMax(game=g, agent=g.agents[1], depth=args["depth"]),
    {"depth": minimax_depth_options}
)

run_grid_search_vs(
    "MiniMax",
    lambda g, args: MiniMax(game=g, agent=g.agents[0], depth=args["depth"]),
    {"depth": minimax_depth_options},
    "MCTS",
    lambda g, args: MonteCarloTreeSearch(game=g, agent=g.agents[1], **args),
    {"simulations": mcts_simulations_options, "rollouts": mcts_rollouts_options, "depth": mcts_depth_options}
)
# Out:
# --- Probando: MCTS(S=10,R=1,D=1) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=9.24ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.20ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.360, Victorias=4, Empates=24, Derrotas=22, Tiempo Promedio/Acción=9.05ms
#
#    Agente O: Recompensa Promedio=0.360, Victorias=22, Empates=24, Derrotas=4, Tiempo Promedio/Acción=13.52ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.580, Victorias=8, Empates=5, Derrotas=37, Tiempo Promedio/Acción=9.24ms
#
#    Agente O: Recompensa Promedio=0.580, Victorias=37, Empates=5, Derrotas=8, Tiempo Promedio/Acción=73.45ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=8.73ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.06ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.220, Victorias=6, Empates=27, Derrotas=17, Tiempo Promedio/Acción=8.63ms
#
#    Agente O: Recompensa Promedio=0.220, Victorias=17, Empates=27, Derrotas=6, Tiempo Promedio/Acción=14.19ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.500, Victorias=10, Empates=5, Derrotas=35, Tiempo Promedio/Acción=8.56ms
#
#    Agente O: Recompensa Promedio=0.500, Victorias=35, Empates=5, Derrotas=10, Tiempo Promedio/Acción=70.88ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=7.99ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=2.90ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=0.100, Victorias=15, Empates=25, Derrotas=10, Tiempo Promedio/Acción=7.35ms
#
#    Agente O: Recompensa Promedio=-0.100, Victorias=10, Empates=25, Derrotas=15, Tiempo Promedio/Acción=13.24ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.220, Victorias=16, Empates=7, Derrotas=27, Tiempo Promedio/Acción=8.04ms
#
#    Agente O: Recompensa Promedio=0.220, Victorias=27, Empates=7, Derrotas=16, Tiempo Promedio/Acción=69.45ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=15.37ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.26ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.300, Victorias=7, Empates=21, Derrotas=22, Tiempo Promedio/Acción=14.09ms
#
#    Agente O: Recompensa Promedio=0.300, Victorias=22, Empates=21, Derrotas=7, Tiempo Promedio/Acción=13.37ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.640, Victorias=8, Empates=2, Derrotas=40, Tiempo Promedio/Acción=15.11ms
#
#    Agente O: Recompensa Promedio=0.640, Victorias=40, Empates=2, Derrotas=8, Tiempo Promedio/Acción=72.45ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=14.64ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.22ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.200, Victorias=5, Empates=30, Derrotas=15, Tiempo Promedio/Acción=13.50ms
#
#    Agente O: Recompensa Promedio=0.200, Victorias=15, Empates=30, Derrotas=5, Tiempo Promedio/Acción=13.63ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.580, Victorias=8, Empates=5, Derrotas=37, Tiempo Promedio/Acción=14.77ms
#
#    Agente O: Recompensa Promedio=0.580, Victorias=37, Empates=5, Derrotas=8, Tiempo Promedio/Acción=71.14ms
#
#
# --- Probando: MCTS(S=10,R=2,D=3) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=3) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=14.45ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.47ms
#
#
# --- Probando: MCTS(S=10,R=2,D=3) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=3) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=0.160, Victorias=15, Empates=28, Derrotas=7, Tiempo Promedio/Acción=12.71ms
#
#    Agente O: Recompensa Promedio=-0.160, Victorias=7, Empates=28, Derrotas=15, Tiempo Promedio/Acción=14.25ms
#
#
# --- Probando: MCTS(S=10,R=2,D=3) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=3) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.120, Victorias=18, Empates=8, Derrotas=24, Tiempo Promedio/Acción=13.61ms
#
#    Agente O: Recompensa Promedio=0.120, Victorias=24, Empates=8, Derrotas=18, Tiempo Promedio/Acción=71.72ms
#
#
# --- Probando: MCTS(S=10,R=3,D=1) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=1) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=21.91ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.26ms
#
#
# --- Probando: MCTS(S=10,R=3,D=1) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=1) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.340, Victorias=9, Empates=15, Derrotas=26, Tiempo Promedio/Acción=20.34ms
#
#    Agente O: Recompensa Promedio=0.340, Victorias=26, Empates=15, Derrotas=9, Tiempo Promedio/Acción=14.41ms
#
#
# --- Probando: MCTS(S=10,R=3,D=1) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=1) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.680, Victorias=7, Empates=2, Derrotas=41, Tiempo Promedio/Acción=20.32ms
#
#    Agente O: Recompensa Promedio=0.680, Victorias=41, Empates=2, Derrotas=7, Tiempo Promedio/Acción=69.33ms
#
#
# --- Probando: MCTS(S=10,R=3,D=2) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=2) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=22.28ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.53ms
#
#
# --- Probando: MCTS(S=10,R=3,D=2) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=2) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.180, Victorias=5, Empates=31, Derrotas=14, Tiempo Promedio/Acción=18.68ms
#
#    Agente O: Recompensa Promedio=0.180, Victorias=14, Empates=31, Derrotas=5, Tiempo Promedio/Acción=13.94ms
#
#
# --- Probando: MCTS(S=10,R=3,D=2) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=2) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.580, Victorias=6, Empates=9, Derrotas=35, Tiempo Promedio/Acción=19.20ms
#
#    Agente O: Recompensa Promedio=0.580, Victorias=35, Empates=9, Derrotas=6, Tiempo Promedio/Acción=69.46ms
#
#
# --- Probando: MCTS(S=10,R=3,D=3) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=3) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=19.46ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.20ms
#
#
# --- Probando: MCTS(S=10,R=3,D=3) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=3) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=0.080, Victorias=9, Empates=36, Derrotas=5, Tiempo Promedio/Acción=16.85ms
#
#    Agente O: Recompensa Promedio=-0.080, Victorias=5, Empates=36, Derrotas=9, Tiempo Promedio/Acción=13.59ms
#
#
# --- Probando: MCTS(S=10,R=3,D=3) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=3,D=3) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.160, Victorias=17, Empates=8, Derrotas=25, Tiempo Promedio/Acción=17.94ms
#
#    Agente O: Recompensa Promedio=0.160, Victorias=25, Empates=8, Derrotas=17, Tiempo Promedio/Acción=72.62ms
#
#
# --- Probando: MCTS(S=30,R=1,D=1) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=1) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=26.35ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.34ms
#
#
# --- Probando: MCTS(S=30,R=1,D=1) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=1) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.540, Victorias=1, Empates=21, Derrotas=28, Tiempo Promedio/Acción=25.41ms
#
#    Agente O: Recompensa Promedio=0.540, Victorias=28, Empates=21, Derrotas=1, Tiempo Promedio/Acción=13.39ms
#
#
# --- Probando: MCTS(S=30,R=1,D=1) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=1) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.720, Victorias=5, Empates=4, Derrotas=41, Tiempo Promedio/Acción=26.94ms
#
#    Agente O: Recompensa Promedio=0.720, Victorias=41, Empates=4, Derrotas=5, Tiempo Promedio/Acción=72.10ms
#
#
# --- Probando: MCTS(S=30,R=1,D=2) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=2) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=25.93ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.47ms
#
#
# --- Probando: MCTS(S=30,R=1,D=2) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=2) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.200, Victorias=4, Empates=32, Derrotas=14, Tiempo Promedio/Acción=25.15ms
#
#    Agente O: Recompensa Promedio=0.200, Victorias=14, Empates=32, Derrotas=4, Tiempo Promedio/Acción=14.83ms
#
#
# --- Probando: MCTS(S=30,R=1,D=2) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=2) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.440, Victorias=10, Empates=8, Derrotas=32, Tiempo Promedio/Acción=24.43ms
#
#    Agente O: Recompensa Promedio=0.440, Victorias=32, Empates=8, Derrotas=10, Tiempo Promedio/Acción=67.92ms
#
#
# --- Probando: MCTS(S=30,R=1,D=3) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=3) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=23.47ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.38ms
#
#
# --- Probando: MCTS(S=30,R=1,D=3) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=3) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=0.040, Victorias=15, Empates=22, Derrotas=13, Tiempo Promedio/Acción=21.33ms
#
#    Agente O: Recompensa Promedio=-0.040, Victorias=13, Empates=22, Derrotas=15, Tiempo Promedio/Acción=14.06ms
#
#
# --- Probando: MCTS(S=30,R=1,D=3) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=1,D=3) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=0.100, Victorias=23, Empates=9, Derrotas=18, Tiempo Promedio/Acción=21.75ms
#
#    Agente O: Recompensa Promedio=-0.100, Victorias=18, Empates=9, Derrotas=23, Tiempo Promedio/Acción=69.82ms
#
#
# --- Probando: MCTS(S=30,R=2,D=1) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=1) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=42.38ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.25ms
#
#
# --- Probando: MCTS(S=30,R=2,D=1) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=1) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.560, Victorias=0, Empates=22, Derrotas=28, Tiempo Promedio/Acción=38.34ms
#
#    Agente O: Recompensa Promedio=0.560, Victorias=28, Empates=22, Derrotas=0, Tiempo Promedio/Acción=12.91ms
#
#
# --- Probando: MCTS(S=30,R=2,D=1) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=1) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.700, Victorias=5, Empates=5, Derrotas=40, Tiempo Promedio/Acción=40.62ms
#
#    Agente O: Recompensa Promedio=0.700, Victorias=40, Empates=5, Derrotas=5, Tiempo Promedio/Acción=69.53ms
#
#
# --- Probando: MCTS(S=30,R=2,D=2) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=2) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=40.35ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.19ms
#
#
# --- Probando: MCTS(S=30,R=2,D=2) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=2) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.240, Victorias=1, Empates=36, Derrotas=13, Tiempo Promedio/Acción=35.80ms
#
#    Agente O: Recompensa Promedio=0.240, Victorias=13, Empates=36, Derrotas=1, Tiempo Promedio/Acción=12.67ms
#
#
# --- Probando: MCTS(S=30,R=2,D=2) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=2) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.460, Victorias=10, Empates=7, Derrotas=33, Tiempo Promedio/Acción=39.02ms
#
#    Agente O: Recompensa Promedio=0.460, Victorias=33, Empates=7, Derrotas=10, Tiempo Promedio/Acción=72.38ms
#
#
# --- Probando: MCTS(S=30,R=2,D=3) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=3) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=41.91ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.75ms
#
#
# --- Probando: MCTS(S=30,R=2,D=3) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=3) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=0.040, Victorias=10, Empates=32, Derrotas=8, Tiempo Promedio/Acción=33.36ms
#
#    Agente O: Recompensa Promedio=-0.040, Victorias=8, Empates=32, Derrotas=10, Tiempo Promedio/Acción=13.16ms
#
#
# --- Probando: MCTS(S=30,R=2,D=3) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=2,D=3) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.020, Victorias=18, Empates=13, Derrotas=19, Tiempo Promedio/Acción=33.80ms
#
#    Agente O: Recompensa Promedio=0.020, Victorias=19, Empates=13, Derrotas=18, Tiempo Promedio/Acción=68.68ms
#
#
# --- Probando: MCTS(S=30,R=3,D=1) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=1) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=56.11ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.03ms
#
#
# --- Probando: MCTS(S=30,R=3,D=1) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=1) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.760, Victorias=0, Empates=12, Derrotas=38, Tiempo Promedio/Acción=54.00ms
#
#    Agente O: Recompensa Promedio=0.760, Victorias=38, Empates=12, Derrotas=0, Tiempo Promedio/Acción=12.49ms
#
#
# --- Probando: MCTS(S=30,R=3,D=1) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=1) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.960, Victorias=0, Empates=2, Derrotas=48, Tiempo Promedio/Acción=56.45ms
#
#    Agente O: Recompensa Promedio=0.960, Victorias=48, Empates=2, Derrotas=0, Tiempo Promedio/Acción=64.58ms
#
#
# --- Probando: MCTS(S=30,R=3,D=2) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=2) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=54.59ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=2.86ms
#
#
# --- Probando: MCTS(S=30,R=3,D=2) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=2) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.080, Victorias=1, Empates=44, Derrotas=5, Tiempo Promedio/Acción=49.21ms
#
#    Agente O: Recompensa Promedio=0.080, Victorias=5, Empates=44, Derrotas=1, Tiempo Promedio/Acción=12.66ms
#
#
# --- Probando: MCTS(S=30,R=3,D=2) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=2) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.460, Victorias=9, Empates=9, Derrotas=32, Tiempo Promedio/Acción=52.96ms
#
#    Agente O: Recompensa Promedio=0.460, Victorias=32, Empates=9, Derrotas=9, Tiempo Promedio/Acción=68.09ms
#
#
# --- Probando: MCTS(S=30,R=3,D=3) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=3) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=51.92ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.09ms
#
#
# --- Probando: MCTS(S=30,R=3,D=3) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=3) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.040, Victorias=7, Empates=34, Derrotas=9, Tiempo Promedio/Acción=45.11ms
#
#    Agente O: Recompensa Promedio=0.040, Victorias=9, Empates=34, Derrotas=7, Tiempo Promedio/Acción=13.58ms
#
#
# --- Probando: MCTS(S=30,R=3,D=3) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=30,R=3,D=3) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=0.120, Victorias=21, Empates=14, Derrotas=15, Tiempo Promedio/Acción=45.99ms
#
#    Agente O: Recompensa Promedio=-0.120, Victorias=15, Empates=14, Derrotas=21, Tiempo Promedio/Acción=68.63ms
#
#
# --- Probando: MCTS(S=50,R=1,D=1) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=1) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=40.15ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.20ms
#
#
# --- Probando: MCTS(S=50,R=1,D=1) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=1) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.440, Victorias=0, Empates=28, Derrotas=22, Tiempo Promedio/Acción=37.31ms
#
#    Agente O: Recompensa Promedio=0.440, Victorias=22, Empates=28, Derrotas=0, Tiempo Promedio/Acción=12.71ms
#
#
# --- Probando: MCTS(S=50,R=1,D=1) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=1) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.520, Victorias=9, Empates=6, Derrotas=35, Tiempo Promedio/Acción=39.81ms
#
#    Agente O: Recompensa Promedio=0.520, Victorias=35, Empates=6, Derrotas=9, Tiempo Promedio/Acción=67.34ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=39.59ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=4.21ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.200, Victorias=2, Empates=36, Derrotas=12, Tiempo Promedio/Acción=35.68ms
#
#    Agente O: Recompensa Promedio=0.200, Victorias=12, Empates=36, Derrotas=2, Tiempo Promedio/Acción=13.30ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.500, Victorias=8, Empates=9, Derrotas=33, Tiempo Promedio/Acción=37.99ms
#
#    Agente O: Recompensa Promedio=0.500, Victorias=33, Empates=9, Derrotas=8, Tiempo Promedio/Acción=69.56ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=39.09ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.42ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.020, Victorias=12, Empates=25, Derrotas=13, Tiempo Promedio/Acción=33.42ms
#
#    Agente O: Recompensa Promedio=0.020, Victorias=13, Empates=25, Derrotas=12, Tiempo Promedio/Acción=13.74ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.080, Victorias=16, Empates=14, Derrotas=20, Tiempo Promedio/Acción=33.47ms
#
#    Agente O: Recompensa Promedio=0.080, Victorias=20, Empates=14, Derrotas=16, Tiempo Promedio/Acción=66.89ms
#
#
# --- Probando: MCTS(S=50,R=2,D=1) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=1) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=68.58ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.31ms
#
#
# --- Probando: MCTS(S=50,R=2,D=1) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=1) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.300, Victorias=0, Empates=35, Derrotas=15, Tiempo Promedio/Acción=59.77ms
#
#    Agente O: Recompensa Promedio=0.300, Victorias=15, Empates=35, Derrotas=0, Tiempo Promedio/Acción=12.73ms
#
#
# --- Probando: MCTS(S=50,R=2,D=1) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=1) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.740, Victorias=4, Empates=5, Derrotas=41, Tiempo Promedio/Acción=66.51ms
#
#    Agente O: Recompensa Promedio=0.740, Victorias=41, Empates=5, Derrotas=4, Tiempo Promedio/Acción=68.54ms
#
#
# --- Probando: MCTS(S=50,R=2,D=2) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=2) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=66.40ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.24ms
#
#
# --- Probando: MCTS(S=50,R=2,D=2) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=2) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.160, Victorias=1, Empates=40, Derrotas=9, Tiempo Promedio/Acción=55.02ms
#
#    Agente O: Recompensa Promedio=0.160, Victorias=9, Empates=40, Derrotas=1, Tiempo Promedio/Acción=13.05ms
#
#
# --- Probando: MCTS(S=50,R=2,D=2) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=2) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.440, Victorias=8, Empates=12, Derrotas=30, Tiempo Promedio/Acción=59.94ms
#
#    Agente O: Recompensa Promedio=0.440, Victorias=30, Empates=12, Derrotas=8, Tiempo Promedio/Acción=64.49ms
#
#
# --- Probando: MCTS(S=50,R=2,D=3) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=3) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=62.51ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.31ms
#
#
# --- Probando: MCTS(S=50,R=2,D=3) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=3) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.300, Victorias=6, Empates=23, Derrotas=21, Tiempo Promedio/Acción=53.87ms
#
#    Agente O: Recompensa Promedio=0.300, Victorias=21, Empates=23, Derrotas=6, Tiempo Promedio/Acción=12.52ms
#
#
# --- Probando: MCTS(S=50,R=2,D=3) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=3) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=0.020, Victorias=20, Empates=11, Derrotas=19, Tiempo Promedio/Acción=55.47ms
#
#    Agente O: Recompensa Promedio=-0.020, Victorias=19, Empates=11, Derrotas=20, Tiempo Promedio/Acción=65.70ms
#
#
# --- Probando: MCTS(S=50,R=3,D=1) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=1) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=91.99ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.30ms
#
#
# --- Probando: MCTS(S=50,R=3,D=1) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=1) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.260, Victorias=0, Empates=37, Derrotas=13, Tiempo Promedio/Acción=81.23ms
#
#    Agente O: Recompensa Promedio=0.260, Victorias=13, Empates=37, Derrotas=0, Tiempo Promedio/Acción=12.41ms
#
#
# --- Probando: MCTS(S=50,R=3,D=1) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=1) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.660, Victorias=4, Empates=9, Derrotas=37, Tiempo Promedio/Acción=89.32ms
#
#    Agente O: Recompensa Promedio=0.660, Victorias=37, Empates=9, Derrotas=4, Tiempo Promedio/Acción=66.28ms
#
#
# --- Probando: MCTS(S=50,R=3,D=2) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=2) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=90.28ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.08ms
#
#
# --- Probando: MCTS(S=50,R=3,D=2) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=2) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=-0.140, Victorias=1, Empates=41, Derrotas=8, Tiempo Promedio/Acción=83.22ms
#
#    Agente O: Recompensa Promedio=0.140, Victorias=8, Empates=41, Derrotas=1, Tiempo Promedio/Acción=13.21ms
#
#
# --- Probando: MCTS(S=50,R=3,D=2) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=2) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.600, Victorias=5, Empates=10, Derrotas=35, Tiempo Promedio/Acción=87.10ms
#
#    Agente O: Recompensa Promedio=0.600, Victorias=35, Empates=10, Derrotas=5, Tiempo Promedio/Acción=68.79ms
#
#
# --- Probando: MCTS(S=50,R=3,D=3) vs MiniMax(D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=3) vs MiniMax(D=1):
#
#    Agente X: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=84.76ms
#
#    Agente O: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.10ms
#
#
# --- Probando: MCTS(S=50,R=3,D=3) vs MiniMax(D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=3) vs MiniMax(D=2):
#
#    Agente X: Recompensa Promedio=0.040, Victorias=10, Empates=32, Derrotas=8, Tiempo Promedio/Acción=72.74ms
#
#    Agente O: Recompensa Promedio=-0.040, Victorias=8, Empates=32, Derrotas=10, Tiempo Promedio/Acción=13.27ms
#
#
# --- Probando: MCTS(S=50,R=3,D=3) vs MiniMax(D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=3) vs MiniMax(D=3):
#
#    Agente X: Recompensa Promedio=-0.020, Victorias=19, Empates=11, Derrotas=20, Tiempo Promedio/Acción=74.80ms
#
#    Agente O: Recompensa Promedio=0.020, Victorias=20, Empates=11, Derrotas=19, Tiempo Promedio/Acción=66.30ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=10,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=10,R=1,D=1):
#
#    Agente X: Recompensa Promedio=-0.900, Victorias=2, Empates=1, Derrotas=47, Tiempo Promedio/Acción=2.98ms
#
#    Agente O: Recompensa Promedio=0.900, Victorias=47, Empates=1, Derrotas=2, Tiempo Promedio/Acción=8.20ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=10,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=10,R=1,D=2):
#
#    Agente X: Recompensa Promedio=-0.920, Victorias=2, Empates=0, Derrotas=48, Tiempo Promedio/Acción=2.87ms
#
#    Agente O: Recompensa Promedio=0.920, Victorias=48, Empates=0, Derrotas=2, Tiempo Promedio/Acción=7.84ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=10,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=10,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.960, Victorias=0, Empates=2, Derrotas=48, Tiempo Promedio/Acción=2.86ms
#
#    Agente O: Recompensa Promedio=0.960, Victorias=48, Empates=2, Derrotas=0, Tiempo Promedio/Acción=7.45ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=10,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=10,R=2,D=1):
#
#    Agente X: Recompensa Promedio=-0.840, Victorias=4, Empates=0, Derrotas=46, Tiempo Promedio/Acción=2.91ms
#
#    Agente O: Recompensa Promedio=0.840, Victorias=46, Empates=0, Derrotas=4, Tiempo Promedio/Acción=13.44ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=10,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=10,R=2,D=2):
#
#    Agente X: Recompensa Promedio=-0.980, Victorias=0, Empates=1, Derrotas=49, Tiempo Promedio/Acción=2.91ms
#
#    Agente O: Recompensa Promedio=0.980, Victorias=49, Empates=1, Derrotas=0, Tiempo Promedio/Acción=12.69ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=10,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=10,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.11ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=12.39ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=10,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=10,R=3,D=1):
#
#    Agente X: Recompensa Promedio=-0.840, Victorias=3, Empates=2, Derrotas=45, Tiempo Promedio/Acción=2.83ms
#
#    Agente O: Recompensa Promedio=0.840, Victorias=45, Empates=2, Derrotas=3, Tiempo Promedio/Acción=18.41ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=10,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=10,R=3,D=2):
#
#    Agente X: Recompensa Promedio=-0.960, Victorias=1, Empates=0, Derrotas=49, Tiempo Promedio/Acción=3.13ms
#
#    Agente O: Recompensa Promedio=0.960, Victorias=49, Empates=0, Derrotas=1, Tiempo Promedio/Acción=17.85ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=10,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=10,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.980, Victorias=0, Empates=1, Derrotas=49, Tiempo Promedio/Acción=3.06ms
#
#    Agente O: Recompensa Promedio=0.980, Victorias=49, Empates=1, Derrotas=0, Tiempo Promedio/Acción=16.38ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=30,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=30,R=1,D=1):
#
#    Agente X: Recompensa Promedio=-0.920, Victorias=1, Empates=2, Derrotas=47, Tiempo Promedio/Acción=3.02ms
#
#    Agente O: Recompensa Promedio=0.920, Victorias=47, Empates=2, Derrotas=1, Tiempo Promedio/Acción=22.81ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=30,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=30,R=1,D=2):
#
#    Agente X: Recompensa Promedio=-0.960, Victorias=1, Empates=0, Derrotas=49, Tiempo Promedio/Acción=3.13ms
#
#    Agente O: Recompensa Promedio=0.960, Victorias=49, Empates=0, Derrotas=1, Tiempo Promedio/Acción=21.54ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=30,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=30,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.26ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=21.50ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=30,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=30,R=2,D=1):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.31ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=39.26ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=30,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=30,R=2,D=2):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.41ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=37.72ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=30,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=30,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.24ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=34.67ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=30,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=30,R=3,D=1):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.25ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=55.41ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=30,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=30,R=3,D=2):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.02ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=49.63ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=30,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=30,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.960, Victorias=1, Empates=0, Derrotas=49, Tiempo Promedio/Acción=3.07ms
#
#    Agente O: Recompensa Promedio=0.960, Victorias=49, Empates=0, Derrotas=1, Tiempo Promedio/Acción=46.16ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=50,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=50,R=1,D=1):
#
#    Agente X: Recompensa Promedio=-0.960, Victorias=1, Empates=0, Derrotas=49, Tiempo Promedio/Acción=3.75ms
#
#    Agente O: Recompensa Promedio=0.960, Victorias=49, Empates=0, Derrotas=1, Tiempo Promedio/Acción=37.23ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=50,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=50,R=1,D=2):
#
#    Agente X: Recompensa Promedio=-0.880, Victorias=3, Empates=0, Derrotas=47, Tiempo Promedio/Acción=3.12ms
#
#    Agente O: Recompensa Promedio=0.880, Victorias=47, Empates=0, Derrotas=3, Tiempo Promedio/Acción=35.65ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=50,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=50,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.24ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=33.60ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.35ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=63.93ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.35ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=59.44ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.11ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=54.03ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=2.99ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=85.48ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=-0.960, Victorias=1, Empates=0, Derrotas=49, Tiempo Promedio/Acción=3.19ms
#
#    Agente O: Recompensa Promedio=0.960, Victorias=49, Empates=0, Derrotas=1, Tiempo Promedio/Acción=84.66ms
#
#
# --- Probando: MiniMax(D=1) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=1) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-1.000, Victorias=0, Empates=0, Derrotas=50, Tiempo Promedio/Acción=3.87ms
#
#    Agente O: Recompensa Promedio=1.000, Victorias=50, Empates=0, Derrotas=0, Tiempo Promedio/Acción=76.79ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=10,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=10,R=1,D=1):
#
#    Agente X: Recompensa Promedio=-0.120, Victorias=16, Empates=12, Derrotas=22, Tiempo Promedio/Acción=16.17ms
#
#    Agente O: Recompensa Promedio=0.120, Victorias=22, Empates=12, Derrotas=16, Tiempo Promedio/Acción=8.40ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=10,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=10,R=1,D=2):
#
#    Agente X: Recompensa Promedio=-0.060, Victorias=19, Empates=9, Derrotas=22, Tiempo Promedio/Acción=16.57ms
#
#    Agente O: Recompensa Promedio=0.060, Victorias=22, Empates=9, Derrotas=19, Tiempo Promedio/Acción=7.72ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=10,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=10,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.360, Victorias=30, Empates=8, Derrotas=12, Tiempo Promedio/Acción=15.79ms
#
#    Agente O: Recompensa Promedio=-0.360, Victorias=12, Empates=8, Derrotas=30, Tiempo Promedio/Acción=7.37ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=10,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=10,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.000, Victorias=21, Empates=8, Derrotas=21, Tiempo Promedio/Acción=16.29ms
#
#    Agente O: Recompensa Promedio=0.000, Victorias=21, Empates=8, Derrotas=21, Tiempo Promedio/Acción=13.91ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=10,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=10,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.020, Victorias=22, Empates=7, Derrotas=21, Tiempo Promedio/Acción=17.89ms
#
#    Agente O: Recompensa Promedio=-0.020, Victorias=21, Empates=7, Derrotas=22, Tiempo Promedio/Acción=13.88ms
#
#
# ...
#
#    Agente X: Recompensa Promedio=-0.300, Victorias=13, Empates=9, Derrotas=28, Tiempo Promedio/Acción=16.64ms
#
#    Agente O: Recompensa Promedio=0.300, Victorias=28, Empates=9, Derrotas=13, Tiempo Promedio/Acción=47.63ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=30,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=30,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.320, Victorias=32, Empates=2, Derrotas=16, Tiempo Promedio/Acción=19.57ms
#
#    Agente O: Recompensa Promedio=-0.320, Victorias=16, Empates=2, Derrotas=32, Tiempo Promedio/Acción=51.38ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=50,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=50,R=1,D=1):
#
#    Agente X: Recompensa Promedio=-0.220, Victorias=19, Empates=1, Derrotas=30, Tiempo Promedio/Acción=18.57ms
#
#    Agente O: Recompensa Promedio=0.220, Victorias=30, Empates=1, Derrotas=19, Tiempo Promedio/Acción=40.02ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=50,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=50,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.180, Victorias=28, Empates=3, Derrotas=19, Tiempo Promedio/Acción=16.42ms
#
#    Agente O: Recompensa Promedio=-0.180, Victorias=19, Empates=3, Derrotas=28, Tiempo Promedio/Acción=34.46ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=50,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=50,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.320, Victorias=31, Empates=4, Derrotas=15, Tiempo Promedio/Acción=16.19ms
#
#    Agente O: Recompensa Promedio=-0.320, Victorias=15, Empates=4, Derrotas=31, Tiempo Promedio/Acción=32.86ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=-0.560, Victorias=11, Empates=0, Derrotas=39, Tiempo Promedio/Acción=18.14ms
#
#    Agente O: Recompensa Promedio=0.560, Victorias=39, Empates=0, Derrotas=11, Tiempo Promedio/Acción=62.33ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.280, Victorias=31, Empates=2, Derrotas=17, Tiempo Promedio/Acción=16.11ms
#
#    Agente O: Recompensa Promedio=-0.280, Victorias=17, Empates=2, Derrotas=31, Tiempo Promedio/Acción=54.43ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=0.340, Victorias=33, Empates=1, Derrotas=16, Tiempo Promedio/Acción=15.80ms
#
#    Agente O: Recompensa Promedio=-0.340, Victorias=16, Empates=1, Derrotas=33, Tiempo Promedio/Acción=51.28ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=-0.280, Victorias=18, Empates=0, Derrotas=32, Tiempo Promedio/Acción=16.83ms
#
#    Agente O: Recompensa Promedio=0.280, Victorias=32, Empates=0, Derrotas=18, Tiempo Promedio/Acción=79.41ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.080, Victorias=27, Empates=0, Derrotas=23, Tiempo Promedio/Acción=16.06ms
#
#    Agente O: Recompensa Promedio=-0.080, Victorias=23, Empates=0, Derrotas=27, Tiempo Promedio/Acción=75.96ms
#
#
# --- Probando: MiniMax(D=2) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=2) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.520, Victorias=36, Empates=4, Derrotas=10, Tiempo Promedio/Acción=15.70ms
#
#    Agente O: Recompensa Promedio=-0.520, Victorias=10, Empates=4, Derrotas=36, Tiempo Promedio/Acción=73.07ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=10,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=10,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.920, Victorias=47, Empates=2, Derrotas=1, Tiempo Promedio/Acción=112.99ms
#
#    Agente O: Recompensa Promedio=-0.920, Victorias=1, Empates=2, Derrotas=47, Tiempo Promedio/Acción=8.96ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=10,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=10,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.780, Victorias=44, Empates=1, Derrotas=5, Tiempo Promedio/Acción=117.21ms
#
#    Agente O: Recompensa Promedio=-0.780, Victorias=5, Empates=1, Derrotas=44, Tiempo Promedio/Acción=9.20ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=10,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=10,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.580, Victorias=37, Empates=5, Derrotas=8, Tiempo Promedio/Acción=111.46ms
#
#    Agente O: Recompensa Promedio=-0.580, Victorias=8, Empates=5, Derrotas=37, Tiempo Promedio/Acción=8.45ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=10,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=10,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.800, Victorias=42, Empates=6, Derrotas=2, Tiempo Promedio/Acción=115.67ms
#
#    Agente O: Recompensa Promedio=-0.800, Victorias=2, Empates=6, Derrotas=42, Tiempo Promedio/Acción=15.55ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=10,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=10,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.740, Victorias=42, Empates=3, Derrotas=5, Tiempo Promedio/Acción=111.54ms
#
#    Agente O: Recompensa Promedio=-0.740, Victorias=5, Empates=3, Derrotas=42, Tiempo Promedio/Acción=13.79ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=10,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=10,R=2,D=3):
#
#    Agente X: Recompensa Promedio=0.360, Victorias=31, Empates=6, Derrotas=13, Tiempo Promedio/Acción=102.86ms
#
#    Agente O: Recompensa Promedio=-0.360, Victorias=13, Empates=6, Derrotas=31, Tiempo Promedio/Acción=12.91ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=10,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=10,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.940, Victorias=48, Empates=1, Derrotas=1, Tiempo Promedio/Acción=111.61ms
#
#    Agente O: Recompensa Promedio=-0.940, Victorias=1, Empates=1, Derrotas=48, Tiempo Promedio/Acción=19.92ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=10,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=10,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.520, Victorias=36, Empates=4, Derrotas=10, Tiempo Promedio/Acción=106.60ms
#
#    Agente O: Recompensa Promedio=-0.520, Victorias=10, Empates=4, Derrotas=36, Tiempo Promedio/Acción=18.62ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=10,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=10,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.240, Victorias=28, Empates=6, Derrotas=16, Tiempo Promedio/Acción=101.80ms
#
#    Agente O: Recompensa Promedio=-0.240, Victorias=16, Empates=6, Derrotas=28, Tiempo Promedio/Acción=16.37ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=30,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=30,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.960, Victorias=49, Empates=0, Derrotas=1, Tiempo Promedio/Acción=110.37ms
#
#    Agente O: Recompensa Promedio=-0.960, Victorias=1, Empates=0, Derrotas=49, Tiempo Promedio/Acción=25.22ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=30,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=30,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.620, Victorias=36, Empates=9, Derrotas=5, Tiempo Promedio/Acción=107.15ms
#
#    Agente O: Recompensa Promedio=-0.620, Victorias=5, Empates=9, Derrotas=36, Tiempo Promedio/Acción=24.93ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=30,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=30,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.100, Victorias=22, Empates=1, Derrotas=27, Tiempo Promedio/Acción=106.88ms
#
#    Agente O: Recompensa Promedio=0.100, Victorias=27, Empates=1, Derrotas=22, Tiempo Promedio/Acción=21.93ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=30,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=30,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.820, Victorias=44, Empates=3, Derrotas=3, Tiempo Promedio/Acción=112.20ms
#
#    Agente O: Recompensa Promedio=-0.820, Victorias=3, Empates=3, Derrotas=44, Tiempo Promedio/Acción=42.17ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=30,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=30,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.400, Victorias=29, Empates=12, Derrotas=9, Tiempo Promedio/Acción=100.51ms
#
#    Agente O: Recompensa Promedio=-0.400, Victorias=9, Empates=12, Derrotas=29, Tiempo Promedio/Acción=37.03ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=30,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=30,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.100, Victorias=19, Empates=7, Derrotas=24, Tiempo Promedio/Acción=97.78ms
#
#    Agente O: Recompensa Promedio=0.100, Victorias=24, Empates=7, Derrotas=19, Tiempo Promedio/Acción=33.20ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=30,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=30,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.920, Victorias=48, Empates=0, Derrotas=2, Tiempo Promedio/Acción=108.86ms
#
#    Agente O: Recompensa Promedio=-0.920, Victorias=2, Empates=0, Derrotas=48, Tiempo Promedio/Acción=57.34ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=30,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=30,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.180, Victorias=21, Empates=17, Derrotas=12, Tiempo Promedio/Acción=94.91ms
#
#    Agente O: Recompensa Promedio=-0.180, Victorias=12, Empates=17, Derrotas=21, Tiempo Promedio/Acción=50.80ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=30,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=30,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.260, Victorias=16, Empates=5, Derrotas=29, Tiempo Promedio/Acción=96.53ms
#
#    Agente O: Recompensa Promedio=0.260, Victorias=29, Empates=5, Derrotas=16, Tiempo Promedio/Acción=43.80ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=50,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=50,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.760, Victorias=44, Empates=0, Derrotas=6, Tiempo Promedio/Acción=108.82ms
#
#    Agente O: Recompensa Promedio=-0.760, Victorias=6, Empates=0, Derrotas=44, Tiempo Promedio/Acción=40.22ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=50,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=50,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.300, Victorias=30, Empates=5, Derrotas=15, Tiempo Promedio/Acción=96.31ms
#
#    Agente O: Recompensa Promedio=-0.300, Victorias=15, Empates=5, Derrotas=30, Tiempo Promedio/Acción=34.69ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=50,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=50,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.340, Victorias=15, Empates=3, Derrotas=32, Tiempo Promedio/Acción=99.09ms
#
#    Agente O: Recompensa Promedio=0.340, Victorias=32, Empates=3, Derrotas=15, Tiempo Promedio/Acción=32.16ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.900, Victorias=46, Empates=3, Derrotas=1, Tiempo Promedio/Acción=103.61ms
#
#    Agente O: Recompensa Promedio=-0.900, Victorias=1, Empates=3, Derrotas=46, Tiempo Promedio/Acción=65.30ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.380, Victorias=31, Empates=7, Derrotas=12, Tiempo Promedio/Acción=101.93ms
#
#    Agente O: Recompensa Promedio=-0.380, Victorias=12, Empates=7, Derrotas=31, Tiempo Promedio/Acción=58.12ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.260, Victorias=18, Empates=1, Derrotas=31, Tiempo Promedio/Acción=101.75ms
#
#    Agente O: Recompensa Promedio=0.260, Victorias=31, Empates=1, Derrotas=18, Tiempo Promedio/Acción=53.68ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.920, Victorias=48, Empates=0, Derrotas=2, Tiempo Promedio/Acción=104.63ms
#
#    Agente O: Recompensa Promedio=-0.920, Victorias=2, Empates=0, Derrotas=48, Tiempo Promedio/Acción=91.32ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.500, Victorias=33, Empates=9, Derrotas=8, Tiempo Promedio/Acción=102.43ms
#
#    Agente O: Recompensa Promedio=-0.500, Victorias=8, Empates=9, Derrotas=33, Tiempo Promedio/Acción=83.85ms
#
#
# --- Probando: MiniMax(D=3) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MiniMax(D=3) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.100, Victorias=21, Empates=3, Derrotas=26, Tiempo Promedio/Acción=98.90ms
#
#    Agente O: Recompensa Promedio=0.100, Victorias=26, Empates=3, Derrotas=21, Tiempo Promedio/Acción=72.39ms

# %% [markdown]
# ## MCTS vs MCTS

# %%
run_grid_search_vs(
    "MCTS",
    lambda g, args: MonteCarloTreeSearch(game=g, agent=g.agents[0], **args),
    {"simulations": mcts_simulations_options, "rollouts": mcts_rollouts_options, "depth": mcts_depth_options},
    "MCTS",
    lambda g, args: MonteCarloTreeSearch(game=g, agent=g.agents[1], **args),
    {"simulations": mcts_simulations_options, "rollouts": mcts_rollouts_options, "depth": mcts_depth_options},
    avoid_duplicates=True
)
# Out:
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.380, Victorias=33, Empates=3, Derrotas=14, Tiempo Promedio/Acción=9.25ms
#
#    Agente O: Recompensa Promedio=-0.380, Victorias=14, Empates=3, Derrotas=33, Tiempo Promedio/Acción=9.67ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.260, Victorias=28, Empates=7, Derrotas=15, Tiempo Promedio/Acción=8.96ms
#
#    Agente O: Recompensa Promedio=-0.260, Victorias=15, Empates=7, Derrotas=28, Tiempo Promedio/Acción=8.54ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.020, Victorias=23, Empates=3, Derrotas=24, Tiempo Promedio/Acción=9.26ms
#
#    Agente O: Recompensa Promedio=0.020, Victorias=24, Empates=3, Derrotas=23, Tiempo Promedio/Acción=8.59ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.400, Victorias=34, Empates=2, Derrotas=14, Tiempo Promedio/Acción=9.60ms
#
#    Agente O: Recompensa Promedio=-0.400, Victorias=14, Empates=2, Derrotas=34, Tiempo Promedio/Acción=15.16ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=2,D=2):
#
#    Agente X: Recompensa Promedio=-0.020, Victorias=22, Empates=5, Derrotas=23, Tiempo Promedio/Acción=9.40ms
#
#    Agente O: Recompensa Promedio=0.020, Victorias=23, Empates=5, Derrotas=22, Tiempo Promedio/Acción=14.13ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=2,D=3):
#
#    Agente X: Recompensa Promedio=0.080, Victorias=24, Empates=6, Derrotas=20, Tiempo Promedio/Acción=9.18ms
#
#    Agente O: Recompensa Promedio=-0.080, Victorias=20, Empates=6, Derrotas=24, Tiempo Promedio/Acción=13.35ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.340, Victorias=29, Empates=9, Derrotas=12, Tiempo Promedio/Acción=8.89ms
#
#    Agente O: Recompensa Promedio=-0.340, Victorias=12, Empates=9, Derrotas=29, Tiempo Promedio/Acción=20.53ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.120, Victorias=25, Empates=6, Derrotas=19, Tiempo Promedio/Acción=9.57ms
#
#    Agente O: Recompensa Promedio=-0.120, Victorias=19, Empates=6, Derrotas=25, Tiempo Promedio/Acción=19.36ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=10,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.260, Victorias=16, Empates=5, Derrotas=29, Tiempo Promedio/Acción=9.08ms
#
#    Agente O: Recompensa Promedio=0.260, Victorias=29, Empates=5, Derrotas=16, Tiempo Promedio/Acción=16.98ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.460, Victorias=35, Empates=3, Derrotas=12, Tiempo Promedio/Acción=8.65ms
#
#    Agente O: Recompensa Promedio=-0.460, Victorias=12, Empates=3, Derrotas=35, Tiempo Promedio/Acción=26.09ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=1,D=2):
#
#    Agente X: Recompensa Promedio=-0.060, Victorias=22, Empates=3, Derrotas=25, Tiempo Promedio/Acción=8.82ms
#
#    Agente O: Recompensa Promedio=0.060, Victorias=25, Empates=3, Derrotas=22, Tiempo Promedio/Acción=22.58ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.140, Victorias=28, Empates=1, Derrotas=21, Tiempo Promedio/Acción=8.64ms
#
#    Agente O: Recompensa Promedio=-0.140, Victorias=21, Empates=1, Derrotas=28, Tiempo Promedio/Acción=22.13ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.320, Victorias=33, Empates=0, Derrotas=17, Tiempo Promedio/Acción=8.75ms
#
#    Agente O: Recompensa Promedio=-0.320, Victorias=17, Empates=0, Derrotas=33, Tiempo Promedio/Acción=42.16ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=2,D=2):
#
#    Agente X: Recompensa Promedio=-0.140, Victorias=19, Empates=5, Derrotas=26, Tiempo Promedio/Acción=8.52ms
#
#    Agente O: Recompensa Promedio=0.140, Victorias=26, Empates=5, Derrotas=19, Tiempo Promedio/Acción=36.62ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.360, Victorias=14, Empates=4, Derrotas=32, Tiempo Promedio/Acción=8.75ms
#
#    Agente O: Recompensa Promedio=0.360, Victorias=32, Empates=4, Derrotas=14, Tiempo Promedio/Acción=33.62ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.320, Victorias=33, Empates=0, Derrotas=17, Tiempo Promedio/Acción=8.75ms
#
#    Agente O: Recompensa Promedio=-0.320, Victorias=17, Empates=0, Derrotas=33, Tiempo Promedio/Acción=57.12ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=3,D=2):
#
#    Agente X: Recompensa Promedio=-0.080, Victorias=19, Empates=8, Derrotas=23, Tiempo Promedio/Acción=8.72ms
#
#    Agente O: Recompensa Promedio=0.080, Victorias=23, Empates=8, Derrotas=19, Tiempo Promedio/Acción=50.48ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=30,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.200, Victorias=19, Empates=2, Derrotas=29, Tiempo Promedio/Acción=8.92ms
#
#    Agente O: Recompensa Promedio=0.200, Victorias=29, Empates=2, Derrotas=19, Tiempo Promedio/Acción=47.84ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.200, Victorias=29, Empates=2, Derrotas=19, Tiempo Promedio/Acción=9.21ms
#
#    Agente O: Recompensa Promedio=-0.200, Victorias=19, Empates=2, Derrotas=29, Tiempo Promedio/Acción=43.62ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=1,D=2):
#
#    Agente X: Recompensa Promedio=-0.060, Victorias=20, Empates=7, Derrotas=23, Tiempo Promedio/Acción=8.87ms
#
#    Agente O: Recompensa Promedio=0.060, Victorias=23, Empates=7, Derrotas=20, Tiempo Promedio/Acción=38.10ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.440, Victorias=12, Empates=4, Derrotas=34, Tiempo Promedio/Acción=9.03ms
#
#    Agente O: Recompensa Promedio=0.440, Victorias=34, Empates=4, Derrotas=12, Tiempo Promedio/Acción=34.87ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.140, Victorias=28, Empates=1, Derrotas=21, Tiempo Promedio/Acción=8.87ms
#
#    Agente O: Recompensa Promedio=-0.140, Victorias=21, Empates=1, Derrotas=28, Tiempo Promedio/Acción=67.86ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.100, Victorias=26, Empates=3, Derrotas=21, Tiempo Promedio/Acción=9.21ms
#
#    Agente O: Recompensa Promedio=-0.100, Victorias=21, Empates=3, Derrotas=26, Tiempo Promedio/Acción=62.93ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.400, Victorias=14, Empates=2, Derrotas=34, Tiempo Promedio/Acción=8.86ms
#
#    Agente O: Recompensa Promedio=0.400, Victorias=34, Empates=2, Derrotas=14, Tiempo Promedio/Acción=56.78ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.440, Victorias=35, Empates=2, Derrotas=13, Tiempo Promedio/Acción=9.95ms
#
#    Agente O: Recompensa Promedio=-0.440, Victorias=13, Empates=2, Derrotas=35, Tiempo Promedio/Acción=106.20ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.100, Victorias=26, Empates=3, Derrotas=21, Tiempo Promedio/Acción=8.69ms
#
#    Agente O: Recompensa Promedio=-0.100, Victorias=21, Empates=3, Derrotas=26, Tiempo Promedio/Acción=84.60ms
#
#
# --- Probando: MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=1) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.420, Victorias=13, Empates=3, Derrotas=34, Tiempo Promedio/Acción=8.95ms
#
#    Agente O: Recompensa Promedio=0.420, Victorias=34, Empates=3, Derrotas=13, Tiempo Promedio/Acción=75.93ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.540, Victorias=38, Empates=1, Derrotas=11, Tiempo Promedio/Acción=8.60ms
#
#    Agente O: Recompensa Promedio=-0.540, Victorias=11, Empates=1, Derrotas=38, Tiempo Promedio/Acción=8.77ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.240, Victorias=29, Empates=4, Derrotas=17, Tiempo Promedio/Acción=8.65ms
#
#    Agente O: Recompensa Promedio=-0.240, Victorias=17, Empates=4, Derrotas=29, Tiempo Promedio/Acción=8.07ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.580, Victorias=38, Empates=3, Derrotas=9, Tiempo Promedio/Acción=9.42ms
#
#    Agente O: Recompensa Promedio=-0.580, Victorias=9, Empates=3, Derrotas=38, Tiempo Promedio/Acción=16.07ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.500, Victorias=36, Empates=3, Derrotas=11, Tiempo Promedio/Acción=9.68ms
#
#    Agente O: Recompensa Promedio=-0.500, Victorias=11, Empates=3, Derrotas=36, Tiempo Promedio/Acción=16.18ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=2,D=3):
#
#    Agente X: Recompensa Promedio=0.200, Victorias=29, Empates=2, Derrotas=19, Tiempo Promedio/Acción=9.29ms
#
#    Agente O: Recompensa Promedio=-0.200, Victorias=19, Empates=2, Derrotas=29, Tiempo Promedio/Acción=13.69ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.620, Victorias=40, Empates=1, Derrotas=9, Tiempo Promedio/Acción=9.53ms
#
#    Agente O: Recompensa Promedio=-0.620, Victorias=9, Empates=1, Derrotas=40, Tiempo Promedio/Acción=22.24ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.480, Victorias=34, Empates=6, Derrotas=10, Tiempo Promedio/Acción=9.98ms
#
#    Agente O: Recompensa Promedio=-0.480, Victorias=10, Empates=6, Derrotas=34, Tiempo Promedio/Acción=20.88ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=10,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.060, Victorias=22, Empates=3, Derrotas=25, Tiempo Promedio/Acción=9.90ms
#
#    Agente O: Recompensa Promedio=0.060, Victorias=25, Empates=3, Derrotas=22, Tiempo Promedio/Acción=19.57ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.500, Victorias=37, Empates=1, Derrotas=12, Tiempo Promedio/Acción=10.18ms
#
#    Agente O: Recompensa Promedio=-0.500, Victorias=12, Empates=1, Derrotas=37, Tiempo Promedio/Acción=29.43ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.280, Victorias=31, Empates=2, Derrotas=17, Tiempo Promedio/Acción=9.06ms
#
#    Agente O: Recompensa Promedio=-0.280, Victorias=17, Empates=2, Derrotas=31, Tiempo Promedio/Acción=25.85ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.140, Victorias=26, Empates=5, Derrotas=19, Tiempo Promedio/Acción=9.40ms
#
#    Agente O: Recompensa Promedio=-0.140, Victorias=19, Empates=5, Derrotas=26, Tiempo Promedio/Acción=26.99ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.400, Victorias=35, Empates=0, Derrotas=15, Tiempo Promedio/Acción=9.08ms
#
#    Agente O: Recompensa Promedio=-0.400, Victorias=15, Empates=0, Derrotas=35, Tiempo Promedio/Acción=45.10ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.160, Victorias=27, Empates=4, Derrotas=19, Tiempo Promedio/Acción=9.10ms
#
#    Agente O: Recompensa Promedio=-0.160, Victorias=19, Empates=4, Derrotas=27, Tiempo Promedio/Acción=40.45ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.040, Victorias=22, Empates=4, Derrotas=24, Tiempo Promedio/Acción=9.48ms
#
#    Agente O: Recompensa Promedio=0.040, Victorias=24, Empates=4, Derrotas=22, Tiempo Promedio/Acción=39.27ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.600, Victorias=39, Empates=2, Derrotas=9, Tiempo Promedio/Acción=9.22ms
#
#    Agente O: Recompensa Promedio=-0.600, Victorias=9, Empates=2, Derrotas=39, Tiempo Promedio/Acción=64.46ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.200, Victorias=29, Empates=2, Derrotas=19, Tiempo Promedio/Acción=9.49ms
#
#    Agente O: Recompensa Promedio=-0.200, Victorias=19, Empates=2, Derrotas=29, Tiempo Promedio/Acción=58.30ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=30,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.180, Victorias=19, Empates=3, Derrotas=28, Tiempo Promedio/Acción=9.86ms
#
#    Agente O: Recompensa Promedio=0.180, Victorias=28, Empates=3, Derrotas=19, Tiempo Promedio/Acción=54.05ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.700, Victorias=42, Empates=1, Derrotas=7, Tiempo Promedio/Acción=9.65ms
#
#    Agente O: Recompensa Promedio=-0.700, Victorias=7, Empates=1, Derrotas=42, Tiempo Promedio/Acción=48.28ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.300, Victorias=31, Empates=3, Derrotas=16, Tiempo Promedio/Acción=10.77ms
#
#    Agente O: Recompensa Promedio=-0.300, Victorias=16, Empates=3, Derrotas=31, Tiempo Promedio/Acción=44.88ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.040, Victorias=23, Empates=2, Derrotas=25, Tiempo Promedio/Acción=9.61ms
#
#    Agente O: Recompensa Promedio=0.040, Victorias=25, Empates=2, Derrotas=23, Tiempo Promedio/Acción=37.82ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.820, Victorias=45, Empates=1, Derrotas=4, Tiempo Promedio/Acción=8.92ms
#
#    Agente O: Recompensa Promedio=-0.820, Victorias=4, Empates=1, Derrotas=45, Tiempo Promedio/Acción=76.44ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.020, Victorias=24, Empates=3, Derrotas=23, Tiempo Promedio/Acción=8.75ms
#
#    Agente O: Recompensa Promedio=-0.020, Victorias=23, Empates=3, Derrotas=24, Tiempo Promedio/Acción=65.25ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=0.320, Victorias=33, Empates=0, Derrotas=17, Tiempo Promedio/Acción=9.01ms
#
#    Agente O: Recompensa Promedio=-0.320, Victorias=17, Empates=0, Derrotas=33, Tiempo Promedio/Acción=63.62ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.520, Victorias=38, Empates=0, Derrotas=12, Tiempo Promedio/Acción=8.91ms
#
#    Agente O: Recompensa Promedio=-0.520, Victorias=12, Empates=0, Derrotas=38, Tiempo Promedio/Acción=97.99ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.140, Victorias=28, Empates=1, Derrotas=21, Tiempo Promedio/Acción=9.11ms
#
#    Agente O: Recompensa Promedio=-0.140, Victorias=21, Empates=1, Derrotas=28, Tiempo Promedio/Acción=91.83ms
#
#
# --- Probando: MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=2) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.040, Victorias=23, Empates=2, Derrotas=25, Tiempo Promedio/Acción=10.15ms
#
#    Agente O: Recompensa Promedio=0.040, Victorias=25, Empates=2, Derrotas=23, Tiempo Promedio/Acción=82.23ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.560, Victorias=36, Empates=6, Derrotas=8, Tiempo Promedio/Acción=8.35ms
#
#    Agente O: Recompensa Promedio=-0.560, Victorias=8, Empates=6, Derrotas=36, Tiempo Promedio/Acción=8.39ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.600, Victorias=39, Empates=2, Derrotas=9, Tiempo Promedio/Acción=8.41ms
#
#    Agente O: Recompensa Promedio=-0.600, Victorias=9, Empates=2, Derrotas=39, Tiempo Promedio/Acción=14.90ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.600, Victorias=38, Empates=4, Derrotas=8, Tiempo Promedio/Acción=8.66ms
#
#    Agente O: Recompensa Promedio=-0.600, Victorias=8, Empates=4, Derrotas=38, Tiempo Promedio/Acción=14.40ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=2,D=3):
#
#    Agente X: Recompensa Promedio=0.300, Victorias=29, Empates=7, Derrotas=14, Tiempo Promedio/Acción=8.27ms
#
#    Agente O: Recompensa Promedio=-0.300, Victorias=14, Empates=7, Derrotas=29, Tiempo Promedio/Acción=13.38ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.540, Victorias=37, Empates=3, Derrotas=10, Tiempo Promedio/Acción=8.31ms
#
#    Agente O: Recompensa Promedio=-0.540, Victorias=10, Empates=3, Derrotas=37, Tiempo Promedio/Acción=20.79ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.340, Victorias=32, Empates=3, Derrotas=15, Tiempo Promedio/Acción=9.10ms
#
#    Agente O: Recompensa Promedio=-0.340, Victorias=15, Empates=3, Derrotas=32, Tiempo Promedio/Acción=21.05ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=10,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.200, Victorias=27, Empates=6, Derrotas=17, Tiempo Promedio/Acción=10.10ms
#
#    Agente O: Recompensa Promedio=-0.200, Victorias=17, Empates=6, Derrotas=27, Tiempo Promedio/Acción=21.80ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.840, Victorias=45, Empates=2, Derrotas=3, Tiempo Promedio/Acción=9.48ms
#
#    Agente O: Recompensa Promedio=-0.840, Victorias=3, Empates=2, Derrotas=45, Tiempo Promedio/Acción=30.44ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.140, Victorias=26, Empates=5, Derrotas=19, Tiempo Promedio/Acción=9.53ms
#
#    Agente O: Recompensa Promedio=-0.140, Victorias=19, Empates=5, Derrotas=26, Tiempo Promedio/Acción=26.59ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.360, Victorias=31, Empates=6, Derrotas=13, Tiempo Promedio/Acción=8.75ms
#
#    Agente O: Recompensa Promedio=-0.360, Victorias=13, Empates=6, Derrotas=31, Tiempo Promedio/Acción=24.44ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.600, Victorias=40, Empates=0, Derrotas=10, Tiempo Promedio/Acción=9.03ms
#
#    Agente O: Recompensa Promedio=-0.600, Victorias=10, Empates=0, Derrotas=40, Tiempo Promedio/Acción=47.15ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.540, Victorias=36, Empates=5, Derrotas=9, Tiempo Promedio/Acción=9.48ms
#
#    Agente O: Recompensa Promedio=-0.540, Victorias=9, Empates=5, Derrotas=36, Tiempo Promedio/Acción=40.04ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=2,D=3):
#
#    Agente X: Recompensa Promedio=0.160, Victorias=27, Empates=4, Derrotas=19, Tiempo Promedio/Acción=8.34ms
#
#    Agente O: Recompensa Promedio=-0.160, Victorias=19, Empates=4, Derrotas=27, Tiempo Promedio/Acción=36.64ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.620, Victorias=39, Empates=3, Derrotas=8, Tiempo Promedio/Acción=8.47ms
#
#    Agente O: Recompensa Promedio=-0.620, Victorias=8, Empates=3, Derrotas=39, Tiempo Promedio/Acción=60.76ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.440, Victorias=34, Empates=4, Derrotas=12, Tiempo Promedio/Acción=8.41ms
#
#    Agente O: Recompensa Promedio=-0.440, Victorias=12, Empates=4, Derrotas=34, Tiempo Promedio/Acción=51.85ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.020, Victorias=24, Empates=3, Derrotas=23, Tiempo Promedio/Acción=8.15ms
#
#    Agente O: Recompensa Promedio=-0.020, Victorias=23, Empates=3, Derrotas=24, Tiempo Promedio/Acción=47.80ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.620, Victorias=39, Empates=3, Derrotas=8, Tiempo Promedio/Acción=8.29ms
#
#    Agente O: Recompensa Promedio=-0.620, Victorias=8, Empates=3, Derrotas=39, Tiempo Promedio/Acción=42.88ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.440, Victorias=33, Empates=6, Derrotas=11, Tiempo Promedio/Acción=8.22ms
#
#    Agente O: Recompensa Promedio=-0.440, Victorias=11, Empates=6, Derrotas=33, Tiempo Promedio/Acción=38.74ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.140, Victorias=26, Empates=5, Derrotas=19, Tiempo Promedio/Acción=8.42ms
#
#    Agente O: Recompensa Promedio=-0.140, Victorias=19, Empates=5, Derrotas=26, Tiempo Promedio/Acción=35.28ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.640, Victorias=38, Empates=6, Derrotas=6, Tiempo Promedio/Acción=8.16ms
#
#    Agente O: Recompensa Promedio=-0.640, Victorias=6, Empates=6, Derrotas=38, Tiempo Promedio/Acción=69.63ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.520, Victorias=35, Empates=6, Derrotas=9, Tiempo Promedio/Acción=7.98ms
#
#    Agente O: Recompensa Promedio=-0.520, Victorias=9, Empates=6, Derrotas=35, Tiempo Promedio/Acción=64.17ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.180, Victorias=16, Empates=9, Derrotas=25, Tiempo Promedio/Acción=7.96ms
#
#    Agente O: Recompensa Promedio=0.180, Victorias=25, Empates=9, Derrotas=16, Tiempo Promedio/Acción=56.07ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.460, Victorias=35, Empates=3, Derrotas=12, Tiempo Promedio/Acción=8.19ms
#
#    Agente O: Recompensa Promedio=-0.460, Victorias=12, Empates=3, Derrotas=35, Tiempo Promedio/Acción=93.10ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.120, Victorias=24, Empates=8, Derrotas=18, Tiempo Promedio/Acción=8.78ms
#
#    Agente O: Recompensa Promedio=-0.120, Victorias=18, Empates=8, Derrotas=24, Tiempo Promedio/Acción=90.95ms
#
#
# --- Probando: MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=1,D=3) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.180, Victorias=28, Empates=3, Derrotas=19, Tiempo Promedio/Acción=8.83ms
#
#    Agente O: Recompensa Promedio=-0.180, Victorias=19, Empates=3, Derrotas=28, Tiempo Promedio/Acción=84.69ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.580, Victorias=39, Empates=1, Derrotas=10, Tiempo Promedio/Acción=15.58ms
#
#    Agente O: Recompensa Promedio=-0.580, Victorias=10, Empates=1, Derrotas=39, Tiempo Promedio/Acción=16.22ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.240, Victorias=30, Empates=2, Derrotas=18, Tiempo Promedio/Acción=15.77ms
#
#    Agente O: Recompensa Promedio=-0.240, Victorias=18, Empates=2, Derrotas=30, Tiempo Promedio/Acción=16.01ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.120, Victorias=18, Empates=8, Derrotas=24, Tiempo Promedio/Acción=15.74ms
#
#    Agente O: Recompensa Promedio=0.120, Victorias=24, Empates=8, Derrotas=18, Tiempo Promedio/Acción=13.67ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.380, Victorias=32, Empates=5, Derrotas=13, Tiempo Promedio/Acción=15.90ms
#
#    Agente O: Recompensa Promedio=-0.380, Victorias=13, Empates=5, Derrotas=32, Tiempo Promedio/Acción=22.37ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.200, Victorias=28, Empates=4, Derrotas=18, Tiempo Promedio/Acción=15.31ms
#
#    Agente O: Recompensa Promedio=-0.200, Victorias=18, Empates=4, Derrotas=28, Tiempo Promedio/Acción=20.27ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=10,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.240, Victorias=15, Empates=8, Derrotas=27, Tiempo Promedio/Acción=16.07ms
#
#    Agente O: Recompensa Promedio=0.240, Victorias=27, Empates=8, Derrotas=15, Tiempo Promedio/Acción=18.50ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.520, Victorias=37, Empates=2, Derrotas=11, Tiempo Promedio/Acción=16.33ms
#
#    Agente O: Recompensa Promedio=-0.520, Victorias=11, Empates=2, Derrotas=37, Tiempo Promedio/Acción=27.81ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.100, Victorias=25, Empates=5, Derrotas=20, Tiempo Promedio/Acción=16.37ms
#
#    Agente O: Recompensa Promedio=-0.100, Victorias=20, Empates=5, Derrotas=25, Tiempo Promedio/Acción=26.94ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.240, Victorias=18, Empates=2, Derrotas=30, Tiempo Promedio/Acción=15.75ms
#
#    Agente O: Recompensa Promedio=0.240, Victorias=30, Empates=2, Derrotas=18, Tiempo Promedio/Acción=23.40ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.320, Victorias=33, Empates=0, Derrotas=17, Tiempo Promedio/Acción=15.94ms
#
#    Agente O: Recompensa Promedio=-0.320, Victorias=17, Empates=0, Derrotas=33, Tiempo Promedio/Acción=46.68ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.180, Victorias=27, Empates=5, Derrotas=18, Tiempo Promedio/Acción=15.58ms
#
#    Agente O: Recompensa Promedio=-0.180, Victorias=18, Empates=5, Derrotas=27, Tiempo Promedio/Acción=42.93ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.300, Victorias=15, Empates=5, Derrotas=30, Tiempo Promedio/Acción=16.20ms
#
#    Agente O: Recompensa Promedio=0.300, Victorias=30, Empates=5, Derrotas=15, Tiempo Promedio/Acción=37.66ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.200, Victorias=30, Empates=0, Derrotas=20, Tiempo Promedio/Acción=16.48ms
#
#    Agente O: Recompensa Promedio=-0.200, Victorias=20, Empates=0, Derrotas=30, Tiempo Promedio/Acción=65.48ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=3,D=2):
#
#    Agente X: Recompensa Promedio=-0.040, Victorias=21, Empates=6, Derrotas=23, Tiempo Promedio/Acción=16.49ms
#
#    Agente O: Recompensa Promedio=0.040, Victorias=23, Empates=6, Derrotas=21, Tiempo Promedio/Acción=60.37ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=30,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.320, Victorias=16, Empates=2, Derrotas=32, Tiempo Promedio/Acción=16.72ms
#
#    Agente O: Recompensa Promedio=0.320, Victorias=32, Empates=2, Derrotas=16, Tiempo Promedio/Acción=53.85ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.180, Victorias=29, Empates=1, Derrotas=20, Tiempo Promedio/Acción=17.15ms
#
#    Agente O: Recompensa Promedio=-0.180, Victorias=20, Empates=1, Derrotas=29, Tiempo Promedio/Acción=45.50ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.080, Victorias=25, Empates=4, Derrotas=21, Tiempo Promedio/Acción=17.08ms
#
#    Agente O: Recompensa Promedio=-0.080, Victorias=21, Empates=4, Derrotas=25, Tiempo Promedio/Acción=41.65ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=1,D=3):
#
#    Agente X: Recompensa Promedio=-0.040, Victorias=23, Empates=2, Derrotas=25, Tiempo Promedio/Acción=16.50ms
#
#    Agente O: Recompensa Promedio=0.040, Victorias=25, Empates=2, Derrotas=23, Tiempo Promedio/Acción=40.21ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.220, Victorias=29, Empates=3, Derrotas=18, Tiempo Promedio/Acción=15.77ms
#
#    Agente O: Recompensa Promedio=-0.220, Victorias=18, Empates=3, Derrotas=29, Tiempo Promedio/Acción=73.02ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.420, Victorias=35, Empates=1, Derrotas=14, Tiempo Promedio/Acción=16.01ms
#
#    Agente O: Recompensa Promedio=-0.420, Victorias=14, Empates=1, Derrotas=35, Tiempo Promedio/Acción=69.28ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.180, Victorias=19, Empates=3, Derrotas=28, Tiempo Promedio/Acción=15.82ms
#
#    Agente O: Recompensa Promedio=0.180, Victorias=28, Empates=3, Derrotas=19, Tiempo Promedio/Acción=61.03ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.400, Victorias=34, Empates=2, Derrotas=14, Tiempo Promedio/Acción=17.28ms
#
#    Agente O: Recompensa Promedio=-0.400, Victorias=14, Empates=2, Derrotas=34, Tiempo Promedio/Acción=104.65ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.300, Victorias=32, Empates=1, Derrotas=17, Tiempo Promedio/Acción=15.68ms
#
#    Agente O: Recompensa Promedio=-0.300, Victorias=17, Empates=1, Derrotas=32, Tiempo Promedio/Acción=95.45ms
#
#
# --- Probando: MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=1) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.200, Victorias=20, Empates=0, Derrotas=30, Tiempo Promedio/Acción=17.77ms
#
#    Agente O: Recompensa Promedio=0.200, Victorias=30, Empates=0, Derrotas=20, Tiempo Promedio/Acción=88.55ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MCTS(S=10,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MCTS(S=10,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.620, Victorias=40, Empates=1, Derrotas=9, Tiempo Promedio/Acción=15.75ms
#
#    Agente O: Recompensa Promedio=-0.620, Victorias=9, Empates=1, Derrotas=40, Tiempo Promedio/Acción=16.02ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MCTS(S=10,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MCTS(S=10,R=2,D=3):
#
#    Agente X: Recompensa Promedio=0.180, Victorias=28, Empates=3, Derrotas=19, Tiempo Promedio/Acción=15.78ms
#
#    Agente O: Recompensa Promedio=-0.180, Victorias=19, Empates=3, Derrotas=28, Tiempo Promedio/Acción=14.79ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MCTS(S=10,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MCTS(S=10,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.660, Victorias=41, Empates=1, Derrotas=8, Tiempo Promedio/Acción=15.31ms
#
#    Agente O: Recompensa Promedio=-0.660, Victorias=8, Empates=1, Derrotas=41, Tiempo Promedio/Acción=22.74ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MCTS(S=10,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MCTS(S=10,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.700, Victorias=41, Empates=3, Derrotas=6, Tiempo Promedio/Acción=15.46ms
#
#    Agente O: Recompensa Promedio=-0.700, Victorias=6, Empates=3, Derrotas=41, Tiempo Promedio/Acción=22.86ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MCTS(S=10,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MCTS(S=10,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.500, Victorias=36, Empates=3, Derrotas=11, Tiempo Promedio/Acción=15.92ms
#
#    Agente O: Recompensa Promedio=-0.500, Victorias=11, Empates=3, Derrotas=36, Tiempo Promedio/Acción=20.72ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MCTS(S=30,R=1,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MCTS(S=30,R=1,D=1):
#
#    Agente X: Recompensa Promedio=0.720, Victorias=43, Empates=0, Derrotas=7, Tiempo Promedio/Acción=16.63ms
#
#    Agente O: Recompensa Promedio=-0.720, Victorias=7, Empates=0, Derrotas=43, Tiempo Promedio/Acción=30.29ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MCTS(S=30,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MCTS(S=30,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.420, Victorias=33, Empates=5, Derrotas=12, Tiempo Promedio/Acción=14.60ms
#
#    Agente O: Recompensa Promedio=-0.420, Victorias=12, Empates=5, Derrotas=33, Tiempo Promedio/Acción=26.69ms
#
#
# --- Probando: MCTS(S=10,R=2,D=2) vs MCTS(S=30,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=10,R=2,D=2) vs MCTS(S=30,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.060, Victorias=24, Empates=5, Derrotas=21, Tiempo Promedio/Acción=15.57ms
#
# ...
#
#    Agente X: Recompensa Promedio=-0.120, Victorias=21, Empates=2, Derrotas=27, Tiempo Promedio/Acción=40.89ms
#
#    Agente O: Recompensa Promedio=0.120, Victorias=27, Empates=2, Derrotas=21, Tiempo Promedio/Acción=79.05ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=1,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=1,D=2):
#
#    Agente X: Recompensa Promedio=0.380, Victorias=32, Empates=5, Derrotas=13, Tiempo Promedio/Acción=45.67ms
#
#    Agente O: Recompensa Promedio=-0.380, Victorias=13, Empates=5, Derrotas=32, Tiempo Promedio/Acción=45.95ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.200, Victorias=29, Empates=2, Derrotas=19, Tiempo Promedio/Acción=44.24ms
#
#    Agente O: Recompensa Promedio=-0.200, Victorias=19, Empates=2, Derrotas=29, Tiempo Promedio/Acción=39.97ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.840, Victorias=46, Empates=0, Derrotas=4, Tiempo Promedio/Acción=42.56ms
#
#    Agente O: Recompensa Promedio=-0.840, Victorias=4, Empates=0, Derrotas=46, Tiempo Promedio/Acción=80.18ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.220, Victorias=28, Empates=5, Derrotas=17, Tiempo Promedio/Acción=42.03ms
#
#    Agente O: Recompensa Promedio=-0.220, Victorias=17, Empates=5, Derrotas=28, Tiempo Promedio/Acción=66.22ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.100, Victorias=21, Empates=3, Derrotas=26, Tiempo Promedio/Acción=41.76ms
#
#    Agente O: Recompensa Promedio=0.100, Victorias=26, Empates=3, Derrotas=21, Tiempo Promedio/Acción=62.87ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.840, Victorias=46, Empates=0, Derrotas=4, Tiempo Promedio/Acción=44.13ms
#
#    Agente O: Recompensa Promedio=-0.840, Victorias=4, Empates=0, Derrotas=46, Tiempo Promedio/Acción=112.08ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.240, Victorias=29, Empates=4, Derrotas=17, Tiempo Promedio/Acción=43.11ms
#
#    Agente O: Recompensa Promedio=-0.240, Victorias=17, Empates=4, Derrotas=29, Tiempo Promedio/Acción=93.44ms
#
#
# --- Probando: MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=2) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.140, Victorias=28, Empates=1, Derrotas=21, Tiempo Promedio/Acción=43.16ms
#
#    Agente O: Recompensa Promedio=-0.140, Victorias=21, Empates=1, Derrotas=28, Tiempo Promedio/Acción=88.46ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=1,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=1,D=3):
#
#    Agente X: Recompensa Promedio=0.620, Victorias=39, Empates=3, Derrotas=8, Tiempo Promedio/Acción=37.95ms
#
#    Agente O: Recompensa Promedio=-0.620, Victorias=8, Empates=3, Derrotas=39, Tiempo Promedio/Acción=40.10ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.820, Victorias=44, Empates=3, Derrotas=3, Tiempo Promedio/Acción=38.79ms
#
#    Agente O: Recompensa Promedio=-0.820, Victorias=3, Empates=3, Derrotas=44, Tiempo Promedio/Acción=72.85ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.660, Victorias=39, Empates=5, Derrotas=6, Tiempo Promedio/Acción=42.28ms
#
#    Agente O: Recompensa Promedio=-0.660, Victorias=6, Empates=5, Derrotas=39, Tiempo Promedio/Acción=70.59ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=0.340, Victorias=32, Empates=3, Derrotas=15, Tiempo Promedio/Acción=41.48ms
#
#    Agente O: Recompensa Promedio=-0.340, Victorias=15, Empates=3, Derrotas=32, Tiempo Promedio/Acción=63.67ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.640, Victorias=39, Empates=4, Derrotas=7, Tiempo Promedio/Acción=38.65ms
#
#    Agente O: Recompensa Promedio=-0.640, Victorias=7, Empates=4, Derrotas=39, Tiempo Promedio/Acción=101.60ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.480, Victorias=33, Empates=8, Derrotas=9, Tiempo Promedio/Acción=37.62ms
#
#    Agente O: Recompensa Promedio=-0.480, Victorias=9, Empates=8, Derrotas=33, Tiempo Promedio/Acción=87.01ms
#
#
# --- Probando: MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=1,D=3) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.480, Victorias=35, Empates=4, Derrotas=11, Tiempo Promedio/Acción=37.32ms
#
#    Agente O: Recompensa Promedio=-0.480, Victorias=11, Empates=4, Derrotas=35, Tiempo Promedio/Acción=84.38ms
#
#
# --- Probando: MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=2,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=2,D=1):
#
#    Agente X: Recompensa Promedio=0.800, Victorias=45, Empates=0, Derrotas=5, Tiempo Promedio/Acción=68.93ms
#
#    Agente O: Recompensa Promedio=-0.800, Victorias=5, Empates=0, Derrotas=45, Tiempo Promedio/Acción=75.31ms
#
#
# --- Probando: MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.420, Victorias=34, Empates=3, Derrotas=13, Tiempo Promedio/Acción=70.41ms
#
#    Agente O: Recompensa Promedio=-0.420, Victorias=13, Empates=3, Derrotas=34, Tiempo Promedio/Acción=68.30ms
#
#
# --- Probando: MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.080, Victorias=23, Empates=0, Derrotas=27, Tiempo Promedio/Acción=63.94ms
#
#    Agente O: Recompensa Promedio=0.080, Victorias=27, Empates=0, Derrotas=23, Tiempo Promedio/Acción=53.63ms
#
#
# --- Probando: MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.680, Victorias=42, Empates=0, Derrotas=8, Tiempo Promedio/Acción=60.55ms
#
#    Agente O: Recompensa Promedio=-0.680, Victorias=8, Empates=0, Derrotas=42, Tiempo Promedio/Acción=91.97ms
#
#
# --- Probando: MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.180, Victorias=29, Empates=1, Derrotas=20, Tiempo Promedio/Acción=62.93ms
#
#    Agente O: Recompensa Promedio=-0.180, Victorias=20, Empates=1, Derrotas=29, Tiempo Promedio/Acción=82.06ms
#
#
# --- Probando: MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=1) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.140, Victorias=21, Empates=1, Derrotas=28, Tiempo Promedio/Acción=63.13ms
#
#    Agente O: Recompensa Promedio=0.140, Victorias=28, Empates=1, Derrotas=21, Tiempo Promedio/Acción=72.35ms
#
#
# --- Probando: MCTS(S=50,R=2,D=2) vs MCTS(S=50,R=2,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=2) vs MCTS(S=50,R=2,D=2):
#
#    Agente X: Recompensa Promedio=0.480, Victorias=34, Empates=6, Derrotas=10, Tiempo Promedio/Acción=57.40ms
#
#    Agente O: Recompensa Promedio=-0.480, Victorias=10, Empates=6, Derrotas=34, Tiempo Promedio/Acción=58.78ms
#
#
# --- Probando: MCTS(S=50,R=2,D=2) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=2) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=-0.080, Victorias=22, Empates=2, Derrotas=26, Tiempo Promedio/Acción=57.56ms
#
#    Agente O: Recompensa Promedio=0.080, Victorias=26, Empates=2, Derrotas=22, Tiempo Promedio/Acción=51.74ms
#
#
# --- Probando: MCTS(S=50,R=2,D=2) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=2) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.780, Victorias=44, Empates=1, Derrotas=5, Tiempo Promedio/Acción=59.22ms
#
#    Agente O: Recompensa Promedio=-0.780, Victorias=5, Empates=1, Derrotas=44, Tiempo Promedio/Acción=92.98ms
#
#
# --- Probando: MCTS(S=50,R=2,D=2) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=2) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.460, Victorias=34, Empates=5, Derrotas=11, Tiempo Promedio/Acción=59.16ms
#
#    Agente O: Recompensa Promedio=-0.460, Victorias=11, Empates=5, Derrotas=34, Tiempo Promedio/Acción=82.91ms
#
#
# --- Probando: MCTS(S=50,R=2,D=2) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=2) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.020, Victorias=24, Empates=3, Derrotas=23, Tiempo Promedio/Acción=58.27ms
#
#    Agente O: Recompensa Promedio=-0.020, Victorias=23, Empates=3, Derrotas=24, Tiempo Promedio/Acción=74.66ms
#
#
# --- Probando: MCTS(S=50,R=2,D=3) vs MCTS(S=50,R=2,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=3) vs MCTS(S=50,R=2,D=3):
#
#    Agente X: Recompensa Promedio=0.360, Victorias=33, Empates=2, Derrotas=15, Tiempo Promedio/Acción=54.71ms
#
#    Agente O: Recompensa Promedio=-0.360, Victorias=15, Empates=2, Derrotas=33, Tiempo Promedio/Acción=54.28ms
#
#
# --- Probando: MCTS(S=50,R=2,D=3) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=3) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.920, Victorias=48, Empates=0, Derrotas=2, Tiempo Promedio/Acción=56.47ms
#
#    Agente O: Recompensa Promedio=-0.920, Victorias=2, Empates=0, Derrotas=48, Tiempo Promedio/Acción=92.27ms
#
#
# --- Probando: MCTS(S=50,R=2,D=3) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=3) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.440, Victorias=33, Empates=6, Derrotas=11, Tiempo Promedio/Acción=54.08ms
#
#    Agente O: Recompensa Promedio=-0.440, Victorias=11, Empates=6, Derrotas=33, Tiempo Promedio/Acción=81.95ms
#
#
# --- Probando: MCTS(S=50,R=2,D=3) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=2,D=3) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.560, Victorias=37, Empates=4, Derrotas=9, Tiempo Promedio/Acción=53.31ms
#
#    Agente O: Recompensa Promedio=-0.560, Victorias=9, Empates=4, Derrotas=37, Tiempo Promedio/Acción=75.09ms
#
#
# --- Probando: MCTS(S=50,R=3,D=1) vs MCTS(S=50,R=3,D=1) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=1) vs MCTS(S=50,R=3,D=1):
#
#    Agente X: Recompensa Promedio=0.640, Victorias=41, Empates=0, Derrotas=9, Tiempo Promedio/Acción=87.04ms
#
#    Agente O: Recompensa Promedio=-0.640, Victorias=9, Empates=0, Derrotas=41, Tiempo Promedio/Acción=94.42ms
#
#
# --- Probando: MCTS(S=50,R=3,D=1) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=1) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.300, Victorias=31, Empates=3, Derrotas=16, Tiempo Promedio/Acción=84.79ms
#
#    Agente O: Recompensa Promedio=-0.300, Victorias=16, Empates=3, Derrotas=31, Tiempo Promedio/Acción=82.06ms
#
#
# --- Probando: MCTS(S=50,R=3,D=1) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=1) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.260, Victorias=18, Empates=1, Derrotas=31, Tiempo Promedio/Acción=86.07ms
#
#    Agente O: Recompensa Promedio=0.260, Victorias=31, Empates=1, Derrotas=18, Tiempo Promedio/Acción=72.80ms
#
#
# --- Probando: MCTS(S=50,R=3,D=2) vs MCTS(S=50,R=3,D=2) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=2) vs MCTS(S=50,R=3,D=2):
#
#    Agente X: Recompensa Promedio=0.520, Victorias=37, Empates=2, Derrotas=11, Tiempo Promedio/Acción=82.63ms
#
#    Agente O: Recompensa Promedio=-0.520, Victorias=11, Empates=2, Derrotas=37, Tiempo Promedio/Acción=83.78ms
#
#
# --- Probando: MCTS(S=50,R=3,D=2) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=2) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=-0.040, Victorias=23, Empates=2, Derrotas=25, Tiempo Promedio/Acción=81.38ms
#
#    Agente O: Recompensa Promedio=0.040, Victorias=25, Empates=2, Derrotas=23, Tiempo Promedio/Acción=72.02ms
#
#
# --- Probando: MCTS(S=50,R=3,D=3) vs MCTS(S=50,R=3,D=3) (50 juegos) ---
#    Juego 10/50
#    Juego 20/50
#    Juego 30/50
#    Juego 40/50
#    Juego 50/50
#
# Resultados Agregados para MCTS(S=50,R=3,D=3) vs MCTS(S=50,R=3,D=3):
#
#    Agente X: Recompensa Promedio=0.300, Victorias=29, Empates=7, Derrotas=14, Tiempo Promedio/Acción=84.50ms
#
#    Agente O: Recompensa Promedio=-0.300, Victorias=14, Empates=7, Derrotas=29, Tiempo Promedio/Acción=87.17ms

# %% [markdown]
# ## Guardar Resultados

# %%
import os
import csv
import numpy as np

def ensure_dir_for_file(filepath: str):
    folder = os.path.dirname(filepath)
    if folder and not os.path.exists(folder):
        os.makedirs(folder)

# Asegurarse que las carpetas existen antes de guardar los archivos
ensure_dir_for_file(summary_csv_file)
ensure_dir_for_file(summary_log_file)

# Guardar CSV detallado
print("\n--- Guardando resultados detallados en CSV ---")
csv_headers = ['Configuration', 'Agent Role', 'Average Reward', 'Total Wins', 'Total Draws', 'Total Losses', 'Average Time (ms)']

with open(summary_csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_headers)
    writer.writeheader()
    writer.writerows(detailed_csv_rows)
print(f"Archivo CSV guardado en: {summary_csv_file}")

# Guardar resumen en log
print("\n--- Guardando resumen en log ---")
with open(summary_log_file, 'a', encoding='utf-8') as log_file:
    for priority_name, current_weight_time in weight_time_configs.items():
        log_lines = []
        header_line = f"\n\n--- Análisis Final: {priority_name} (WEIGHT_TIME = {current_weight_time}) ---\n"
        print(header_line)
        log_lines.append(header_line)

        # Inicializar diccionarios para mejores configuraciones
        best_configs = {
            "MCTS_vs_Random": {"score": -np.inf, "config": None},
            "Random_vs_MCTS": {"score": -np.inf, "config": None},
            "MiniMax_vs_Random": {"score": -np.inf, "config": None},
            "Random_vs_MiniMax": {"score": -np.inf, "config": None},
            "MCTS_vs_MiniMax": {"score": -np.inf, "config": None},
            "MiniMax_vs_MCTS": {"score": -np.inf, "config": None},
            "MCTS_vs_MCTS": {"score": -np.inf, "config": None},
        }

        for config_name, agent_results in all_results.items():
            # Obtener tipo de agentes
            agent1_raw, agent2_raw = config_name.split(" vs ")
            agent1_type = agent1_raw.split('(')[0]
            agent2_type = agent2_raw.split('(')[0]

            # Determinar agente principal
            main_agent_role = None
            if agent1_type in ["MCTS", "MiniMax"]:
                main_agent_role = game.agents[0]
            elif agent2_type in ["MCTS", "MiniMax"]:
                main_agent_role = game.agents[1]

            if not main_agent_role or main_agent_role not in agent_results:
                continue

            # Calcular métricas
            avg_reward = np.mean(agent_results[main_agent_role]['rewards'])
            avg_time_ms = np.mean(agent_results[main_agent_role]['times']) * 1000
            total_wins = sum(agent_results[main_agent_role]['wins'])
            total_draws = sum(agent_results[main_agent_role]['draws'])
            total_losses = sum(agent_results[main_agent_role]['losses'])

            combined_score = avg_reward - (current_weight_time * avg_time_ms)

            # Actualizar mejores configuraciones
            key = None
            if agent1_type == "MCTS" and agent2_type == "Random":
                key = "MCTS_vs_Random"
            elif agent1_type == "Random" and agent2_type == "MCTS":
                key = "Random_vs_MCTS"
            elif agent1_type == "MiniMax" and agent2_type == "Random":
                key = "MiniMax_vs_Random"
            elif agent1_type == "Random" and agent2_type == "MiniMax":
                key = "Random_vs_MiniMax"
            elif agent1_type == "MCTS" and agent2_type == "MiniMax":
                key = "MCTS_vs_MiniMax"
            elif agent1_type == "MiniMax" and agent2_type == "MCTS":
                key = "MiniMax_vs_MCTS"
            elif agent1_type == "MCTS" and agent2_type == "MCTS":
                key = "MCTS_vs_MCTS"

            if key is None:
                continue

            if combined_score > best_configs[key]["score"]:
                best_configs[key] = {
                    "score": combined_score,
                    "config": config_name,
                    "avg_time_ms": avg_time_ms,
                    "wins": total_wins,
                    "draws": total_draws,
                    "losses": total_losses,
                    "agent_role": main_agent_role
                }

        # Función para imprimir y escribir en log la info de la mejor config
        def print_and_log_best(key, title):
            bc = best_configs[key]
            if bc["config"] is None:
                line = f"\n**{title}:** No se encontraron configuraciones para esta categoría.\n"
                print(line)
                log_lines.append(line)
                return
            
            win_rate = bc["wins"] / N_GAMES_PER_CONFIG
            draw_rate = bc["draws"] / N_GAMES_PER_CONFIG
            loss_rate = bc["losses"] / N_GAMES_PER_CONFIG
            
            line = (
                f"\n**{title}:**\n"
                f"  Mejor Configuración: {bc['config']}\n"
                f"  Score Combinado: {bc['score']:.3f}\n"
                f"  Victorias: {bc['wins']} ({win_rate:.2%})\n"
                f"  Empates: {bc['draws']} ({draw_rate:.2%})\n"
                f"  Derrotas: {bc['losses']} ({loss_rate:.2%})\n"
                f"  Tiempo Promedio/Acción: {bc['avg_time_ms']:.2f} ms\n"
                f"  Agente Principal (rol): {bc['agent_role']}\n"
            )
            print(line)
            log_lines.append(line)

        print_and_log_best("MCTS_vs_Random", "MCTS (Agente X) vs Random (Agente O)")
        print_and_log_best("Random_vs_MCTS", "Random (Agente X) vs MCTS (Agente O)")
        print_and_log_best("MiniMax_vs_Random", "MiniMax (Agente X) vs Random (Agente O)")
        print_and_log_best("Random_vs_MiniMax", "Random (Agente X) vs MiniMax (Agente O)")
        print_and_log_best("MCTS_vs_MiniMax", "MCTS (Agente X) vs MiniMax (Agente O)")
        print_and_log_best("MiniMax_vs_MCTS", "MiniMax (Agente X) vs MCTS (Agente O)")
        print_and_log_best("MCTS_vs_MCTS", "MCTS (Agente X) vs MCTS (Agente O)")

        log_file.writelines(log_lines)

print("\n--- Guardado completo ---")
# Out:
# --- Guardando resultados detallados en CSV ---
# Archivo CSV guardado en: grid_search_results_tateti_20250624_202015\detailed_results.csv
#
# --- Guardando resumen en log ---
#
#
# --- Análisis Final: Priorizando Victoria (WEIGHT_TIME = 1e-05) ---
#
#
# **MCTS (Agente X) vs Random (Agente O):**
#   Mejor Configuración: MCTS(S=10,R=3,D=3) vs Random
#   Score Combinado: 1.000
#   Victorias: 50 (100.00%)
#   Empates: 0 (0.00%)
#   Derrotas: 0 (0.00%)
#   Tiempo Promedio/Acción: 19.41 ms
#   Agente Principal (rol): X
#
#
# **Random (Agente X) vs MCTS (Agente O):**
#   Mejor Configuración: Random vs MCTS(S=50,R=1,D=3)
#   Score Combinado: 0.820
#   Victorias: 44 (88.00%)
#   Empates: 3 (6.00%)
#   Derrotas: 3 (6.00%)
#   Tiempo Promedio/Acción: 35.77 ms
#   Agente Principal (rol): O
#
#
# **MiniMax (Agente X) vs Random (Agente O):**
#   Mejor Configuración: MiniMax(D=3) vs Random
#   Score Combinado: 0.899
#   Victorias: 47 (94.00%)
#   Empates: 1 (2.00%)
#   Derrotas: 2 (4.00%)
#   Tiempo Promedio/Acción: 117.60 ms
#   Agente Principal (rol): X
#
#
# **Random (Agente X) vs MiniMax (Agente O):**
#   Mejor Configuración: Random vs MiniMax(D=3)
#   Score Combinado: 0.639
#   Victorias: 37 (74.00%)
#   Empates: 8 (16.00%)
#   Derrotas: 5 (10.00%)
#   Tiempo Promedio/Acción: 71.27 ms
#   Agente Principal (rol): O
#
#
# **MCTS (Agente X) vs MiniMax (Agente O):**
#   Mejor Configuración: MCTS(S=10,R=1,D=3) vs MiniMax(D=1)
#   Score Combinado: 1.000
#   Victorias: 50 (100.00%)
#   Empates: 0 (0.00%)
#   Derrotas: 0 (0.00%)
#   Tiempo Promedio/Acción: 7.99 ms
#   Agente Principal (rol): X
#
#
# **MiniMax (Agente X) vs MCTS (Agente O):**
#   Mejor Configuración: MiniMax(D=3) vs MCTS(S=30,R=1,D=1)
#   Score Combinado: 0.959
#   Victorias: 49 (98.00%)
#   Empates: 0 (0.00%)
#   Derrotas: 1 (2.00%)
#   Tiempo Promedio/Acción: 110.37 ms
#   Agente Principal (rol): X
#
#
# **MCTS (Agente X) vs MCTS (Agente O):**
#   Mejor Configuración: MCTS(S=10,R=3,D=2) vs MCTS(S=30,R=2,D=1)
#   Score Combinado: 0.960
#   Victorias: 49 (98.00%)
#   Empates: 0 (0.00%)
#   Derrotas: 1 (2.00%)
#   Tiempo Promedio/Acción: 22.86 ms
#   Agente Principal (rol): X
#
#
#
# --- Análisis Final: Priorizando Velocidad (WEIGHT_TIME = 0.01) ---
#
#
# **MCTS (Agente X) vs Random (Agente O):**
#   Mejor Configuración: MCTS(S=10,R=1,D=2) vs Random
#   Score Combinado: 0.835
#   Victorias: 47 (94.00%)
#   Empates: 2 (4.00%)
#   Derrotas: 1 (2.00%)
#   Tiempo Promedio/Acción: 8.46 ms
#   Agente Principal (rol): X
#
#
# **Random (Agente X) vs MCTS (Agente O):**
#   Mejor Configuración: Random vs MCTS(S=50,R=1,D=3)
#   Score Combinado: 0.462
#   Victorias: 44 (88.00%)
#   Empates: 3 (6.00%)
#   Derrotas: 3 (6.00%)
#   Tiempo Promedio/Acción: 35.77 ms
#   Agente Principal (rol): O
#
#
# **MiniMax (Agente X) vs Random (Agente O):**
#   Mejor Configuración: MiniMax(D=2) vs Random
#   Score Combinado: 0.614
#   Victorias: 42 (84.00%)
#   Empates: 5 (10.00%)
#   Derrotas: 3 (6.00%)
#   Tiempo Promedio/Acción: 16.56 ms
#   Agente Principal (rol): X
#
#
# **Random (Agente X) vs MiniMax (Agente O):**
#   Mejor Configuración: Random vs MiniMax(D=2)
#   Score Combinado: 0.133
#   Victorias: 18 (36.00%)
#   Empates: 27 (54.00%)
#   Derrotas: 5 (10.00%)
#   Tiempo Promedio/Acción: 12.71 ms
#   Agente Principal (rol): O
#
#
# **MCTS (Agente X) vs MiniMax (Agente O):**
#   Mejor Configuración: MCTS(S=10,R=1,D=3) vs MiniMax(D=1)
#   Score Combinado: 0.920
#   Victorias: 50 (100.00%)
#   Empates: 0 (0.00%)
#   Derrotas: 0 (0.00%)
#   Tiempo Promedio/Acción: 7.99 ms
#   Agente Principal (rol): X
#
#
# **MiniMax (Agente X) vs MCTS (Agente O):**
#   Mejor Configuración: MiniMax(D=2) vs MCTS(S=50,R=3,D=3)
#   Score Combinado: 0.363
#   Victorias: 36 (72.00%)
#   Empates: 4 (8.00%)
#   Derrotas: 10 (20.00%)
#   Tiempo Promedio/Acción: 15.70 ms
#   Agente Principal (rol): X
#
#
# **MCTS (Agente X) vs MCTS (Agente O):**
#   Mejor Configuración: MCTS(S=10,R=1,D=3) vs MCTS(S=30,R=1,D=1)
#   Score Combinado: 0.745
#   Victorias: 45 (90.00%)
#   Empates: 2 (4.00%)
#   Derrotas: 3 (6.00%)
#   Tiempo Promedio/Acción: 9.48 ms
#   Agente Principal (rol): X
#
#
# --- Guardado completo ---

# %% [markdown]
# ## Guardar Visualizaciones

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os 
import re 

print("\n--- Generando Visualizaciones y Guardando Gráficos para TODAS las combinaciones ---")

# Cargar los datos del CSV (asumiendo que summary_csv_file está definido en Celda 1 y Celda 6 ya corrió)
try:
    df_all_results = pd.read_csv(summary_csv_file)
except FileNotFoundError:
    print(f"Error: No se encontró el archivo CSV de resultados en '{summary_csv_file}'. Asegúrate de ejecutar la Celda 6 primero.")
    df_all_results = pd.DataFrame() # DataFrame vacío para evitar errores

if df_all_results.empty:
    print("El DataFrame de resultados está vacío. No se generarán visualizaciones.")
else:
    # --- Helper function for saving plots ---
    def save_plot(fig, folder_name, plot_filename):
        plot_folder_path = os.path.join(main_results_dir, folder_name)
        os.makedirs(plot_folder_path, exist_ok=True)
        full_path = os.path.join(plot_folder_path, plot_filename)
        fig.savefig(full_path, bbox_inches='tight')
        print(f"Guardado: {full_path}")
        plt.close(fig) # Close the figure to free up memory

    # --- MAIN LOOP: Gráficos de barras comparativos para CADA CONFIGURACIÓN ÚNICA ---
    print("\n--- Generando gráficos de barras comparativos por cada configuración ---")
    unique_combinations = df_all_results['Configuration'].unique()

    for config_label in unique_combinations:
        df_current_config_data = df_all_results[df_all_results['Configuration'] == config_label].copy()
        
        if df_current_config_data.empty:
            continue

        # Extraer el nombre de la carpeta de subresultados (Ej. "MCTS_vs_Random")
        agent_types_folder_name_parts = [s.split('(')[0] for s in config_label.split(" vs ")]
        agent_types_folder = f"{agent_types_folder_name_parts[0]}_vs_{agent_types_folder_name_parts[1]}"
        
        # Limpiar el nombre del archivo para evitar caracteres problemáticos
        filename_base = config_label.replace('(', '_').replace(')', '').replace(',', '_').replace('=', '').replace(' ', '_').replace('vs', '_vs_').replace('__', '_')
        
        # --- Gráfico de barras para Recompensa Promedio ---
        fig_reward_bar = plt.figure(figsize=(8, 5))
        sns.barplot(x='Agent Role', y='Average Reward', data=df_current_config_data, palette='viridis')
        plt.title(f'Recompensa Promedio en: {config_label}')
        plt.xlabel('Rol del Agente')
        plt.ylabel('Recompensa Promedio')
        plt.ylim(-1, 1) # Normalizar el eje Y para consistencia
        save_plot(fig_reward_bar, agent_types_folder, f'{filename_base}_reward_barplot.png')

        # --- Gráfico de barras para Tiempo Promedio ---
        fig_time_bar = plt.figure(figsize=(8, 5))
        sns.barplot(x='Agent Role', y='Average Time (ms)', data=df_current_config_data, palette='coolwarm')
        plt.title(f'Tiempo Promedio por Acción en: {config_label}')
        plt.xlabel('Rol del Agente')
        plt.ylabel('Tiempo Promedio (ms)')
        save_plot(fig_time_bar, agent_types_folder, f'{filename_base}_time_barplot.png')

    # --- SECCIONES ADICIONALES: Heatmaps / Barplots AGRUPADOS por tipo de enfrentamiento ---
    print("\n--- Generando heatmaps/barplots agrupados (si hay suficientes datos) ---")

    # --- 1. MCTS (Agente X) vs Random (Agente O) - Heatmaps ---
    df_mcts_x_vs_random_o_grouped = df_all_results[
        (df_all_results['Configuration'].str.contains("MCTS") & df_all_results['Configuration'].str.contains("Random")) &
        (df_all_results['Agent Role'] == game.agents[0]) # MCTS es Agente X
    ].copy()

    if not df_mcts_x_vs_random_o_grouped.empty:
        df_mcts_x_vs_random_o_grouped[['Simulations', 'Rollouts', 'Depth']] = df_mcts_x_vs_random_o_grouped['Configuration'].apply(
            lambda x: pd.Series(extract_mcts_params(x))
        )
        df_mcts_x_vs_random_o_grouped.dropna(subset=['Simulations', 'Rollouts', 'Depth'], inplace=True)
        
        # Check if there's enough variation for a heatmap (more than one unique value per axis)
        if df_mcts_x_vs_random_o_grouped['Simulations'].nunique() > 1 and \
           (df_mcts_x_vs_random_o_grouped['Rollouts'].nunique() > 1 or df_mcts_x_vs_random_o_grouped['Depth'].nunique() > 1):
            
            df_mcts_x_vs_random_o_grouped['Rollouts_Depth'] = df_mcts_x_vs_random_o_grouped['Rollouts'].astype(int).astype(str) + '_D' + df_mcts_x_vs_random_o_grouped['Depth'].astype(int).astype(str)

            # Heatmap Recompensa
            fig_hm1_reward = plt.figure(figsize=(10, 6))
            pivot_reward = df_mcts_x_vs_random_o_grouped.pivot_table(index='Simulations', columns='Rollouts_Depth', values='Average Reward')
            sns.heatmap(pivot_reward, annot=True, fmt=".2f", cmap="viridis", linewidths=.5)
            plt.title('MCTS (Agente X) vs Random: Recompensa Promedio (Agrupado)')
            plt.xlabel('Rollouts y Profundidad MCTS')
            plt.ylabel('Simulaciones MCTS')
            save_plot(fig_hm1_reward, get_folder_name("MCTS", "Random"), 'mcts_x_vs_random_o_reward_heatmap.png')

            # Heatmap Tiempo
            fig_hm1_time = plt.figure(figsize=(10, 6))
            pivot_time = df_mcts_x_vs_random_o_grouped.pivot_table(index='Simulations', columns='Rollouts_Depth', values='Average Time (ms)')
            sns.heatmap(pivot_time, annot=True, fmt=".2f", cmap="coolwarm", linewidths=.5)
            plt.title('MCTS (Agente X) vs Random: Tiempo Promedio (ms) (Agrupado)')
            plt.xlabel('Rollouts y Profundidad MCTS')
            plt.ylabel('Simulaciones MCTS')
            save_plot(fig_hm1_time, get_folder_name("MCTS", "Random"), 'mcts_x_vs_random_o_time_heatmap.png')
        else:
            print("No hay suficientes datos variados para heatmaps de MCTS (Agente X) vs Random.")
    else:
        print("No hay datos para MCTS (Agente X) vs Random para generar heatmaps agrupados.")

    # --- 2. Random (Agente X) vs MCTS (Agente O) - Heatmaps ---
    df_random_x_vs_mcts_o_grouped = df_all_results[
        (df_all_results['Configuration'].str.contains("Random") & df_all_results['Configuration'].str.contains("MCTS")) &
        (df_all_results['Agent Role'] == game.agents[1]) # MCTS es Agente O
    ].copy()

    if not df_random_x_vs_mcts_o_grouped.empty:
        df_random_x_vs_mcts_o_grouped[['Simulations', 'Rollouts', 'Depth']] = df_random_x_vs_mcts_o_grouped['Configuration'].apply(
            lambda x: pd.Series(extract_mcts_params(x))
        )
        df_random_x_vs_mcts_o_grouped.dropna(subset=['Simulations', 'Rollouts', 'Depth'], inplace=True)

        if df_random_x_vs_mcts_o_grouped['Simulations'].nunique() > 1 and \
           (df_random_x_vs_mcts_o_grouped['Rollouts'].nunique() > 1 or df_random_x_vs_mcts_o_grouped['Depth'].nunique() > 1):
            
            df_random_x_vs_mcts_o_grouped['Rollouts_Depth'] = df_random_x_vs_mcts_o_grouped['Rollouts'].astype(int).astype(str) + '_D' + df_random_x_vs_mcts_o_grouped['Depth'].astype(int).astype(str)

            # Heatmap Recompensa (para MCTS como Agente O)
            fig_hm2_reward = plt.figure(figsize=(10, 6))
            pivot_reward = df_random_x_vs_mcts_o_grouped.pivot_table(index='Simulations', columns='Rollouts_Depth', values='Average Reward')
            sns.heatmap(pivot_reward, annot=True, fmt=".2f", cmap="viridis", linewidths=.5)
            plt.title('Random (Agente X) vs MCTS (Agente O): Recompensa Promedio (Agente O, Agrupado)')
            plt.xlabel('Rollouts y Profundidad MCTS')
            plt.ylabel('Simulaciones MCTS')
            save_plot(fig_hm2_reward, get_folder_name("Random", "MCTS"), 'random_x_vs_mcts_o_reward_heatmap.png')

            # Heatmap Tiempo (para MCTS como Agente O)
            fig_hm2_time = plt.figure(figsize=(10, 6))
            pivot_time = df_random_x_vs_mcts_o_grouped.pivot_table(index='Simulations', columns='Rollouts_Depth', values='Average Time (ms)')
            sns.heatmap(pivot_time, annot=True, fmt=".2f", cmap="coolwarm", linewidths=.5)
            plt.title('Random (Agente X) vs MCTS (Agente O): Tiempo Promedio (ms) (Agente O, Agrupado)')
            plt.xlabel('Rollouts y Profundidad MCTS')
            plt.ylabel('Simulaciones MCTS')
            save_plot(fig_hm2_time, get_folder_name("Random", "MCTS"), 'random_x_vs_mcts_o_time_heatmap.png')
        else:
            print("No hay suficientes datos variados para heatmaps de Random (Agente X) vs MCTS (Agente O).")
    else:
        print("No hay datos para Random (Agente X) vs MCTS (Agente O) para generar heatmaps agrupados.")

    # --- 3. MiniMax (Agente X) vs Random (Agente O) - Barplots Agrupados ---
    df_minimax_x_vs_random_o_grouped = df_all_results[
        (df_all_results['Configuration'].str.contains("MiniMax") & df_all_results['Configuration'].str.contains("Random")) &
        (df_all_results['Agent Role'] == game.agents[0]) # MiniMax es Agente X
    ].copy()

    if not df_minimax_x_vs_random_o_grouped.empty:
        df_minimax_x_vs_random_o_grouped['Depth'] = df_minimax_x_vs_random_o_grouped['Configuration'].apply(extract_minimax_params)
        df_minimax_x_vs_random_o_grouped.dropna(subset=['Depth'], inplace=True)
        
        # Check if there's enough variation for a barplot (more than one unique depth)
        if df_minimax_x_vs_random_o_grouped['Depth'].nunique() > 1:
            # Barplot Recompensa
            fig_bp1_reward = plt.figure(figsize=(8, 5))
            sns.barplot(x='Depth', y='Average Reward', data=df_minimax_x_vs_random_o_grouped, palette='viridis')
            plt.title('MiniMax (Agente X) vs Random: Recompensa Promedio por Profundidad (Agrupado)')
            plt.xlabel('Profundidad MiniMax')
            plt.ylabel('Recompensa Promedio')
            save_plot(fig_bp1_reward, get_folder_name("MiniMax", "Random"), 'minimax_x_vs_random_o_reward_barplot_grouped.png')

            # Barplot Tiempo
            fig_bp1_time = plt.figure(figsize=(8, 5))
            sns.barplot(x='Depth', y='Average Time (ms)', data=df_minimax_x_vs_random_o_grouped, palette='coolwarm')
            plt.title('MiniMax (Agente X) vs Random: Tiempo Promedio (ms) por Profundidad (Agrupado)')
            plt.xlabel('Profundidad MiniMax')
            plt.ylabel('Tiempo Promedio (ms)')
            save_plot(fig_bp1_time, get_folder_name("MiniMax", "Random"), 'minimax_x_vs_random_o_time_barplot_grouped.png')
        else:
            print("No hay suficientes datos variados para barplots agrupados de MiniMax (Agente X) vs Random.")
    else:
        print("No hay datos para MiniMax (Agente X) vs Random para generar barplots agrupados.")

    # --- 4. Random (Agente X) vs MiniMax (Agente O) - Barplots Agrupados ---
    df_random_x_vs_minimax_o_grouped = df_all_results[
        (df_all_results['Configuration'].str.contains("Random") & df_all_results['Configuration'].str.contains("MiniMax")) &
        (df_all_results['Agent Role'] == game.agents[1]) # MiniMax es Agente O
    ].copy()

    if not df_random_x_vs_minimax_o_grouped.empty:
        df_random_x_vs_minimax_o_grouped['Depth'] = df_random_x_vs_minimax_o_grouped['Configuration'].apply(extract_minimax_params)
        df_random_x_vs_minimax_o_grouped.dropna(subset=['Depth'], inplace=True)
        
        if df_random_x_vs_minimax_o_grouped['Depth'].nunique() > 1:
            # Barplot Recompensa (para MiniMax como Agente O)
            fig_bp2_reward = plt.figure(figsize=(8, 5))
            sns.barplot(x='Depth', y='Average Reward', data=df_random_x_vs_minimax_o_grouped, palette='viridis')
            plt.title('Random (Agente X) vs MiniMax (Agente O): Recompensa Promedio (Agente O, Agrupado)')
            plt.xlabel('Profundidad MiniMax')
            plt.ylabel('Recompensa Promedio')
            save_plot(fig_bp2_reward, get_folder_name("Random", "MiniMax"), 'random_x_vs_minimax_o_reward_barplot_grouped.png')

            # Barplot Tiempo (para MiniMax como Agente O)
            fig_bp2_time = plt.figure(figsize=(8, 5))
            sns.barplot(x='Depth', y='Average Time (ms)', data=df_random_x_vs_minimax_o_grouped, palette='coolwarm')
            plt.title('Random (Agente X) vs MiniMax (Agente O): Tiempo Promedio (ms) (Agente O, Agrupado)')
            plt.xlabel('Profundidad MiniMax')
            plt.ylabel('Tiempo Promedio (ms)')
            save_plot(fig_bp2_time, get_folder_name("Random", "MiniMax"), 'random_x_vs_minimax_o_time_barplot_grouped.png')
        else:
            print("No hay suficientes datos variados para barplots agrupados de Random (Agente X) vs MiniMax (Agente O).")
    else:
        print("No hay datos para Random (Agente X) vs MiniMax (Agente O) para generar barplots agrupados.")

print("--- Generación de Visualizaciones Completada ---")
# Out:
# --- Generando Visualizaciones y Guardando Gráficos para TODAS las combinaciones ---
#
# --- Generando gráficos de barras comparativos por cada configuración ---
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R1_D1_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R1_D1_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R1_D2_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R1_D2_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R1_D3_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R1_D3_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R2_D1_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R2_D1_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R2_D2_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R2_D2_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R2_D3_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R2_D3_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R3_D1_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R3_D1_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R3_D2_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R3_D2_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R3_D3_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S10_R3_D3_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R1_D1_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R1_D1_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R1_D2_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R1_D2_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R1_D3_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R1_D3_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R2_D1_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R2_D1_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R2_D2_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R2_D2_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R2_D3_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R2_D3_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R3_D1_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R3_D1_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R3_D2_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R3_D2_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R3_D3_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S30_R3_D3_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R1_D1_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R1_D1_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R1_D2_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R1_D2_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R1_D3_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R1_D3_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R2_D1_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R2_D1_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R2_D2_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R2_D2_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R2_D3_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R2_D3_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R3_D1_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R3_D1_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R3_D2_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R3_D2_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R3_D3_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\MCTS_S50_R3_D3_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S10_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S30_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\Random_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_Random\MiniMax_D1_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_Random\MiniMax_D1_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_Random\MiniMax_D2_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_Random\MiniMax_D2_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_Random\MiniMax_D3_vs_Random_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_Random\MiniMax_D3_vs_Random_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MiniMax\Random_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MiniMax\Random_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MiniMax\Random_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MiniMax\Random_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MiniMax\Random_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MiniMax\Random_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D1_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D1_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D1_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D1_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D1_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D1_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D2_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D2_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D2_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D2_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D2_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D2_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D3_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D3_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D3_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D3_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D3_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R1_D3_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D1_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D1_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D1_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D1_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D1_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D1_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D2_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D2_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D2_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D2_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D2_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D2_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D3_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D3_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D3_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D3_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D3_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R2_D3_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D1_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D1_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D1_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D1_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D1_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D1_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D2_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D2_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D2_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D2_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D2_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D2_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D3_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D3_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D3_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D3_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D3_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S10_R3_D3_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D1_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D1_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D1_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D1_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D1_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D1_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D2_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D2_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D2_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D2_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D2_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D2_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D3_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D3_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D3_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D3_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D3_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R1_D3_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D1_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D1_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D1_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D1_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D1_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D1_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D2_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D2_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D2_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D2_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D2_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D2_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D3_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D3_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D3_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D3_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D3_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R2_D3_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D1_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D1_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D1_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D1_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D1_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D1_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D2_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D2_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D2_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D2_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D2_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D2_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D3_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D3_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D3_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D3_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D3_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S30_R3_D3_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D1_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D1_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D1_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D1_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D1_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D1_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D2_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D2_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D2_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D2_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D2_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D2_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D3_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D3_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D3_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D3_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D3_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R1_D3_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D1_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D1_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D1_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D1_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D1_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D1_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D2_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D2_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D2_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D2_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D2_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D2_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D3_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D3_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D3_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D3_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D3_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R2_D3_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D1_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D1_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D1_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D1_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D1_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D1_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D2_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D2_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D2_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D2_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D2_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D2_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D3_vs_MiniMax_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D3_vs_MiniMax_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D3_vs_MiniMax_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D3_vs_MiniMax_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D3_vs_MiniMax_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MiniMax\MCTS_S50_R3_D3_vs_MiniMax_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S10_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S30_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D1_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S10_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S30_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D2_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S10_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S30_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_MCTS\MiniMax_D3_vs_MCTS_S50_R3_D3_time_barplot.png
# ...
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D1_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D1_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D1_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D1_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S30_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S30_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S30_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S30_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D2_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S30_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S30_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S30_R3_D3_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R1_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R1_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D1_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R1_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R1_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D2_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R1_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R1_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R1_D3_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R2_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R2_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D1_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D2_vs_MCTS_S50_R2_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D2_vs_MCTS_S50_R2_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D2_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D2_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D2_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D2_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D2_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D2_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D2_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D2_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D3_vs_MCTS_S50_R2_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D3_vs_MCTS_S50_R2_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D3_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D3_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D3_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D3_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D3_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R2_D3_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D1_vs_MCTS_S50_R3_D1_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D1_vs_MCTS_S50_R3_D1_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D1_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D1_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D1_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D1_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D2_vs_MCTS_S50_R3_D2_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D2_vs_MCTS_S50_R3_D2_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D2_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D2_vs_MCTS_S50_R3_D3_time_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D3_vs_MCTS_S50_R3_D3_reward_barplot.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_MCTS\MCTS_S50_R3_D3_vs_MCTS_S50_R3_D3_time_barplot.png
#
# --- Generando heatmaps/barplots agrupados (si hay suficientes datos) ---
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\mcts_x_vs_random_o_reward_heatmap.png
# Guardado: grid_search_results_20250617_095847\MCTS_vs_Random\mcts_x_vs_random_o_time_heatmap.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\random_x_vs_mcts_o_reward_heatmap.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MCTS\random_x_vs_mcts_o_time_heatmap.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_Random\minimax_x_vs_random_o_reward_barplot_grouped.png
# Guardado: grid_search_results_20250617_095847\MiniMax_vs_Random\minimax_x_vs_random_o_time_barplot_grouped.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MiniMax\random_x_vs_minimax_o_reward_barplot_grouped.png
# Guardado: grid_search_results_20250617_095847\Random_vs_MiniMax\random_x_vs_minimax_o_time_barplot_grouped.png
# --- Generación de Visualizaciones Completada ---
