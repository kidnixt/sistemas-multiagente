# %%
from games.nocca_nocca.nocca_nocca import NoccaNocca
from agents.agent_random import RandomAgent
from agents.minimax import MiniMax

# %%
game = NoccaNocca(max_steps=150, initial_player=0, seed=1)

# %%
agents = {
    game.agents[0]: MiniMax(game=game, agent=game.agents[0], depth=1),
    game.agents[1]: MiniMax(game=game, agent=game.agents[1], depth=1),
}

# %%
game.reset()
print(f"Initial Agent: {game.agent_selection}")
while not game.game_over():
    game.render()
    action = agents[game.agent_selection].action()
    print(f"Turn {game.steps} -- Agent {game.agent_selection} plays action {action}")
    game.step(action=action)
game.render()
if game.truncated():
    print("Game was truncated")
for agent in agents:
    print(f"Reward agent {agent}: {game.reward(agent)}")
print(f"The winner is: {game.check_for_winner()}")
# Out:
# Initial Agent: Black
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ 0__ 0__
# 2: ___ ___ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ 1__ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 0 -- Agent Black plays action 70
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ 1__ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 1 -- Agent White plays action 274
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 2 -- Agent Black plays action 43
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ 0__ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 3 -- Agent White plays action 240
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ 0__ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ 1__ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 4 -- Agent Black plays action 50
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ 1__ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 5 -- Agent White plays action 207
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 6 -- Agent Black plays action 58
# 0: ___ ___ ___ ___ ___
# 1: 0__ 00_ ___ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 7 -- Agent White plays action 173
# 0: ___ ___ ___ ___ ___
# 1: 0__ 00_ ___ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: 1__ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 8 -- Agent Black plays action 50
# 0: ___ ___ ___ ___ ___
# 1: 00_ 0__ ___ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: 1__ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 9 -- Agent White plays action 253
# 0: ___ ___ ___ ___ ___
# 1: 00_ 0__ ___ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: 1__ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 10 -- Agent Black plays action 52
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 0__
# 2: 0__ ___ ___ ___ 0__
# 3: 1__ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 11 -- Agent White plays action 266
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 0__
# 2: 0__ ___ ___ ___ 0__
# 3: 1__ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ 11_ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 12 -- Agent Black plays action 112
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 00_
# 2: 0__ ___ ___ ___ ___
# 3: 1__ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ 11_ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 13 -- Agent White plays action 261
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 00_
# 2: 0__ ___ ___ ___ ___
# 3: 1__ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ 1__ ___ ___ ___
# 6: ___ ___ 1__ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 14 -- Agent Black plays action 86
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 00_
# 2: ___ ___ ___ ___ ___
# 3: 1__ 0__ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ 1__ ___ ___ ___
# 6: ___ ___ 1__ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 15 -- Agent White plays action 266
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 00_
# 2: ___ ___ ___ ___ ___
# 3: 1__ 0__ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ 1__ ___ ___ ___
# 6: ___ ___ 11_ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 16 -- Agent Black plays action 74
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ 0__ 0__
# 2: ___ ___ ___ ___ ___
# 3: 1__ 0__ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ 1__ ___ ___ ___
# 6: ___ ___ 11_ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 17 -- Agent White plays action 215
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ 0__ 0__
# 2: ___ ___ ___ ___ ___
# 3: 1__ 0__ ___ ___ ___
# 4: ___ ___ 1__ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ 11_ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 18 -- Agent Black plays action 68
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 0__
# 2: ___ ___ 0__ ___ ___
# 3: 1__ 0__ ___ ___ ___
# 4: ___ ___ 1__ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ 11_ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 19 -- Agent White plays action 127
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 0__
# 2: ___ 1__ 0__ ___ ___
# 3: ___ 0__ ___ ___ ___
# 4: ___ ___ 1__ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ 11_ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 20 -- Agent Black plays action 99
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 0__
# 2: ___ 1__ ___ 0__ ___
# 3: ___ 0__ ___ ___ ___
# 4: ___ ___ 1__ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ 11_ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 21 -- Agent White plays action 207
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 0__
# 2: ___ 1__ ___ 0__ ___
# 3: ___ 0__ ___ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ ___ 11_ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 22 -- Agent Black plays action 128
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 0__
# 2: ___ 10_ ___ 0__ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ ___ 11_ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 23 -- Agent White plays action 261
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ ___ ___ 0__
# 2: ___ 10_ ___ 0__ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ 1__ ___ ___ ___
# 6: ___ ___ 1__ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 24 -- Agent Black plays action 109
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ 0__ ___ 0__
# 2: ___ 10_ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ 1__ ___ ___ ___
# 6: ___ ___ 1__ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 25 -- Agent White plays action 261
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ 0__ ___ 0__
# 2: ___ 10_ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ 11_ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 26 -- Agent Black plays action 74
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ 0__ 0__ ___
# 2: ___ 10_ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ 11_ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 27 -- Agent White plays action 210
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ 0__ 0__ ___
# 2: ___ 10_ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: 1__ 1__ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 28 -- Agent Black plays action 94
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ 0__ 0__ ___
# 2: ___ 1__ ___ ___ ___
# 3: ___ ___ 0__ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: 1__ 1__ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 29 -- Agent White plays action 206
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ 0__ 0__ ___
# 2: ___ 1__ ___ ___ ___
# 3: ___ ___ 0__ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ 1__ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 30 -- Agent Black plays action 143
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ 0__ 0__ ___
# 2: ___ 1__ ___ 0__ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ 1__ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 31 -- Agent White plays action 215
# 0: ___ ___ ___ ___ ___
# 1: 00_ ___ 0__ 0__ ___
# 2: ___ 1__ ___ 0__ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 11_ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 32 -- Agent Black plays action 41
# 0: ___ ___ ___ ___ ___
# 1: 0__ ___ 0__ 0__ ___
# 2: 0__ 1__ ___ 0__ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 11_ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 33 -- Agent White plays action 183
# 0: ___ ___ ___ ___ ___
# 1: 0__ ___ 0__ 0__ ___
# 2: 0__ 1__ ___ 0__ ___
# 3: ___ ___ ___ 1__ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 34 -- Agent Black plays action 41
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 0__ 0__ ___
# 2: 00_ 1__ ___ 0__ ___
# 3: ___ ___ ___ 1__ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 35 -- Agent White plays action 144
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 0__ 0__ ___
# 2: 00_ 1__ ___ 01_ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 36 -- Agent Black plays action 68
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 0__ ___ ___
# 2: 00_ 1__ 0__ 01_ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ 1__ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 37 -- Agent White plays action 183
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 0__ ___ ___
# 2: 00_ 1__ 0__ 01_ ___
# 3: ___ ___ ___ 1__ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 38 -- Agent Black plays action 99
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 0__ ___ ___
# 2: 00_ 1__ ___ 010 ___
# 3: ___ ___ ___ 1__ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 39 -- Agent White plays action 251
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 0__ ___ ___
# 2: 00_ 1__ ___ 010 ___
# 3: ___ ___ ___ 1__ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ ___ 1__ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 40 -- Agent Black plays action 111
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 0__ ___ 0__
# 2: 00_ 1__ ___ 01_ ___
# 3: ___ ___ ___ 1__ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ ___ 1__ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 41 -- Agent White plays action 173
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 0__ ___ 0__
# 2: 00_ 1__ ___ 01_ ___
# 3: 1__ ___ ___ 1__ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ ___ 1__ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 42 -- Agent Black plays action 87
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ 0__
# 2: 0__ 1__ ___ 01_ ___
# 3: 1__ ___ ___ 1__ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ ___ 1__ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 43 -- Agent White plays action 258
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ 0__
# 2: 0__ 1__ ___ 01_ ___
# 3: 1__ ___ ___ 1__ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 44 -- Agent Black plays action 86
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ 0__
# 2: ___ 1__ ___ 01_ ___
# 3: 1__ 0__ ___ 1__ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 45 -- Agent White plays action 90
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ 0__
# 2: 1__ ___ ___ 01_ ___
# 3: 1__ 0__ ___ 1__ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 46 -- Agent Black plays action 134
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ 0__
# 2: 1__ ___ ___ 01_ ___
# 3: 1__ ___ ___ 1__ ___
# 4: ___ ___ 0__ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 47 -- Agent White plays action 123
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ 0__
# 2: 1__ ___ ___ 01_ ___
# 3: ___ 1__ ___ 1__ ___
# 4: ___ ___ 0__ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 48 -- Agent Black plays action 60
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ ___ ___ 0__
# 2: 1__ 0__ ___ 01_ ___
# 3: ___ 1__ ___ 1__ ___
# 4: ___ ___ 0__ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 49 -- Agent White plays action 87
# 0: ___ ___ ___ ___ ___
# 1: ___ 01_ ___ ___ 0__
# 2: ___ 0__ ___ 01_ ___
# 3: ___ 1__ ___ 1__ ___
# 4: ___ ___ 0__ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 50 -- Agent Black plays action 183
# 0: ___ ___ ___ ___ ___
# 1: ___ 01_ ___ ___ 0__
# 2: ___ 0__ ___ 01_ ___
# 3: ___ 1__ ___ 10_ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 51 -- Agent White plays action 53
# 0: 1__ ___ ___ ___ ___
# 1: ___ 0__ ___ ___ 0__
# 2: ___ 0__ ___ 01_ ___
# 3: ___ 1__ ___ 10_ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: ___ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Reward agent Black: -1
# Reward agent White: 1
# The winner is: White
